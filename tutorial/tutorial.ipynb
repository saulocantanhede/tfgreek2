# %%
# %load_ext autoreload
# %autoreload 2

from tf.fabric import Fabric
from tf.app import use

# %%
NA = use("ETCBC/nestle1904", hoist=globals())
A = use("saulocantanhede/tfgreek2", version="0.5.1", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv0.4.0=#g61756f28da3d0fdf8053448afbccb9b20607c60c offline under C:/Users/TF/text-fabric-data/github">~/text-fabric-data/github/ETCBC/nestle1904/app</span>
# <b title="local release">data:</b> <span title="rv0.4.0=#g61756f28da3d0fdf8053448afbccb9b20607c60c offline under C:/Users/TF/text-fabric-data/github">~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.5.1</a>, <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/app" title="ETCBC/nestle1904 app">ETCBC/nestle1904/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/about.md" title="provenance of ETCBC - nestle1904/tf">ETCBC - nestle1904 0.4.0</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/greek.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="ETCBC - nestle1904 feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>27</td>
#     <td>5102.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>260</td>
#     <td>529.92</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>7944</td>
#     <td>17.34</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>8011</td>
#     <td>17.20</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>wg</th>
#     <td>114879</td>
#     <td>7.60</td>
#     <td><i>633</i></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>30152</td>
#     <td>7.37</td>
#     <td><i>161</i></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>42636</td>
#     <td>3.21</td>
#     <td>99</td>
# </tr>
#
# <tr>
#     <th><i>w</i></th>
#     <td>137779</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>ETCBC - nestle1904/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> material after the end of the word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/appositioncontainer.tf">appositioncontainer</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if it is an apposition container</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/articular.tf">articular</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the wg has an article</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> book name (abbreviated), from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/case.tf">case</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> chapter number, from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/clauseType.tf">clauseType</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/cls.tf">cls</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute cls</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/cltype.tf">cltype</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type for verbless, verb-elided, and minor clauses</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/crule.tf">crule</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause rule (from xml attribute Rule)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/degree.tf">degree</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical degree</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/discontinuous.tf">discontinuous</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the word is out of sequence in the xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/domain.tf">domain</a>
# </div>
# <div class="fmono">str</div>
#
# <span> domain</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/framespec.tf">framespec</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute framespec</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/gender.tf">gender</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/gloss.tf">gloss</a>
# </div>
# <div class="fmono">str</div>
#
# <span> short translation</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/id.tf">id</a>
# </div>
# <div class="fmono">str</div>
#
# <span> xml id</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/junction.tf">junction</a>
# </div>
# <div class="fmono">str</div>
#
# <span> type of junction</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/lang.tf">lang</a>
# </div>
# <div class="fmono">str</div>
#
# <span> lang
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--borde
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# **Locating corpus resources ...**
# <b title="local commit">app:</b> <span title="#a66a7847e4e3f82c3701d74aab14fbb8377678f3 offline under C:/Users/TF/text-fabric-data/github">~/text-fabric-data/github/saulocantanhede/tfgreek2/app</span>
# <b title="local commit">data:</b> <span title="#a66a7847e4e3f82c3701d74aab14fbb8377678f3 offline under C:/Users/TF/text-fabric-data/github">~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.5.1</a>, <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/app" title="saulocantanhede/tfgreek2 app">saulocantanhede/tfgreek2/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/about.md" title="provenance of saulocantanhede - tfgreek2/tf">saulocantanhede - tfgreek2 0.5.1</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="saulocantanhede - tfgreek2 feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>27</td>
#     <td>5102.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>260</td>
#     <td>529.92</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>7944</td>
#     <td>17.34</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>8011</td>
#     <td>17.20</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>30152</td>
#     <td>7.37</td>
#     <td><i>161</i></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>141650</td>
#     <td>4.08</td>
#     <td><i>419</i></td>
# </tr>
#
# <tr>
#     <th>subphrase</th>
#     <td>72845</td>
#     <td>1.00</td>
#     <td>53</td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>137779</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>saulocantanhede - tfgreek2/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> material after the end of the word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/appositioncontainer.tf">appositioncontainer</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if it is an apposition container</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/articular.tf">articular</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the wg has an article</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> book name (abbreviated), from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/book_short.tf">book_short</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute book_short</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/case.tf">case</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> chapter number, from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/clauseType.tf">clauseType</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/cls.tf">cls</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute cls</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/cltype.tf">cltype</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/crule.tf">crule</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause rule (from xml attribute Rule)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/degree.tf">degree</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical degree</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/discontinuous.tf">discontinuous</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the word is out of sequence in the xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/domain.tf">domain</a>
# </div>
# <div class="fmono">str</div>
#
# <span> domain</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/framespec.tf">framespec</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute framespec</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/function.tf">function</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute function</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.1/gender.tf">gender</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/blob/main/docs/transcription.md" title="~/text-fabric-data/github/saulocantanhede/tfgreek2/tf
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--borde
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>

# %% [markdown]
# # Operational matters
#
# You can now get a report of the memory footprint of a TF dataset:

# %%
A.footprint()
# Out:
# # 59 features
#
# feature | members | size in bytes
# --- | --- | ---
# __levUp__ | 398,668 | 74,558,176
# parent | 244,646 | 45,366,420
# sibling | 129,767 | 43,799,224
# num | 390,464 | 32,468,632
# __levDown__ | 260,889 | 27,661,716
# id | 275,558 | 26,605,999
# ref | 275,558 | 26,423,196
# __boundary__ | 2 | 24,706,036
# oslots | 3 | 24,479,752
# unicode | 275,558 | 20,937,256
# text | 275,558 | 20,312,916
# cls | 348,346 | 20,240,486
# normalized | 275,558 | 20,209,882
# gloss | 275,558 | 19,413,793
# lemma | 275,558 | 18,770,341
# strong | 275,558 | 18,344,056
# morph | 275,558 | 18,261,164
# after | 275,558 | 18,202,711
# ln | 253,758 | 18,022,126
# domain | 253,758 | 17,688,963
# number | 197,874 | 16,026,440
# __order__ | 398,668 | 14,352,088
# case | 159,036 | 9,696,263
# type | 157,626 | 9,657,465
# gender | 147,950 | 9,385,738
# book | 146,010 | 9,332,773
# chapter | 145,983 | 9,330,492
# verse | 145,723 | 9,323,212
# frame | 25,491 | 9,204,957
# book_short | 137,806 | 9,102,940
# role | 131,010 | 8,912,018
# rule | 93,234 | 7,902,994
# function | 91,262 | 7,798,569
# framespec | 50,986 | 5,613,154
# mood | 56,714 | 4,209,881
# tense | 56,714 | 4,209,867
# voice | 56,714 | 4,209,756
# subjrefspec | 33,150 | 2,592,765
# referent | 28,942 | 2,515,167
# typ | 42,621 | 2,504,455
# subjref | 16,575 | 2,454,440
# person | 38,838 | 2,398,435
# articular | 28,772 | 2,116,452
# otype | 4 | 2,087,721
# __rank__ | 398,668 | 1,647,884
# junction | 17,921 | 1,091,827
# discontinuous | 12,068 | 927,852
# nodeId | 5,558 | 628,480
# __sections__ | 2 | 572,804
# crule | 5,558 | 450,731
# clauseType | 5,296 | 295,900
# cltype | 2,843 | 227,326
# appositioncontainer | 1,908 | 127,268
# rela | 1,632 | 119,565
# degree | 1,026 | 65,808
# __characters__ | 1 | 30,696
# lang | 27 | 1,983
# __levels__ | 8 | 1,737
# note | 2 | 360
# TOTAL | 7,876,102 | 707,601,108

# %% [markdown]
# # Existence of error nodes

# %%
F.otype.s("error")
# Out:
# ()

# %% [markdown]
# No error nodes anymore.

# %% [markdown]
# # Books
# We changed from the abbreviation of the name to the names itself.

# %%
for b in F.otype.s("book"):
    print(f"{b} {NA.sectionStrFromNode(b)}")
for b in F.otype.s("book"):
    print(f"{b} {A.sectionStrFromNode(b)}")
# Out:
# 137780 MAT
# 137781 MRK
# 137782 LUK
# 137783 JHN
# 137784 ACT
# 137785 ROM
# 137786 1CO
# 137787 2CO
# 137788 GAL
# 137789 EPH
# 137790 PHP
# 137791 COL
# 137792 1TH
# 137793 2TH
# 137794 1TI
# 137795 2TI
# 137796 TIT
# 137797 PHM
# 137798 HEB
# 137799 JAS
# 137800 1PE
# 137801 2PE
# 137802 1JN
# 137803 2JN
# 137804 3JN
# 137805 JUD
# 137806 REV
# 137780 Matthew
# 137781 Mark
# 137782 Luke
# 137783 John
# 137784 Acts
# 137785 Romans
# 137786 1Corinthians
# 137787 2Corinthians
# 137788 Galatians
# 137789 Ephesians
# 137790 Philippians
# 137791 Colossians
# 137792 1Thessalonians
# 137793 2Thessalonians
# 137794 1Timothy
# 137795 2Timothy
# 137796 Titus
# 137797 Philemon
# 137798 Hebrews
# 137799 James
# 137800 1Peter
# 137801 2Peter
# 137802 1John
# 137803 2John
# 137804 3John
# 137805 Jude
# 137806 Revelation

# %% [markdown]
# # Features on `word` and `wg`
#
# Some features have values for `word` and for `wg` nodes. Yet we can get frequnecy lists for them separately.

# %%
F.cls.freqList(nodeTypes={"word"})
# Out:
# (('noun', 28455),
#  ('verb', 28357),
#  ('det', 19786),
#  ('conj', 18227),
#  ('pron', 16177),
#  ('prep', 10914),
#  ('adj', 8452),
#  ('adv', 6147),
#  ('ptcl', 773),
#  ('num', 476),
#  ('intj', 15))

# %%
F.cls.freqList(nodeTypes={"wg"})
# Out:
# ()

# %%
F.cls.freqList(nodeTypes={"clause"})
# Out:
# (('cl', 30152),)

# %%
F.cls.freqList(nodeTypes={"phrase"})
# Out:
# (('np', 30911),
#  ('verb', 27546),
#  ('conj', 18228),
#  ('pp', 11169),
#  ('pron', 8754),
#  ('adv', 4391),
#  ('noun', 3238),
#  ('adj', 2344),
#  ('det', 257),
#  ('vp', 207),
#  ('adjp', 168),
#  ('advp', 166),
#  ('ptcl', 148),
#  ('num', 25),
#  ('intj', 7),
#  ('nump', 7),
#  ('prep', 4))

# %%
F.cls.freqList(nodeTypes={"subphrase"})
# Out:
# (('noun', 25217),
#  ('det', 19529),
#  ('prep', 10910),
#  ('pron', 7423),
#  ('adj', 6108),
#  ('adv', 1763),
#  ('verb', 811),
#  ('ptcl', 625),
#  ('num', 451),
#  ('intj', 8))

# %% [markdown]
# ## A sentence with discontinuous word groups

# %%
NA.displaySetup(withNodes=True,
               standardFeatures=True,
               hideTypes=True,
               queryFeatures=False)
A.displaySetup(withNodes=True,
               standardFeatures=False,
               hideTypes=True,
               queryFeatures=False)

# %%
matthew = A.nodeFromSectionStr("Matthew")
#L is the Locality class looking for downward (d) nodes
s = L.d(matthew)[1]
A.pretty(s)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Matthew/1/1&amp;version=0.5.1" title="Show this on the website" sec="Matthew@1:1">Matthew@1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse:390725 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:309869 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause:138067 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168219 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317880 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1 </span> <span class="txtu">Βίβλος </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168220 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317881 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">2 </span> <span class="txtu">γενέσεως </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168221 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168222 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168223 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317882 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">3 </span> <span class="txtu">Ἰησοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317883 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">4 </span> <span class="txtu">Χριστοῦ </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168224 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317884 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">5 </span> <span class="txtu">υἱοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317885 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">6 </span> <span class="txtu">Δαυεὶδ </span></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168225 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317886 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">7 </span> <span class="txtu">υἱοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317887 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">8 </span> <span class="txtu">Ἀβραάμ.</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div>

# %% [markdown]
# ## Clauses and phrases
#
# We can switch from a lowlevel display with `wg` elements to a higher-level display with `clause` and `phrase` elements.

# %%
A.pretty(s)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Matthew/1/1&amp;version=0.5.1" title="Show this on the website" sec="Matthew@1:1">Matthew@1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse:390725 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:309869 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause:138067 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168219 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317880 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1 </span> <span class="txtu">Βίβλος </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168220 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317881 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">2 </span> <span class="txtu">γενέσεως </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168221 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168222 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168223 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317882 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">3 </span> <span class="txtu">Ἰησοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317883 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">4 </span> <span class="txtu">Χριστοῦ </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168224 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317884 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">5 </span> <span class="txtu">υἱοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317885 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">6 </span> <span class="txtu">Δαυεὶδ </span></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168225 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317886 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">7 </span> <span class="txtu">υἱοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317887 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">8 </span> <span class="txtu">Ἀβραάμ.</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div>

# %% [markdown]
# ## Parents
#
# For now, we stick to the low-level display with `wg` elements.

# %%
word = L.d(s, otype="word")[0]

parent = E.parent.f(word)[0]

A.pretty(s, highlights={parent: "cyan", word: "salmon"})
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Matthew/1/1&amp;version=0.5.1" title="Show this on the website" sec="Matthew@1:1">Matthew@1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse:390725 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:309869 </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause:138067 </span></div><div class="children hor wrap "><div class="contnr c1    hl"  style="background-color: cyan;" ><div class="lbl c1  hl"  style="background-color: cyan;" ><span class="nd">phrase:168219 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317880 </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: salmon;" ><div class="lbl c0 trm hl"  style="background-color: salmon;" ><span class="nd">1 </span> <span class="txtu">Βίβλος </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168220 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317881 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">2 </span> <span class="txtu">γενέσεως </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168221 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168222 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168223 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317882 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">3 </span> <span class="txtu">Ἰησοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317883 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">4 </span> <span class="txtu">Χριστοῦ </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168224 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317884 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">5 </span> <span class="txtu">υἱοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317885 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">6 </span> <span class="txtu">Δαυεὶδ </span></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168225 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317886 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">7 </span> <span class="txtu">υἱοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317887 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">8 </span> <span class="txtu">Ἀβραάμ.</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div>

# %% [markdown]
# Look for `wg` parents that have `word` children.

# %%
results = A.search("""
book book=Matthew
  clause
  <parent- word
""")
A.show(results, end=1, condenseType="clause", queryFeatures=False)
# Out:
#   0.46s 6607 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Matthew/1/1&amp;version=0.5.1" title="Show this on the website" sec="Matthew">Matthew</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book:137780 </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">Matthew</span></span></span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Matthew/1/2&amp;version=0.5.1" title="Show this on the website" sec="Matthew@1:2">Matthew@1:2</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause:138068 </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase:168226 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168227 </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="nd">9 </span> <span class="txtu">Ἀβραὰμ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168228 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">10 </span> <span class="txtu">ἐγέννησεν </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:168229 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317888 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">11 </span> <span class="txtu">τὸν </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:317889 </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">12 </span> <span class="txtu">Ἰσαάκ,</span></div></div></div></div></div></div></div></div></div></div></div>

# %% [markdown]
# # Siblings

# %%
wg = L.d(s, otype="wg")[4]
parent = E.parent.f(wg)[0]
siblings = E.sibling.b(wg)

for (sib, dist) in siblings:
    print(f"distance from {F.otype.v(sib)}-node {sib} to wg-node {wg} = `{dist}`\n\n")
    A.pretty(sib, queryFeatures=False, hiddenTypes={"wg"})
    
highlights = {sib[0]: "cyan" for sib in siblings}
highlights[wg] = "salmon"

A.pretty(parent, highlights=highlights, hiddenTypes={"wg"})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15624\3634361541.py in <module>
# ----> 1 wg = L.d(s, otype="wg")[4]
#       2 parent = E.parent.f(wg)[0]
#       3 siblings = E.sibling.b(wg)
#       4
#       5 for (sib, dist) in siblings:
#
# IndexError: tuple index out of range

# %% [markdown]
# Look for `word` siblings with distance greater than 3 in Jude:

# %%
results = A.search("""
book book=Jude
    clause
        phrase
            word
            -sibling>3> word
""")
A.show(results, end=1, queryFeatures=False)
# Out:
#   0.58s 3 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Jude/1/1&amp;version=0.5.1" title="Show this on the website" sec="Jude">Jude</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">Jude</span></span></span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Jude/1/5&amp;version=0.5.1" title="Show this on the website" sec="Jude@1:5">Jude@1:5</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ὑπομνῆσαι </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὑμᾶς </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">βούλομαι,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">εἰδότας </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἅπαξ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">πάντα,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὅτι </span></div></div><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">Κύριος </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">λαὸν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐκ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">γῆς </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Αἰγύπτου </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">σώσας </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τὸ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δεύτερον </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τοὺς </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">μὴ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">πιστεύσαντας </span></div></div><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">ἀπώλεσεν,</span></div></div></div></div></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Jude/1/7&amp;version=0.5.1" title="Show this on the website" sec="Jude@1:7">Jude@1:7</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὡς </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Σόδομα </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Γόμορρα </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">αἱ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">περὶ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">αὐτὰς </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">πόλεις,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τὸν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὅμοιον </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τρόπον </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τούτοις </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐκπορνεύσασαι </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀπελθοῦσαι </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὀπίσω </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">σαρκὸς </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἑτέρας,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">πρόκεινται </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δεῖγμα </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">πυρὸς </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">αἰωνίου </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δίκην </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὑπέχουσαι.</span></div></div></div></div></div></div></div>

# %% [markdown]
# # Sibling distance
#
# What is the biggest distance between siblings?

# %%
maxDist = -1
pair = None

for (fro, tos) in E.sibling.items():
    for (to, dist) in tos.items():
        if int(dist) > int(maxDist):
            maxDist = dist
            pair = (fro, to)
        
(fro, to) = pair

# %%
print(f"""
The maximum distance between siblings is **{maxDist}**

* from {F.otype.v(fro)}-node {fro}
* to {F.otype.v(to)}-node {to}
""")

A.plain(fro)
A.plain(to)
parent = E.parent.f(fro)[0]

A.pretty(parent, highlights={fro, to}, queryFeatures=False)
# Out:
# The maximum distance between siblings is **20**
#
# * from phrase-node 270604
# * to phrase-node 270640
# <div class=""><span class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/2Corinthians/6/4&amp;version=0.5.1" title="Show this on the website" sec="2Corinthians@6:4">2Corinthians@6:4</a></span></span>  <span class="txtu">ἐν </span><span class="txtu">ὑπομονῇ </span><span class="txtu">πολλῇ,</span></div>
# <div class=""><span class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/2Corinthians/6/8&amp;version=0.5.1" title="Show this on the website" sec="2Corinthians@6:8">2Corinthians@6:8</a></span></span>  <span class="txtu">διὰ </span><span class="txtu">δυσφημίας </span><span class="txtu">καὶ </span><span class="txtu">εὐφημίας·</span></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/2Corinthians/6/4&amp;version=0.5.1" title="Show this on the website" sec="2Corinthians@6:4">2Corinthians@6:4</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὑπομονῇ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">πολλῇ,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">θλίψεσιν,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀνάγκαις,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">στενοχωρίαις,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">πληγαῖς,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">φυλακαῖς,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀκαταστασίαις,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">κόποις,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀγρυπνίαις,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">νηστείαις,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἁγνότητι,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">γνώσει,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">μακροθυμίᾳ,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">χρηστότητι,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Πνεύματι </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἁγίῳ,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀγάπῃ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀνυποκρίτῳ,</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu" ...

# %% [markdown]
# # Frames
#
# We show a few verbal frames.

# %%
frames = A.search("""
book book=Jude
    word framespec
    -frame> word
""")
A.show(frames, start=3, end=6, colorMap={2: "cyan", 3: "salmon"}, queryFeatures=True)
# Out:
#   0.48s 145 results
# <p><b>result</b> <i>3</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Jude/1/1&amp;version=0.5.1" title="Show this on the website" sec="Jude">Jude</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">Jude</span></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Jude/1/2&amp;version=0.5.1" title="Show this on the website" sec="Jude@1:2">Jude@1:2</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: salmon;" ><div class="lbl c0 trm hl"  style="background-color: salmon;" ><span class="txtu">ἔλεος </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127508">frame•</span>
# <span
#     ef="frame"
#     nd="127508"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A1</span>
# </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὑμῖν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127509">frame•</span>
# <span
#     ef="frame"
#     nd="127509"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A2</span>
# </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">εἰρήνη </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127511">frame•</span>
# <span
#     ef="frame"
#     nd="127511"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A1</span>
# </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀγάπη </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127513">frame•</span>
# <span
#     ef="frame"
#     nd="127513"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A1</span>
# </span></div></div><div class="contnr c0 trm   hl"  style="background-color: cyan;" ><div class="lbl c0 trm hl"  style="background-color: cyan;" ><span class="txtu">πληθυνθείη.</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127514">frame•</span>
# <span
#     ef="frame"
#     nd="127514"
#     md="127508"
#     arrow="right"
#     class="etf"
# >A1<span class="etfx">↦</span></span>
#
# <span
#     ef="frame"
#     nd="127514"
#     md="127509"
#     arrow="right"
#     class="etf"
# >A2<span class="etfx">↦</span></span>
#
# <span
#     ef="frame"
#     nd="127514"
#     md="127511"
#     arrow="right"
#     class="etf"
# >A1<span class="etfx">↦</span></span>
#
# <span
#     ef="frame"
#     nd="127514"
#     md="127513"
#     arrow="right"
#     class="etf"
# >A1<span class="etfx">↦</span></span>
# </span><span class="framespec xft" ><span class="f">framespec=</span>A2:n65001002002 A1:n65001002001;n65001002004;n65001002006</span></div></div></div></div></div></div></div>
# <p><b>result</b> <i>4</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Jude/1/1&amp;version=0.5.1" title="Show this on the website" sec="Jude">Jude</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">Jude</span></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Jude/1/2&amp;version=0.5.1" title="Show this on the website" sec="Jude@1:2">Jude@1:2</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἔλεος </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127508">frame•</span>
# <span
#     ef="frame"
#     nd="127508"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A1</span>
# </span></div></div><div class="contnr c0 trm   hl"  style="background-color: salmon;" ><div class="lbl c0 trm hl"  style="background-color: salmon;" ><span class="txtu">ὑμῖν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127509">frame•</span>
# <span
#     ef="frame"
#     nd="127509"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A2</span>
# </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">εἰρήνη </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127511">frame•</span>
# <span
#     ef="frame"
#     nd="127511"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A1</span>
# </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀγάπη </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127513">frame•</span>
# <span
#     ef="frame"
#     nd="127513"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A1</span>
# </span></div></div><div class="contnr c0 trm   hl"  style="background-color: cyan;" ><div class="lbl c0 trm hl"  style="background-color: cyan;" ><span class="txtu">πληθυνθείη.</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127514">frame•</span>
# <span
#     ef="frame"
#     nd="127514"
#     md="127508"
#     arrow="right"
#     class="etf"
# >A1<span class="etfx">↦</span></span>
#
# <span
#     ef="frame"
#     nd="127514"
#     md="127509"
#     arrow="right"
#     class="etf"
# >A2<span class="etfx">↦</span></span>
#
# <span
#     ef="frame"
#     nd="127514"
#     md="127511"
#     arrow="right"
#     class="etf"
# >A1<span class="etfx">↦</span></span>
#
# <span
#     ef="frame"
#     nd="127514"
#     md="127513"
#     arrow="right"
#     class="etf"
# >A1<span class="etfx">↦</span></span>
# </span><span class="framespec xft" ><span class="f">framespec=</span>A2:n65001002002 A1:n65001002001;n65001002004;n65001002006</span></div></div></div></div></div></div></div>
# <p><b>result</b> <i>5</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Jude/1/1&amp;version=0.5.1" title="Show this on the website" sec="Jude">Jude</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">Jude</span></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Jude/1/2&amp;version=0.5.1" title="Show this on the website" sec="Jude@1:2">Jude@1:2</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἔλεος </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127508">frame•</span>
# <span
#     ef="frame"
#     nd="127508"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A1</span>
# </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὑμῖν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127509">frame•</span>
# <span
#     ef="frame"
#     nd="127509"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A2</span>
# </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div><div class="contnr c0 trm   hl"  style="background-color: salmon;" ><div class="lbl c0 trm hl"  style="background-color: salmon;" ><span class="txtu">εἰρήνη </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127511">frame•</span>
# <span
#     ef="frame"
#     nd="127511"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A1</span>
# </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀγάπη </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127513">frame•</span>
# <span
#     ef="frame"
#     nd="127513"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A1</span>
# </span></div></div><div class="contnr c0 trm   hl"  style="background-color: cyan;" ><div class="lbl c0 trm hl"  style="background-color: cyan;" ><span class="txtu">πληθυνθείη.</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127514">frame•</span>
# <span
#     ef="frame"
#     nd="127514"
#     md="127508"
#     arrow="right"
#     class="etf"
# >A1<span class="etfx">↦</span></span>
#
# <span
#     ef="frame"
#     nd="127514"
#     md="127509"
#     arrow="right"
#     class="etf"
# >A2<span class="etfx">↦</span></span>
#
# <span
#     ef="frame"
#     nd="127514"
#     md="127511"
#     arrow="right"
#     class="etf"
# >A1<span class="etfx">↦</span></span>
#
# <span
#     ef="frame"
#     nd="127514"
#     md="127513"
#     arrow="right"
#     class="etf"
# >A1<span class="etfx">↦</span></span>
# </span><span class="framespec xft" ><span class="f">framespec=</span>A2:n65001002002 A1:n65001002001;n65001002004;n65001002006</span></div></div></div></div></div></div></div>
# <p><b>result</b> <i>6</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Jude/1/1&amp;version=0.5.1" title="Show this on the website" sec="Jude">Jude</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">Jude</span></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Jude/1/2&amp;version=0.5.1" title="Show this on the website" sec="Jude@1:2">Jude@1:2</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἔλεος </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127508">frame•</span>
# <span
#     ef="frame"
#     nd="127508"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A1</span>
# </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὑμῖν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127509">frame•</span>
# <span
#     ef="frame"
#     nd="127509"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A2</span>
# </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">εἰρήνη </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127511">frame•</span>
# <span
#     ef="frame"
#     nd="127511"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A1</span>
# </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div><div class="contnr c0 trm   hl"  style="background-color: salmon;" ><div class="lbl c0 trm hl"  style="background-color: salmon;" ><span class="txtu">ἀγάπη </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127513">frame•</span>
# <span
#     ef="frame"
#     nd="127513"
#     md="127514"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A1</span>
# </span></div></div><div class="contnr c0 trm   hl"  style="background-color: cyan;" ><div class="lbl c0 trm hl"  style="background-color: cyan;" ><span class="txtu">πληθυνθείη.</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="frame xft" ><span class="e" edge="frame" nd="127514">frame•</span>
# <span
#     ef="frame"
#     nd="127514"
#     md="127508"
#     arrow="right"
#     class="etf"
# >A1<span class="etfx">↦</span></span>
#
# <span
#     ef="frame"
#     nd="127514"
#     md="127509"
#     arrow="right"
#     class="etf"
# >A2<span class="etfx">↦</span></span>
#
# <span
#     ef="frame"
#     nd="127514"
#     md="127511"
#     arrow="right"
#     class="etf"
# >A1<span class="etfx">↦</span></span>
#
# <span
#     ef="frame"
#     nd="127514"
#     md="127513"
#     arrow="right"
#     class="etf"
# >A1<span class="etfx">↦</span></span>
# </span><span class="framespec xft" ><span class="f">framespec=</span>A2:n65001002002 A1:n65001002001;n65001002004;n65001002006</span></div></div></div></div></div></div></div>

# %% [markdown]
# With hand coding we can get a better display:

# %%
colors = dict(A1="salmon", A2="goldenrod", self="cyan")
highlights = {}

self = frames[2][1]
parent = E.parent.f(self)[0]

highlights[self] = colors["self"]

for (arg, label) in E.frame.f(self):
    highlights[arg] = colors[label]
    
A.pretty(parent, highlights=highlights, queryFeatures=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15624\3147794282.py in <module>
#       2 highlights = {}
#       3
# ----> 4 self = frames[2][1]
#       5 parent = E.parent.f(self)[0]
#       6
#
# NameError: name 'frames' is not defined

# %%
results='''
clause typ* rela* num*
    phrase role* function* typ*
        word book=John chapter=1 verse=1
'''
results=A.search(results)
A.show(results, start=1, end=1, multiFeatures=False, queryFeatures=True)
# Out:
#   1.50s 17 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/John/1/1&amp;version=0.5.1" title="Show this on the website" sec="John@1:1">John@1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="verse xft" ><span class="f">verse=</span>1</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1</span></div><div class="children hor wrap "><div class="contnr c2    hl" ><div class="lbl c2  hl" ><span class="nd">clause </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1</span></div><div class="children hor wrap "><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Pred</span><span class="num xft" ><span class="f">num=</span>2</span><span class="role xft" ><span class="f">role=</span>p</span><span class="typ xft" ><span class="f">typ=</span>PP</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">Ἐν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="num xft" ><span class="f">num=</span>1</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>2</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀρχῇ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="num xft" ><span class="f">num=</span>2</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>3</span><span class="role xft" ><span class="f">role=</span>vc</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἦν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="num xft" ><span class="f">num=</span>3</span><span class="role xft" ><span class="f">role=</span>vc</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Subj</span><span class="num xft" ><span class="f">num=</span>4</span><span class="role xft" ><span class="f">role=</span>s</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase < ...

# %%
results='''
clause typ* rela* num*
    phrase role* function* typ*
        word book=Matthew chapter=6 verse=24
'''
results=A.search(results)
A.show(results, start=1, end=1, multiFeatures=False)
# Out:
#   1.48s 34 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Matthew/6/24&amp;version=0.5.1" title="Show this on the website" sec="Matthew@6:24">Matthew@6:24</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="verse xft" ><span class="f">verse=</span>24</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>160</span></div><div class="children hor wrap "><div class="contnr c2    hl" ><div class="lbl c2  hl" ><span class="nd">clause </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>620</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>2955</span></div><div class="children hor wrap "><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Subj</span><span class="num xft" ><span class="f">num=</span>2956</span><span class="role xft" ><span class="f">role=</span>s</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">Οὐδεὶς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="function xft" ><span class="f">function=</span>Subj</span><span class="num xft" ><span class="f">num=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="verse xft" ><span class="f">verse=</span>24</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Pred</span><span class="num xft" ><span class="f">num=</span>2957</span><span class="role xft" ><span class="f">role=</span>v</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δύναται </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="function xft" ><span class="f">function=</span>Pred</span><span class="num xft" ><span class="f">num=</span>2</span><span class="role xft" ><span class="f">role=</span>v</span><span class="verse xft" ><span class="f">verse=</span>24</span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>621</span><span class="role xft" ><span class="f">role=</span>o</span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>2955</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Objc</span><span class="num xft" ><span class="f">num=</span>2958</span><span class="role xft" ><span class="f">role=</span>o</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="num xft" ><span ...
