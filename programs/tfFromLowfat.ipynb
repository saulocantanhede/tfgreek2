# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Lowfat to TF - version 0.5.0 (updated version of Dirk Roorda's code v. 0.4.0)
#
# We use the machinery of Text-Fabric combined with some custom code to convert
# the lowfat XML of the Greek New Testament into TF.

# %% [markdown]
# # Set up
#
# We gather all prerequisites.

# %%
from tf.convert.xml import XML
from lowfat import convertTaskCustom
from tf.advanced.helpers import dm
from tf.app import use

# %% [markdown]
# The custom code is in `lowfat.py`, here in this directory.
#
# It consists of two functions that replace default functions in
# [xmlCustom](https://annotation.github.io/text-fabric/tf/convert/xmlCustom.html),
# which is part of TF.
#
# So you only have to focus on the bits that actually touch the lowfat XML.
#
# We pass the function `convertCustomTask()`, defined in `lowfat.py`, to the XML converter.
#
# We also specify the way we want to see some attributes in the report files:
#
# * keyword attributes: we want to see an inventory of all words that occur in such attributes
# * trim attributes: we do not want to see the values of these attributes

# %%
keywordAtts = set(
    """
    case
    class
    number
    gender
    mood
    person
    role
    tense
    type
    voice
""".strip().split()
)

trimAtts = set(
    """
    domain
    frame
    gloss
    id
    lemma
    ln
    morph
    normalized
    ref
    referent
    rule
    strong
    subjref
    unicode
""".strip().split()
)

# %% [markdown]
# We do not want both the `Rule` and `rule` features in our dataset, because this can clash on file systems
# that are case insensitive.
#
# We translate the `frame` attribute to an edge feature, but we retain the original contents in the
# `framespec` attribute.
#
# The name `class` is exceptionally cumbersome if you want to use it inside Python code,
# so we rename it to `cls`.
#
# Also, considering a friendly query, we switch the _label_ of node type from `w` to `word`.

# %%
renameAtts = {
    "Rule": "crule",
    "frame": "framespec",
    "subjref": "subjrefspec",
    "class": "cls",
}

# %%
X = XML(
    convertTaskCustom=convertTaskCustom,
    keywordAtts=keywordAtts,
    trimAtts=trimAtts,
    renameAtts=renameAtts,
    verbose=1,
    xml=0,
    tf="0.5.0",
)
# Out:
# Working in repository XML-nestle1904/programs in backend Downloads
# XML data version is 2022-11-01 (most recent)
# TF data version is 0.5.0 (explicit existing)
# Processing instructions will be ignored

# %% [markdown]
# # Check
#
# First we check the input:

# %%
X.task(check=True)
# Out:
# XML to TF checking: ~/Downloads/XML-nestle1904/programs/xml/2022-11-01 => ~/Downloads/XML-nestle1904/programs/report/2022-11-01
# Processing instructions are ignored
# Start folder gnt:
#   27 27-revelation.xml
# End   folder gnt
#
# 151 info line(s) written to ~/Downloads/XML-nestle1904/programs/report/2022-11-01/elements.txt
# 0 error(s) in 0 file(s) written to ~/Downloads/XML-nestle1904/programs/report/2022-11-01/errors.txt
# 7 tags of which 0 with multiple namespaces written to ~/Downloads/XML-nestle1904/programs/report/2022-11-01/namespaces.txt
# True

# %% [markdown]
# # Convert, Load, and App Creation
#
# Here we generate, check to see that the TF is valid is to load, and create the config file that turns the dataset into a TF app.

# %%
X.task(convert=True)
X.task(load=True)
X.task(app=True)
# Out:
# XML to TF converting: ~/Downloads/XML-nestle1904/programs/xml/2022-11-01 => ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#   0.00s Not all of the warp features otype and oslots are present in
# ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#   0.00s Only the Feature and Edge APIs will be enabled
#   0.01s Warp feature "otext" not found. Working without Text-API
#
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s No structure nodes will be set up
#    |   SECTION   TYPES:    book, chapter, verse
#    |   SECTION   FEATURES: book, chapter, verse
#    |   STRUCTURE TYPES:
#    |   STRUCTURE FEATURES:
#    |   TEXT      FEATURES:
#    |      |   text-orig-full       after, text
#    |     0.01s OK
#    |     0.00s Following director...
#   27 27-revelation.xml
# There are no broken subjref references.
# There are 9 broken frame references.
# gnt/01-matthew.xml            : n40003016026, n40004024030
# gnt/03-luke.xml               : n42001054008, n42001054011
# gnt/04-john.xml               : n43019024036
# gnt/07-1corinthians.xml       : n46012026017
# gnt/09-galatians.xml          : n48005007009
# gnt/10-ephesians.xml          : n49005014021, n49005019017
# source reading done
#    |       41s "delete" actions: 0
#    |       41s "edge" actions: 487491
#    |       41s "feature" actions: 471456
#    |       41s "node" actions: 341688
#    |       41s "resume" actions: 0
#    |       41s "slot" actions: 137779
#    |       41s "terminate" actions: 479467
#    |         27 x "book" node
#    |        260 x "chapter" node
#    |      30152 x "clause" node
#    |     107570 x "phrase" node
#    |       8011 x "sentence" node
#    |      72845 x "subphrase" node
#    |       7944 x "verse" node
#    |     114879 x "wg" node
#    |     137779 x "word" node  = slot type
#    |     479467 nodes of all types
#    |       41s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.49s OK
#    |     0.00s checking (section) features ...
#    |     3.21s OK
#    |     0.00s reordering nodes ...
#    |     0.00s Sorting 137779 slots (node type "word")
#    |     2.17s Sorting 27 nodes of type "book"
#    |     2.20s Sorting 260 nodes of type "chapter"
#    |     2.21s Sorting 30152 nodes of type "clause"
#    |     2.34s Sorting 107570 nodes of type "phrase"
#    |     3.25s Sorting 8011 nodes of type "sentence"
#    |     3.29s Sorting 72845 nodes of type "subphrase"
#    |     3.56s Sorting 7944 nodes of type "verse"
#    |     3.61s Sorting 114879 nodes of type "wg"
#    |     3.98s Max node = 479467
#    |     4.00s OK
#    |     0.00s reassigning feature values ...
#    |      |   node feature "after" with 275558 nodes
#    |      |   node feature "appositioncontainer" with 1908 nodes
#    |      |   node feature "articular" with 53093 nodes
#    |      |   node feature "book" with 145750 nodes
#    |      |   node feature "book_short" with 137806 nodes
#    |      |   node feature "case" with 159036 nodes
#    |      |   node feature "chapter" with 145983 nodes
#    |      |   node feature "clauseType" with 9990 nodes
#    |      |   node feature "cls" with 421134 nodes
#    |      |   node feature "cltype" with 4854 nodes
#    |      |   node feature "crule" with 10530 nodes
#    |      |   node feature "degree" with 1026 nodes
#    |      |   node feature "discontinuous" with 12068 nodes
#    |      |   node feature "domain" with 253758 nodes
#    |      |   node feature "framespec" with 50986 nodes
#    |      |   node feature "function" with 47752 nodes
#    |      |   node feature "gender" with 147950 nodes
#    |      |   node feature "gloss" with 275558 nodes
#    |      |   node feature "id" with 275558 nodes
#    |      |   node feature "junction" with 33327 nodes
#    |      |   node feature "lang" with 27 nodes
#    |      |   node feature "lemma" with 275558 nodes
#    |      |   node feature "ln" with 253758 nodes
#    |      |   node feature "mood" with 56714 nodes
#    |      |   node feature "morph" with 275558 nodes
#    |      |   node feature "nodeId" with 10530 nodes
#    |      |   node feature "normalized" with 275558 nodes
#    |      |   node feature "note" with 2 nodes
#    |      |   node feature "num" with 429172 nodes
#    |      |   node feature "number" with 197874 nodes
#    |      |   node feature "person" with 38838 nodes
#    |      |   node feature "ref" with 275558 nodes
#    |      |   node feature "referent" with 28942 nodes
#    |      |   node feature "rela" with 1590 nodes
#    |      |   node feature "role" with 159971 nodes
#    |      |   node feature "rule" with 161050 nodes
#    |      |   node feature "strong" with 275558 nodes
#    |      |   node feature "subjrefspec" with 33150 nodes
#    |      |   node feature "tense" with 56714 nodes
#    |      |   node feature "text" with 275558 nodes
#    |      |   node feature "typ" with 85242 nodes
#    |      |   node feature "type" with 200247 nodes
#    |      |   node feature "unicode" with 275558 nodes
#    |      |   node feature "verse" with 145723 nodes
#    |      |   node feature "voice" with 56714 nodes
#    |      |   edge feature "frame" with 25491 start nodes
#    |      |   edge feature "parent" with 252657 start nodes
#    |      |   edge feature "sibling" with 129767 start nodes
#    |      |   edge feature "subjref" with 16575 start nodes
#    |     6.48s OK
#     56s Features ready to write
#   0.00s Exporting 46 node and 5 edge and 1 config features to ~/Downloads/XML-nestle1904/programs/tf/0.5.0:
#   0.00s VALIDATING oslots feature
#   0.09s VALIDATING oslots feature
#   0.09s maxSlot=     137779
#   0.09s maxNode=     479467
#   0.19s OK: oslots is valid
#    |     0.85s T after                to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.00s T appositioncontainer  to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.14s T articular            to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.45s T book                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.42s T book_short           to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.55s T case                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.45s T chapter              to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.03s T clauseType           to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     1.37s T cls                  to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.01s T cltype               to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.04s T crule                to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.00s T degree               to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.02s T discontinuous        to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.82s T domain               to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.21s T framespec            to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.14s T function             to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.52s T gender               to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.91s T gloss                to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.88s T id                   to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.09s T junction             to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.02s T lang                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     1.05s T lemma                to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.79s T ln                   to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.22s T mood                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.91s T morph                to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.04s T nodeId               to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     1.02s T normalized           to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.00s T note                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     1.36s T num                  to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.67s T number               to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.29s T otype                to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.10s T person               to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.94s T ref                  to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.14s T referent             to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.02s T rela                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.64s T role                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.63s T rule                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.82s T strong               to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.11s T subjrefspec          to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.24s T tense                to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     1.07s T text                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.30s T typ                  to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.70s T type                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.97s T unicode              to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.35s T verse                to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.20s T voice                to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.36s T frame                to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     2.24s T oslots               to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     1.41s T parent               to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     1.43s T sibling              to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.11s T subjref              to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     0.00s M otext                to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#     27s Exported 46 node features and 5 edge features and 1 config features to ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     2.25s T otype                from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |       20s T oslots               from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     1.63s T book                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     4.42s T text                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     4.12s T after                from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     1.80s T verse                from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |     1.87s T chapter              from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.58s C __levels__           from otype, oslots, otext
#    |      |       11s C __order__            from otype, oslots, __levels__
#    |      |     0.49s C __rank__             from otype, __order__
#    |      |       40s C __levUp__            from otype, oslots, __rank__
#    |      |       21s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.33s C __characters__       from otext
#    |      |     6.83s C __boundary__         from otype, oslots, __rank__
#    |      |     0.14s C __sections__         from otype, oslots, otext, __levUp__, __levels__, book, chapter, verse
#    |      |     0.02s T appositioncontainer  from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.71s T articular            from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     1.90s T book_short           from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     2.37s T case                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.15s T clauseType           from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     6.18s T cls                  from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.07s T cltype               from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.18s T crule                from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.02s T degree               from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.15s T discontinuous        from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     3.92s T domain               from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     1.26s T frame                from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.98s T framespec            from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.75s T function             from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     2.21s T gender               from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     4.27s T gloss                from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     4.71s T id                   from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.52s T junction             from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.01s T lang                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     4.33s T lemma                from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     3.89s T ln                   from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.90s T mood                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     4.09s T morph                from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.17s T nodeId               from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     4.43s T normalized           from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.00s T note                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     5.60s T num                  from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     2.91s T number               from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     6.23s T parent               from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.61s T person               from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     4.95s T ref                  from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.54s T referent             from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.02s T rela                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     2.39s T role                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     2.48s T rule                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     4.90s T sibling              from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     3.64s T strong               from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.42s T subjref              from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.63s T subjrefspec          from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.90s T tense                from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     1.30s T typ                  from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     3.01s T type                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     4.25s T unicode              from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
#    |      |     0.88s T voice                from ~/Downloads/XML-nestle1904/programs/tf/0.5.0
# max node = 479467
# App updating ...
# 	~/Downloads/XML-nestle1904/programs/app/static/logo.png (already exists, not overwritten)
# 	~/Downloads/XML-nestle1904/programs/app/static/display.css (no custom info, older orginal exists)
# 	~/Downloads/XML-nestle1904/programs/app/config.yaml (no custom info, older orginal exists)
# 	~/Downloads/XML-nestle1904/programs/app/app.py (deleted)
# Done
# True

# %% [markdown]
# # Test
#
# We test a bit of the resulting dataset right here.

# %%
A = use("app:~/Downloads/XML-nestle1904/programs/app", version="0.5.0", hoist=globals())
B = use("etcbc/nestle1904", hoist=globals())
#C = use("saulocantanhede/tfgreek2/programs", version="0.5.0", hoist=globals())
# Out:
# **Locating corpus resources ...**
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.5.1</a>, <a target="_blank" href="https://github.com///blob/main/app" title="app:~/Downloads/XML-nestle1904/programs/app app">//app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> C:/Users/TF/Downloads/XML-nestle1904/programs/tf/0.5.0, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>27</td>
#     <td>5102.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>260</td>
#     <td>529.92</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>7944</td>
#     <td>17.34</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>8011</td>
#     <td>17.20</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>wg</th>
#     <td>114879</td>
#     <td>7.60</td>
#     <td><i>633</i></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>30152</td>
#     <td>7.37</td>
#     <td><i>161</i></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>107570</td>
#     <td>1.88</td>
#     <td><i>147</i></td>
# </tr>
#
# <tr>
#     <th>subphrase</th>
#     <td>72845</td>
#     <td>1.00</td>
#     <td>53</td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>137779</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>C:/Users/TF/Downloads/XML-nestle1904/programs/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/after.tf">after</span>
# </div>
# <div class="fmono">str</div>
#
# <span> material after the end of the word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/appositioncontainer.tf">appositioncontainer</span>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if it is an apposition container</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/articular.tf">articular</span>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the wg has an article</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/book.tf">book</span>
# </div>
# <div class="fmono">str</div>
#
# <span> book name (abbreviated), from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/book_short.tf">book_short</span>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute book_short</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/case.tf">case</span>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/chapter.tf">chapter</span>
# </div>
# <div class="fmono">int</div>
#
# <span> chapter number, from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/clauseType.tf">clauseType</span>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/cls.tf">cls</span>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute cls</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/cltype.tf">cltype</span>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/crule.tf">crule</span>
# </div>
# <div class="fmono">str</div>
#
# <span> clause rule (from xml attribute Rule)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/degree.tf">degree</span>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical degree</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/discontinuous.tf">discontinuous</span>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the word is out of sequence in the xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/domain.tf">domain</span>
# </div>
# <div class="fmono">str</div>
#
# <span> domain</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/framespec.tf">framespec</span>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute framespec</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/function.tf">function</span>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute function</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/gender.tf">gender</span>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/gloss.tf">gloss</span>
# </div>
# <div class="fmono">str</div>
#
# <span> short translation</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/id.tf">id</span>
# </div>
# <div class="fmono">str</div>
#
# <span> xml id</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/junction.tf">junction</span>
# </div>
# <div class="fmono">str</div>
#
# <span> type of junction</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/lang.tf">lang</span>
# </div>
# <div class="fmono">str</div>
#
# <span> language the text is in</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/lemma.tf">lemma</span>
# </div>
# <div class="fmono">str</div>
#
# <span> lexical lemma</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/ln.tf">ln</span>
# </div>
# <div class="fmono">str</div>
#
# <span> ln</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/mood.tf">mood</span>
# </div>
# <div class="fmono">str</div>
#
# <span> verbal mood</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/morph.tf">morph</span>
# </div>
# <div class="fmono">str</div>
#
# <span> morphological code</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/nodeId.tf">nodeId</span>
# </div>
# <div class="fmono">int</div>
#
# <span> node id (as in the XML source data</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/normalized.tf">normalized</span>
# </div>
# <div class="fmono">str</div>
#
# <span> lemma normalized</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.0/note.tf">note</span>
# </div>
# <div class="fmono">str</div>
#
# <span> annotation of linguistic nature</span>
#
# </div>
#
# <d
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--borde
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# **Locating corpus resources ...**
# <b title="local release">app:</b> <span title="rv0.4.0=#g61756f28da3d0fdf8053448afbccb9b20607c60c offline under C:/Users/TF/text-fabric-data/github">~/text-fabric-data/github/etcbc/nestle1904/app</span>
# <b title="local release">data:</b> <span title="rv0.4.0=#g61756f28da3d0fdf8053448afbccb9b20607c60c offline under C:/Users/TF/text-fabric-data/github">~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.5.1</a>, <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/app" title="etcbc/nestle1904 app">etcbc/nestle1904/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/about.md" title="provenance of etcbc - nestle1904/tf">etcbc - nestle1904 0.4.0</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/greek.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="etcbc - nestle1904 feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>27</td>
#     <td>5102.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>260</td>
#     <td>529.92</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>7944</td>
#     <td>17.34</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>8011</td>
#     <td>17.20</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>wg</th>
#     <td>114879</td>
#     <td>7.60</td>
#     <td><i>633</i></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>30152</td>
#     <td>7.37</td>
#     <td><i>161</i></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>42636</td>
#     <td>3.21</td>
#     <td>99</td>
# </tr>
#
# <tr>
#     <th><i>w</i></th>
#     <td>137779</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>etcbc - nestle1904/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> material after the end of the word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/appositioncontainer.tf">appositioncontainer</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if it is an apposition container</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/articular.tf">articular</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the wg has an article</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> book name (abbreviated), from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/case.tf">case</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> chapter number, from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/clauseType.tf">clauseType</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/cls.tf">cls</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute cls</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/cltype.tf">cltype</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type for verbless, verb-elided, and minor clauses</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/crule.tf">crule</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause rule (from xml attribute Rule)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/degree.tf">degree</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical degree</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/discontinuous.tf">discontinuous</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the word is out of sequence in the xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/domain.tf">domain</a>
# </div>
# <div class="fmono">str</div>
#
# <span> domain</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/framespec.tf">framespec</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute framespec</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/gender.tf">gender</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/gloss.tf">gloss</a>
# </div>
# <div class="fmono">str</div>
#
# <span> short translation</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/id.tf">id</a>
# </div>
# <div class="fmono">str</div>
#
# <span> xml id</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/junction.tf">junction</a>
# </div>
# <div class="fmono">str</div>
#
# <span> type of junction</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/etcbc/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/etcbc/nestle1904/tf/0.4.0/lang.tf">lang</a>
# </div>
# <div class="fmono">str</div>
#
# <span> lang
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--borde
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>

# %% [markdown]
# ## Comparing queries between the BHSA and our results

# %%
results = B.search("""
book book=JUD
  w
  -sibling>3> w
""")
B.show(results, start=1, end=1, condensed=True, multiFeatures=False, hiddenTypes={"wg"})
# Out:
#   0.43s 2 results
# <p><b>sentence</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.etcbc.org/nestle1904/JUD/1/5&amp;version=0.4.0" title="Show this on the website" sec="JUD@1:5">JUD@1:5</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ὑπομνῆσαι </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>JUD</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127568">sibling•</span>
# <span
#     ef="sibling"
#     nd="127568"
#     md="127570"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
# </span></div></div></div></div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">δὲ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>JUD</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127569">sibling•</span>
# <span
#     ef="sibling"
#     nd="127569"
#     md="332741"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
# </span></div></div><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ὑμᾶς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>JUD</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127570">sibling•</span>
# <span
#     ef="sibling"
#     nd="127570"
#     md="127568"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>1</span>
# </span></div></div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">βούλομαι,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>JUD</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127571">sibling•</span>
# <span
#     ef="sibling"
#     nd="127571"
#     md="332742"
#     arrow="right"
#     class="etf"
# >2<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="127571"
#     md="332744"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
# </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">εἰδότας </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>JUD</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127572">sibling•</span>
# <span
#     ef="sibling"
#     nd="127572"
#     md="127573"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="127572"
#     md="127574"
#     arrow="right"
#     class="etf"
# >2<span class="etfx">↦</span></span>
# </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἅπαξ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>JUD</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127573">sibling•</span>
# <span
#     ef="sibling"
#     nd="127573"
#     md="127572"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>1</span>
#
# <span
#     ef="sibling"
#     nd="127573"
#     md="127574"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
# </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">πάντα,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>JUD</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127574">sibling•</span>
# <span
#     ef="sibling"
#     nd="127574"
#     md="127572"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>2</span>
#
# <span
#     ef="sibling"
#     nd="127574"
#     md="127573"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>1</span>
# </span></div></div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ὅτι </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>JUD</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127575">sibling•</span>
# <span
#     ef="sibling"
#     nd="127575"
#     md="332746"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="127575"
#     md="332771"
#     arrow="right"
#     class="etf"
# >2<span class="etfx">↦</span></span>
# </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu grc">Κύριος </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>JUD</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127576">sibling•</span>
# <span
#     ef="sibling"
#     nd="127576"
#     md="332748"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="127576"
#     md="332751"
#     arrow="right"
#     class="etf"
# >2<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="127576"
#     md="332752"
#     arrow="right"
#     class="etf"
# >3<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="127576"
#     md="127587"
#     arrow="right"
#     class="etf"
# >4<span class="etfx">↦</span></span>
# </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">λαὸν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>JUD</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127577">sibling•</span>
# <span
#     ef="sibling"
#     nd="127577"
#     md="332749"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="127577"
#     md="127581"
#     arrow="right"
#     class="etf"
# >2<span class="etfx">↦</span></span>
# </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐκ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>JUD</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127578">sibling•</span>
# <span
#     ef="sibling"
#     nd="127578"
#     md="332750"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
# </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">γῆς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>JUD</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127579">sibling•</span>
# <span
#     ef="sibling"
#     nd="127579"
#     md="127580"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
# </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Αἰγύπτου </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>JUD</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127580">sibling•</span>
# <span
#     ef="sibling"
#     nd="127580"
#     md="127579"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</s

# %%
results = A.search("""
book book=Jude
  word
  -sibling>3> word
""")
A.show(results, start=1, end=1, condensed=True, multiFeatures=False, hiddenTypes={"wg"})
# Out:
#   0.20s 2 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Jude@1:5</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div><div class="children hor wrap "><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ὑπομνῆσαι </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127568">sibling•</span>
# <span
#     ef="sibling"
#     nd="127568"
#     md="127570"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
# </span></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127569">sibling•</span>
# <span
#     ef="sibling"
#     nd="127569"
#     md="470520"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1   l rno " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὑμᾶς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127570">sibling•</span>
# <span
#     ef="sibling"
#     nd="127570"
#     md="127568"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>1</span>
# </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">βούλομαι,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127571">sibling•</span>
# <span
#     ef="sibling"
#     nd="127571"
#     md="470521"
#     arrow="right"
#     class="etf"
# >2<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="127571"
#     md="470523"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">εἰδότας </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127572">sibling•</span>
# <span
#     ef="sibling"
#     nd="127572"
#     md="127573"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="127572"
#     md="127574"
#     arrow="right"
#     class="etf"
# >2<span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἅπαξ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127573">sibling•</span>
# <span
#     ef="sibling"
#     nd="127573"
#     md="127572"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>1</span>
#
# <span
#     ef="sibling"
#     nd="127573"
#     md="127574"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">πάντα,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127574">sibling•</span>
# <span
#     ef="sibling"
#     nd="127574"
#     md="127572"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>2</span>
#
# <span
#     ef="sibling"
#     nd="127574"
#     md="127573"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>1</span>
# </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὅτι </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127575">sibling•</span>
# <span
#     ef="sibling"
#     nd="127575"
#     md="470525"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="127575"
#     md="470550"
#     arrow="right"
#     class="etf"
# >2<span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">Κύριος </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127576">sibling•</span>
# <span
#     ef="sibling"
#     nd="127576"
#     md="470527"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="127576"
#     md="470530"
#     arrow="right"
#     class="etf"
# >2<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="127576"
#     md="470531"
#     arrow="right"
#     class="etf"
# >3<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="127576"
#     md="127587"
#     arrow="right"
#     class="etf"
# >4<span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">λαὸν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="sibling xft" ><span class="e" edge="sibling" nd="127577">sibling•</span>
# <span
#     ef="sibling"
#     nd="127577"
#     md="470528"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="127577"
#     md="127581"
#     arrow="right"
#     class="etf"
# >2<span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span

# %%
results = A.search('''
verse book=Matthew chapter=6 verse=24
    clause
        phrase typ* function* rela*
                word role*
''')
A.show(results, start=1, end=1, condensed=True, multiFeatures=False, hiddenTypes={"wg"})
# Out:
#   1.25s 28 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Matthew@6:24</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="verse xft" ><span class="f">verse=</span>24</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Subj</span><span class="role xft" ><span class="f">role=</span>s</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">Οὐδεὶς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="function xft" ><span class="f">function=</span>Subj</span><span class="role xft" ><span class="f">role=</span>s</span><span class="verse xft" ><span class="f">verse=</span>24</span></div></div></div></div><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>v</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">δύναται </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="role xft" ><span class="f">role=</span>v</span><span class="verse xft" ><span class="f">verse=</span>24</span></div></div></div></div><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>o</span></div><div class="children hor wrap "><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Objc</span><span class="role xft" ><span class="f">role=</span>o</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">δυσὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="verse xft" ><span class="f">verse=</span>24</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">κυρίοις </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="verse xft" ><span class="f">verse=</span>24</span></div></div></div></div></div></div><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>v</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">δουλεύειν·</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span ...

# %% [markdown]
# # Browse
#
# We are ready to browse the data.
# If you run this notebook, then the next cell will open a browser window with the TF-browser
# on the Greek New Testament.

# %%
X.task(browse=True)

# %% [markdown]
# # Terminate
#
# You can stop the browser by pressing `i` twice.

# %% [markdown]
# # Create zip
#
# It is time to commit and push the repo to GitHub now:
#
# ```
# git add --all .
# git commit "new data version"
# git push origin master
# ```
#
# Then go over to GitHub and create a new release there.
#
# After that, fetch the new tags from GitHub by
#
# ```
# git pull --tags
# ```
#
# Then we are ready to create a zip file for publishing the dataset in a release on Github,
# so that users can get it easily.

# %%
A.zipAll()
# Out:
# Data to be zipped:
# 	missing  app                      (??)                : ~/github/None/None/app
# 	missing  main data                (??)                : ~/github/None/None/tf/0.5.0

# %% [markdown]
# # Fetch
#
# We now test wether users can use this dataset in the normal way.
#
# Run this after you have attached the complete.zip file that we create earlier, to the latest release on GitHub.

# %%
A = use("ETCBC/nestle1904:latest")
# Out:
# **Locating corpus resources ...**
# Status: latest release online <b>v0.4.0</b> versus <b>v0.3.1</b> locally
# downloading app, main data and requested additions ...
# <b title="latest release">app:</b> <span title="rv0.3.1=#gd1847f53703ffeb01670e324cfe60d5cec41dd47">~/text-fabric-data/github/ETCBC/nestle1904/app</span>
# <b title="local release">data:</b> <span title="rv0.4.0=#g61756f28da3d0fdf8053448afbccb9b20607c60c offline under /Users/me/text-fabric-data/github">~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0</span>
#    |     0.17s T otype                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     2.36s T oslots               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.36s T text                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.28s T after                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.28s T book                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.24s T chapter              from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.26s T verse                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |      |     0.05s C __levels__           from otype, oslots, otext
#    |      |     1.47s C __order__            from otype, oslots, __levels__
#    |      |     0.06s C __rank__             from otype, __order__
#    |      |     4.38s C __levUp__            from otype, oslots, __rank__
#    |      |     2.38s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.04s C __characters__       from otext
#    |      |     0.88s C __boundary__         from otype, oslots, __rank__
#    |      |     0.02s C __sections__         from otype, oslots, otext, __levUp__, __levels__, book, chapter, verse
#    |     0.00s T appositioncontainer  from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.11s T articular            from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.18s T case                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.02s T clauseType           from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.61s T cls                  from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.01s T cltype               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.03s T crule                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.00s T degree               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.01s T discontinuous        from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.28s T domain               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.19s T frame                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.08s T framespec            from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.17s T gender               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.35s T gloss                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.38s T id                   from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.08s T junction             from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.00s T lang                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.33s T lemma                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.31s T ln                   from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.07s T mood                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.30s T morph                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.03s T nodeId               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.36s T normalized           from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.00s T note                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.27s T num                  from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.22s T number               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     1.10s T parent               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.05s T person               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.39s T ref                  from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.04s T referent             from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.26s T role                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.37s T rule                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.76s T sibling              from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.27s T strong               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.06s T subjref              from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.05s T subjrefspec          from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.07s T tense                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.36s T type                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.37s T unicode              from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.07s T voice                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.4.12</a>, <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/app" title="ETCBC/nestle1904 app">ETCBC/nestle1904/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/about.md" title="provenance of ETCBC - nestle1904/tf">ETCBC - nestle1904 0.4.0</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/greek.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="ETCBC - nestle1904 feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>27</td>
#     <td>5102.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>260</td>
#     <td>529.92</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>7944</td>
#     <td>17.34</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>8011</td>
#     <td>17.20</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>wg</th>
#     <td>114879</td>
#     <td>7.60</td>
#     <td><i>633</i></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>30152</td>
#     <td>7.37</td>
#     <td><i>161</i></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>42636</td>
#     <td>3.21</td>
#     <td>99</td>
# </tr>
#
# <tr>
#     <th><i>w</i></th>
#     <td>137779</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>ETCBC - nestle1904/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> material after the end of the word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/appositioncontainer.tf">appositioncontainer</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if it is an apposition container</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/articular.tf">articular</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the wg has an article</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> book name (abbreviated), from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/case.tf">case</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> chapter number, from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/clauseType.tf">clauseType</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/cls.tf">cls</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute cls</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/cltype.tf">cltype</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type for verbless, verb-elided, and minor clauses</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/crule.tf">crule</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause rule (from xml attribute Rule)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/degree.tf">degree</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical degree</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/discontinuous.tf">discontinuous</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the word is out of sequence in the xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/domain.tf">domain</a>
# </div>
# <div class="fmono">str</div>
#
# <span> domain</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/framespec.tf">framespec</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute framespec</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/gender.tf">gender</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/gloss.tf">gloss</a>
# </div>
# <div class="fmono">str</div>
#
# <span> short translation</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/id.tf">id</a>
# </div>
# <div class="fmono">str</div>
#
# <span> xml id</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/junction.tf">junction</a>
# </div>
# <div class="fmono">str</div>
#
# <span> type of junction</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/lang.tf">lang</a>
# </div>
# <div class="fmono">str</div>
#
# <span> lan
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>

# %% [markdown]
# Indeed, downloading and installing went without hassle.

# %% [markdown]
# # Demo
#
# We demo the effect of the reshuffling of the words.
#
# Our test corpus is the letter of Jude, first sentence, twice.
#
# The first time we do not shuffle the words in the sentence, the second time we do.
#
# We run the conversion with `demo = True` in `lowfat.py`.

# %%
X = XML(
    convertTaskCustom=convertTaskCustom,
    keywordAtts=keywordAtts,
    trimAtts=trimAtts,
    renameAtts=renameAtts,
    verbose=1,
    xml=-1,
    tf="0.3.1t",
)
# Out:
# Working in repository ETCBC/nestle1904 in backend github
# XML data version is 2000-01-01 (oldest)
# TF data version is 0.3.1t (explicit new)

# %%
X.task(convert=True, load=True, app=True)
# Out:
# XML to TF converting: ~/github/ETCBC/nestle1904/xml/2000-01-01 => ~/github/ETCBC/nestle1904/tf/0.3.1t
#   0.00s Not all of the warp features otype and oslots are present in
# ~/github/ETCBC/nestle1904/tf/0.3.1t
#   0.00s Only the Feature and Edge APIs will be enabled
#   0.00s Warp feature "otext" not found. Working without Text-API
#
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s No structure nodes will be set up
#    |   SECTION   TYPES:    book, chapter, verse
#    |   SECTION   FEATURES: book, chapter, verse
#    |   STRUCTURE TYPES:
#    |   STRUCTURE FEATURES:
#    |   TEXT      FEATURES:
#    |      |   text-orig-full       after, text
#    |     0.00s OK
#    |     0.00s Following director...
#    1 26-jude.xml
# source reading done
#    |     0.00s "edge" actions: 0
#    |     0.00s "feature" actions: 71
#    |     0.00s "node" actions: 39
#    |     0.00s "resume" actions: 0
#    |     0.00s "slot" actions: 34
#    |     0.00s "terminate" actions: 39
#    |          1 x "book" node
#    |          1 x "chapter" node
#    |          2 x "sentence" node
#    |          1 x "verse" node
#    |         34 x "w" node  = slot type
#    |         34 x "wg" node
#    |         73 nodes of all types
#    |     0.01s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.00s OK
#    |     0.00s checking (section) features ...
#    |     0.00s OK
#    |     0.00s reordering nodes ...
#    |     0.00s Sorting 34 slots (node type "w")
#    |     0.00s Sorting 1 nodes of type "book"
#    |     0.00s Sorting 1 nodes of type "chapter"
#    |     0.00s Sorting 2 nodes of type "sentence"
#    |     0.00s Sorting 1 nodes of type "verse"
#    |     0.00s Sorting 34 nodes of type "wg"
#    |     0.00s Max node = 73
#    |     0.00s OK
#    |     0.00s reassigning feature values ...
#    |      |   node feature "after" with 34 nodes
#    |      |   node feature "appositioncontainer" with 8 nodes
#    |      |   node feature "articular" with 2 nodes
#    |      |   node feature "book" with 35 nodes
#    |      |   node feature "case" with 28 nodes
#    |      |   node feature "chapter" with 35 nodes
#    |      |   node feature "class" with 50 nodes
#    |      |   node feature "clauseType" with 2 nodes
#    |      |   node feature "cltype" with 2 nodes
#    |      |   node feature "discontinuous" with 2 nodes
#    |      |   node feature "domain" with 28 nodes
#    |      |   node feature "frame" with 4 nodes
#    |      |   node feature "gender" with 28 nodes
#    |      |   node feature "gloss" with 34 nodes
#    |      |   node feature "junction" with 6 nodes
#    |      |   node feature "lang" with 1 node
#    |      |   node feature "lemma" with 34 nodes
#    |      |   node feature "ln" with 28 nodes
#    |      |   node feature "mood" with 4 nodes
#    |      |   node feature "morph" with 34 nodes
#    |      |   node feature "normalized" with 34 nodes
#    |      |   node feature "num" with 37 nodes
#    |      |   node feature "number" with 28 nodes
#    |      |   node feature "ref" with 34 nodes
#    |      |   node feature "role" with 14 nodes
#    |      |   node feature "rule" with 28 nodes
#    |      |   node feature "strong" with 34 nodes
#    |      |   node feature "subjref" with 4 nodes
#    |      |   node feature "tense" with 4 nodes
#    |      |   node feature "text" with 34 nodes
#    |      |   node feature "type" with 42 nodes
#    |      |   node feature "unicode" with 34 nodes
#    |      |   node feature "verse" with 35 nodes
#    |      |   node feature "voice" with 4 nodes
#    |     0.01s OK
#   0.02s Features ready to write
#   0.00s Exporting 35 node and 1 edge and 1 config features to ~/github/ETCBC/nestle1904/tf/0.3.1t:
#   0.00s VALIDATING oslots feature
#   0.00s VALIDATING oslots feature
#   0.00s maxSlot=         34
#   0.00s maxNode=         73
#   0.00s OK: oslots is valid
#    |     0.00s T after                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T appositioncontainer  to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T articular            to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T book                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T case                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T chapter              to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T class                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T clauseType           to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T cltype               to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T discontinuous        to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T domain               to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T frame                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T gender               to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T gloss                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T junction             to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T lang                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T lemma                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T ln                   to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T mood                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T morph                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T normalized           to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T num                  to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T number               to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T otype                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T ref                  to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T role                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T rule                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T strong               to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T subjref              to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T tense                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T text                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T type                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T unicode              to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T verse                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T voice                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T oslots               to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s M otext                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#   0.03s Exported 35 node features and 1 edge features and 1 config features to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T otype                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T oslots               from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T verse                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T after                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T book                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T text                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T chapter              from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s C __levels__           from otype, oslots, otext
#    |      |     0.00s C __order__            from otype, oslots, __levels__
#    |      |     0.00s C __rank__             from otype, __order__
#    |      |     0.00s C __levUp__            from otype, oslots, __rank__
#    |      |     0.00s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.00s C __characters__       from otext
#    |      |     0.00s C __boundary__         from otype, oslots, __rank__
#    |      |     0.00s C __sections__         from otype, oslots, otext, __levUp__, __levels__, book, chapter, verse
#    |      |     0.00s T appositioncontainer  from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T articular            from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T case                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T class                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T clauseType           from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T cltype               from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T discontinuous        from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T domain               from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T frame                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T gender               from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T gloss                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T junction             from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T lang                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T lemma                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T ln                   from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T mood                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T morph                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T normalized           from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T num                  from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T number               from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T ref                  from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T role                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T rule                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T strong               from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T subjref              from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T tense                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T type                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T unicode              from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T voice                from ~/github/ETCBC/nestle1904/tf/0.3.1t
# max node = 73
# App updating ...
# 	~/github/ETCBC/nestle1904/app/static/logo.png (already exists, not overwritten)
# 	~/github/ETCBC/nestle1904/app/static/display.css (no custom info, older orginal exists)
# 	~/github/ETCBC/nestle1904/app/config.yaml (generated with custom info)
# 	~/github/ETCBC/nestle1904/app/app.py (deleted)
# Done
# True

# %%
A = use("ETCBC/nestle1904:clone", checkout="clone", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/nestle1904/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/nestle1904/tf/0.3.1t</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.4.11</a>, <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/app" title="ETCBC/nestle1904 app">ETCBC/nestle1904/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/about.md" title="provenance of ETCBC - nestle1904/tf">ETCBC - nestle1904 0.3.1t</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/greek.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="ETCBC - nestle1904 feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>1</td>
#     <td>34.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>1</td>
#     <td>34.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>1</td>
#     <td>34.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>2</td>
#     <td>17.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>wg</th>
#     <td>34</td>
#     <td>6.00</td>
#     <td><i>600</i></td>
# </tr>
#
# <tr>
#     <th><i>w</i></th>
#     <td>34</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>ETCBC - nestle1904/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> material after the end of the word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/appositioncontainer.tf">appositioncontainer</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if it is an apposition container</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/articular.tf">articular</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the wg has an article</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> book name (abbreviated), from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/case.tf">case</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> chapter number, from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/class.tf">class</a>
# </div>
# <div class="fmono">str</div>
#
# <span> morphological class (on w); syntactical class (on wg)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/clauseType.tf">clauseType</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/cltype.tf">cltype</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/discontinuous.tf">discontinuous</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the word is out of sequence in the xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/domain.tf">domain</a>
# </div>
# <div class="fmono">str</div>
#
# <span> domain</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/frame.tf">frame</a>
# </div>
# <div class="fmono">str</div>
#
# <span> frame</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/gender.tf">gender</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/gloss.tf">gloss</a>
# </div>
# <div class="fmono">str</div>
#
# <span> short translation</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/junction.tf">junction</a>
# </div>
# <div class="fmono">str</div>
#
# <span> type of junction</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/lang.tf">lang</a>
# </div>
# <div class="fmono">str</div>
#
# <span> language the text is in</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/lemma.tf">lemma</a>
# </div>
# <div class="fmono">str</div>
#
# <span> lexical lemma</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/ln.tf">ln</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ln</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/mood.tf">mood</a>
# </div>
# <div class="fmono">str</div>
#
# <span> verbal mood</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/morph.tf">morph</a>
# </div>
# <div class="fmono">str</div>
#
# <span> morphological code</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/normalized.tf">normalized</a>
# </div>
# <div class="fmono">str</div>
#
# <span> lemma nor
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF</a> directly usable</div><hr>

# %%
(s1, s2) = F.otype.s("sentence")

# %%
color1 = "cyan"
color2 = "goldenrod"
start = 5
offset = 17
highlights = {
    start: color1,
    start + 1: color2,
    start + offset: color2,
    start + offset + 1: color1,
}
A.displaySetup(standardFeatures=True, highlights=highlights)

# %%
A.pretty(s1)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.ETCBC.org/nestle1904/JUD/1/1&amp;version=0.3.1t" title="Show this on the website" sec="JUD@1:1">JUD@1:1</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰούδας </span></div><div class="features"><span class="num " title="num">1</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰησοῦ </span></div><div class="features"><span class="num " title="num">2</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Χριστοῦ </span></div><div class="features"><span class="num " title="num">3</span></div></div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">δοῦλος,</span></div><div class="features"><span class="num " title="num">4</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: cyan;" ><div class="lbl c0 trm hl"  style="background-color: cyan;" ><span class="txtu grc">δὲ </span></div><div class="features"><span class="num " title="num">6</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: goldenrod;" ><div class="lbl c0 trm hl"  style="background-color: goldenrod;" ><span class="txtu grc">ἀδελφὸς </span></div><div class="features"><span class="num " title="num">5</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰακώβου,</span></div><div class="features"><span class="num " title="num">7</span></div></div></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τοῖς </span></div><div class="features"><span class="num " title="num">8</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐν </span></div><div class="features"><span class="num " title="num">9</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Θεῷ </span></div><div class="features"><span class="num " title="num">10</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Πατρὶ < ...

# %%
A.pretty(s2)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.ETCBC.org/nestle1904/JUD/1/1&amp;version=0.3.1t" title="Show this on the website" sec="JUD@1:1">JUD@1:1</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰούδας </span></div><div class="features"><span class="num " title="num">1</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰησοῦ </span></div><div class="features"><span class="num " title="num">2</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Χριστοῦ </span></div><div class="features"><span class="num " title="num">3</span></div></div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">δοῦλος,</span></div><div class="features"><span class="num " title="num">4</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: goldenrod;" ><div class="lbl c0 trm hl"  style="background-color: goldenrod;" ><span class="txtu grc">ἀδελφὸς </span></div><div class="features"><span class="num " title="num">5</span></div></div></div></div><div class="contnr c0 trm   hl"  style="background-color: cyan;" ><div class="lbl c0 trm hl"  style="background-color: cyan;" ><span class="txtu grc">δὲ </span></div><div class="features"><span class="num " title="num">6</span></div></div><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰακώβου,</span></div><div class="features"><span class="num " title="num">7</span></div></div></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τοῖς </span></div><div class="features"><span class="num " title="num">8</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐν </span></div><div class="features"><span class="num " title="num">9</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Θεῷ </span></div><div class="features"><span cla ...

# %% [markdown]
# # Restore
#
# We restore the app so that it uses the normal tf version again.

# %%
X = XML(
    convertTaskCustom=convertTaskCustom,
    keywordAtts=keywordAtts,
    trimAtts=trimAtts,
    renameAtts=renameAtts,
    verbose=1,
    tf="0.3.1",
)
# Out:
# Working in repository ETCBC/nestle1904 in backend github
# XML data version is 2022-11-01 (most recent)
# TF data version is 0.3.1 (explicit existing)

# %%
X.task(app=True)
# Out:
# App updating ...
# 	~/github/ETCBC/nestle1904/app/static/logo.png (already exists, not overwritten)
# 	~/github/ETCBC/nestle1904/app/static/display.css (no custom info, older orginal exists)
# 	~/github/ETCBC/nestle1904/app/config.yaml (generated with custom info)
# 	~/github/ETCBC/nestle1904/app/app.py (deleted)
# Done
# True

# %% [markdown]
# Now save this notebook, commit and push the repo again to publish this very notebook.
#
# ```
# git add --all .
# git commit "maker notebook updated"
# git push origin master
# ```
