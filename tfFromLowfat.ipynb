# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Lowfat to TF - version 0.5.1 (updated version of Dirk Roorda's code v. 0.4.0)
#
# We use the machinery of Text-Fabric combined with some custom code to convert
# the lowfat XML of the Greek New Testament into TF.

# %% [markdown]
# # Set up
#
# We gather all prerequisites.

# %%
from tf.convert.xml import XML
from lowfat import convertTaskCustom
from tf.advanced.helpers import dm
from tf.app import use
color = {2: "#1be7ff", 3: "#6eeb83", 4: "#e4ff1a", 5: "ffb800", 6: "ff5714"}

# %% [markdown]
# The custom code is in `lowfat.py`, here in this directory.
#
# It consists of two functions that replace default functions in
# [xmlCustom](https://annotation.github.io/text-fabric/tf/convert/xmlCustom.html),
# which is part of TF.
#
# So you only have to focus on the bits that actually touch the lowfat XML.
#
# We pass the function `convertCustomTask()`, defined in `lowfat.py`, to the XML converter.
#
# We also specify the way we want to see some attributes in the report files:
#
# * keyword attributes: we want to see an inventory of all words that occur in such attributes
# * trim attributes: we do not want to see the values of these attributes

# %%
keywordAtts = set(
    """
    case
    class
    number
    gender
    mood
    person
    role
    tense
    type
    voice
    degree
    articular
""".strip().split()
)

trimAtts = set(
    """
    domain
    frame
    gloss
    id
    lemma
    ln
    morph
    normalized
    ref
    referent
    rule
    strong
    subjref
    unicode
""".strip().split()
)

# %% [markdown]
# We do not want both the `Rule` and `rule` features in our dataset, because this can clash on file systems
# that are case insensitive.
#
# We translate the `frame` and `subjrefspec` attributes to edge features, but we retain the original contents in the
# `framespec` and `subjref` attributes.
#
# The name `class` is exceptionally cumbersome if you want to use it inside Python code,
# so we rename it to `cls`.
#
# Also, considering a friendly query, we switch the _label_ of node type from `w` to `word`.

# %%
renameAtts = {
    "Rule": "crule",
    "frame": "framespec",
    "subjref": "subjrefspec",
    "class": "cls",
}

# %%
X = XML(
    convertTaskCustom=convertTaskCustom,
    keywordAtts=keywordAtts,
    trimAtts=trimAtts,
    renameAtts=renameAtts,
    verbose=1,
    xml=0,
    tf="0.5.1",
)
# Out:
# Working in repository XML-nestle1904/programs in backend Downloads
# XML data version is 2022-11-01 (most recent)
# TF data version is 0.5.1 (explicit existing)
# Processing instructions will be ignored

# %%
X = XML(
    convertTaskCustom=convertTaskCustom,
    keywordAtts=keywordAtts,
    trimAtts=trimAtts,
    renameAtts=renameAtts,
    verbose=1,
    xml="2000-01-01",
    tf="0.5.1",
)
# Out:
# Working in repository XML-nestle1904/programs in backend Downloads
# XML data version is 2000-01-01 (oldest)
# TF data version is 0.5.1 (explicit existing)
# Processing instructions will be ignored

# %% [markdown]
# # Check
#
# First we check the input:

# %%
X.task(check=True)
# Out:
# XML to TF checking: ~/Downloads/XML-nestle1904/programs/xml/2022-11-01 => ~/Downloads/XML-nestle1904/programs/report/2022-11-01
# Processing instructions are ignored
# Start folder gnt:
#   27 27-revelation.xml
# End   folder gnt
#
# 151 info line(s) written to ~/Downloads/XML-nestle1904/programs/report/2022-11-01/elements.txt
# 0 error(s) in 0 file(s) written to ~/Downloads/XML-nestle1904/programs/report/2022-11-01/errors.txt
# 7 tags of which 0 with multiple namespaces written to ~/Downloads/XML-nestle1904/programs/report/2022-11-01/namespaces.txt
# True

# %% [markdown]
# # Convert, Load, and App Creation
#
# Here we generate, check to see that the TF is valid is to load, and create the config file that turns the dataset into a TF app.

# %%
X.task(convert=True)
X.task(load=True)
X.task(app=True)
# Out:
# XML to TF converting: ~/Downloads/XML-nestle1904/programs/xml/2022-11-01 => ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#   0.00s Not all of the warp features otype and oslots are present in
# ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#   0.00s Only the Feature and Edge APIs will be enabled
#   0.00s Warp feature "otext" not found. Working without Text-API
#
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s No structure nodes will be set up
#    |   SECTION   TYPES:    book, chapter, verse
#    |   SECTION   FEATURES: book, chapter, verse
#    |   STRUCTURE TYPES:
#    |   STRUCTURE FEATURES:
#    |   TEXT      FEATURES:
#    |      |   text-orig-clean      punctuation, text
#    |      |   text-orig-full       after, before, text
#    |     0.01s OK
#    |     0.00s Following director...
#   27 27-revelation.xml
# There are no broken subjref references.
# There are 9 broken frame references.
# gnt/01-matthew.xml            : n40003016026, n40004024030
# gnt/03-luke.xml               : n42001054008, n42001054011
# gnt/04-john.xml               : n43019024036
# gnt/07-1corinthians.xml       : n46012026017
# gnt/09-galatians.xml          : n48005007009
# gnt/10-ephesians.xml          : n49005014021, n49005019017
# source reading done
#    |       43s "delete" actions: 0
#    |       43s "edge" actions: 1015347
#    |       43s "feature" actions: 505536
#    |       43s "node" actions: 367757
#    |       43s "resume" actions: 0
#    |       43s "slot" actions: 137779
#    |       43s "terminate" actions: 513547
#    |         27 x "book" node
#    |        260 x "chapter" node
#    |      52242 x "clause" node
#    |     119560 x "phrase" node
#    |       8011 x "sentence" node
#    |      72845 x "subphrase" node
#    |       7944 x "verse" node
#    |     106868 x "wg" node
#    |     137779 x "word" node  = slot type
#    |     505536 nodes of all types
#    |       43s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.71s OK
#    |     0.00s checking (section) features ...
#    |     3.74s OK
#    |     0.00s reordering nodes ...
#    |     0.00s Sorting 137779 slots (node type "word")
#    |     3.03s Sorting 27 nodes of type "book"
#    |     3.06s Sorting 260 nodes of type "chapter"
#    |     3.09s Sorting 52242 nodes of type "clause"
#    |     3.31s Sorting 119560 nodes of type "phrase"
#    |     4.32s Sorting 8011 nodes of type "sentence"
#    |     4.38s Sorting 72845 nodes of type "subphrase"
#    |     4.62s Sorting 7944 nodes of type "verse"
#    |     4.68s Sorting 106868 nodes of type "wg"
#    |     5.00s Max node = 505536
#    |     5.01s OK
#    |     0.00s reassigning feature values ...
#    |      |   node feature "after" with 275558 nodes
#    |      |   node feature "appositioncontainer" with 3816 nodes
#    |      |   node feature "articular" with 57544 nodes
#    |      |   node feature "before" with 68 nodes
#    |      |   node feature "book" with 214325 nodes
#    |      |   node feature "book_short" with 137806 nodes
#    |      |   node feature "case" with 159036 nodes
#    |      |   node feature "chapter" with 145983 nodes
#    |      |   node feature "clauseType" with 10592 nodes
#    |      |   node feature "cls" with 421134 nodes
#    |      |   node feature "cltype" with 5686 nodes
#    |      |   node feature "criticalsign" with 126 nodes
#    |      |   node feature "crule" with 11116 nodes
#    |      |   node feature "degree" with 1026 nodes
#    |      |   node feature "discontinuous" with 12068 nodes
#    |      |   node feature "domain" with 253758 nodes
#    |      |   node feature "framespec" with 50986 nodes
#    |      |   node feature "function" with 103554 nodes
#    |      |   node feature "gender" with 147950 nodes
#    |      |   node feature "gloss" with 275558 nodes
#    |      |   node feature "id" with 275558 nodes
#    |      |   node feature "junction" with 35842 nodes
#    |      |   node feature "lang" with 27 nodes
#    |      |   node feature "lemma" with 275558 nodes
#    |      |   node feature "ln" with 253758 nodes
#    |      |   node feature "mood" with 56714 nodes
#    |      |   node feature "morph" with 275558 nodes
#    |      |   node feature "nodeId" with 11116 nodes
#    |      |   node feature "normalized" with 275558 nodes
#    |      |   node feature "note" with 2 nodes
#    |      |   node feature "num" with 497332 nodes
#    |      |   node feature "number" with 197874 nodes
#    |      |   node feature "person" with 38838 nodes
#    |      |   node feature "punctuation" with 275546 nodes
#    |      |   node feature "ref" with 275558 nodes
#    |      |   node feature "referent" with 28942 nodes
#    |      |   node feature "rela" with 2050 nodes
#    |      |   node feature "role" with 168436 nodes
#    |      |   node feature "rule" with 186468 nodes
#    |      |   node feature "strong" with 275558 nodes
#    |      |   node feature "subjrefspec" with 33150 nodes
#    |      |   node feature "tense" with 56714 nodes
#    |      |   node feature "text" with 275558 nodes
#    |      |   node feature "typ" with 101392 nodes
#    |      |   node feature "type" with 226336 nodes
#    |      |   node feature "unicode" with 275558 nodes
#    |      |   node feature "verse" with 145723 nodes
#    |      |   node feature "voice" with 56714 nodes
#    |      |   edge feature "frame" with 25491 start nodes
#    |      |   edge feature "parent" with 416448 start nodes
#    |      |   edge feature "sibling" with 158993 start nodes
#    |      |   edge feature "subjref" with 16575 start nodes
#    |     6.85s OK
#  1m 00s Features ready to write
#   0.00s Exporting 49 node and 5 edge and 1 config features to ~/Downloads/XML-nestle1904/programs/tf/0.5.1:
#   0.00s VALIDATING oslots feature
#   0.08s VALIDATING oslots feature
#   0.08s maxSlot=     137779
#   0.08s maxNode=     505536
#   0.16s OK: oslots is valid
#    |     0.79s T after                to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.00s T appositioncontainer  to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.13s T articular            to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.00s T before               to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.63s T book                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.39s T book_short           to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.52s T case                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.41s T chapter              to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.05s T clauseType           to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     1.36s T cls                  to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.02s T cltype               to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.00s T criticalsign         to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.04s T crule                to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.00s T degree               to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.02s T discontinuous        to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.79s T domain               to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.15s T framespec            to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.31s T function             to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.50s T gender               to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.90s T gloss                to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.88s T id                   to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.11s T junction             to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.00s T lang                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.97s T lemma                to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.82s T ln                   to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.19s T mood                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.90s T morph                to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.04s T nodeId               to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.99s T normalized           to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.00s T note                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     1.48s T num                  to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.63s T number               to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.27s T otype                to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.10s T person               to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.84s T punctuation          to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.87s T ref                  to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.08s T referent             to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.01s T rela                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.52s T role                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.60s T rule                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.88s T strong               to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.07s T subjrefspec          to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.17s T tense                to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     1.02s T text                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.28s T typ                  to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.75s T type                 to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     1.02s T unicode              to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.42s T verse                to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.18s T voice                to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.33s T frame                to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     2.03s T oslots               to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     2.42s T parent               to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     1.91s T sibling              to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.06s T subjref              to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.00s M otext                to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#     29s Exported 49 node features and 5 edge features and 1 config features to ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     2.11s T otype                from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |       22s T oslots               from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     1.74s T chapter              from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     4.48s T text                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     3.12s T book                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     4.04s T after                from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     3.94s T punctuation          from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     1.80s T verse                from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |     0.00s T before               from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.60s C __levels__           from otype, oslots, otext
#    |      |       11s C __order__            from otype, oslots, __levels__
#    |      |     0.41s C __rank__             from otype, __order__
#    |      |       49s C __levUp__            from otype, oslots, __rank__
#    |      |       25s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.49s C __characters__       from otext
#    |      |     7.74s C __boundary__         from otype, oslots, __rank__
#    |      |     0.15s C __sections__         from otype, oslots, otext, __levUp__, __levels__, book, chapter, verse
#    |      |     0.05s T appositioncontainer  from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.83s T articular            from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     1.96s T book_short           from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     2.38s T case                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.13s T clauseType           from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     6.04s T cls                  from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.10s T cltype               from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.01s T criticalsign         from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.19s T crule                from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.04s T degree               from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.17s T discontinuous        from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     4.15s T domain               from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     1.49s T frame                from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     1.05s T framespec            from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     1.76s T function             from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     2.47s T gender               from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     4.55s T gloss                from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     4.85s T id                   from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.57s T junction             from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.00s T lang                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     4.40s T lemma                from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     3.56s T ln                   from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.97s T mood                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     4.47s T morph                from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.19s T nodeId               from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     4.61s T normalized           from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.00s T note                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     6.44s T num                  from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     3.05s T number               from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |       13s T parent               from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.65s T person               from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     5.17s T ref                  from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.53s T referent             from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.05s T rela                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     2.52s T role                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     2.91s T rule                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     7.05s T sibling              from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     3.62s T strong               from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.38s T subjref              from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.59s T subjrefspec          from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.91s T tense                from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     1.38s T typ                  from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     3.34s T type                 from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     4.64s T unicode              from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
#    |      |     0.90s T voice                from ~/Downloads/XML-nestle1904/programs/tf/0.5.1
# max node = 505536
# App updating ...
# 	~/Downloads/XML-nestle1904/programs/app/static/logo.png (already exists, not overwritten)
# 	~/Downloads/XML-nestle1904/programs/app/static/display.css (no custom info, older orginal exists)
# 	~/Downloads/XML-nestle1904/programs/app/config.yaml (no custom info, older orginal exists)
# 	~/Downloads/XML-nestle1904/programs/app/app.py (deleted)
# Done
# True

# %% [markdown]
# # Test
#
# We test a bit of the resulting dataset right here.

# %%
A = use("app:~/Downloads/XML-nestle1904/programs/app", version="0.5.1", hoist=globals())
#B = use("etcbc/nestle1904", hoist=globals())
#B = use("saulocantanhede/tfgreek2", version="0.5.0", hoist=globals())
# Out:
# **Locating corpus resources ...**
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.5.1</a>, <a target="_blank" href="https://github.com///blob/main/app" title="app:~/Downloads/XML-nestle1904/programs/app app">//app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> C:/Users/TF/Downloads/XML-nestle1904/programs/tf/0.5.1, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/" title="How TF features represent text">Character table</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>27</td>
#     <td>5102.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>260</td>
#     <td>529.92</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>7944</td>
#     <td>17.34</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>8011</td>
#     <td>17.20</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>52242</td>
#     <td>8.56</td>
#     <td><i>324</i></td>
# </tr>
#
# <tr>
#     <th>wg</th>
#     <td>106868</td>
#     <td>6.88</td>
#     <td><i>533</i></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>119560</td>
#     <td>2.95</td>
#     <td><i>256</i></td>
# </tr>
#
# <tr>
#     <th>subphrase</th>
#     <td>72845</td>
#     <td>1.00</td>
#     <td>53</td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>137779</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>C:/Users/TF/Downloads/XML-nestle1904/programs/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/after.tf">after</span>
# </div>
# <div class="fmono">str</div>
#
# <span> material after the end of the word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/appositioncontainer.tf">appositioncontainer</span>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if it is an apposition container</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/articular.tf">articular</span>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the wg has an article</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/before.tf">before</span>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute before</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/book.tf">book</span>
# </div>
# <div class="fmono">str</div>
#
# <span> book name (abbreviated), from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/book_short.tf">book_short</span>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute book_short</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/case.tf">case</span>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/chapter.tf">chapter</span>
# </div>
# <div class="fmono">int</div>
#
# <span> chapter number, from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/clauseType.tf">clauseType</span>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/cls.tf">cls</span>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute cls</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/cltype.tf">cltype</span>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/criticalsign.tf">criticalsign</span>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute criticalsign</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/crule.tf">crule</span>
# </div>
# <div class="fmono">str</div>
#
# <span> clause rule (from xml attribute Rule)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/degree.tf">degree</span>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical degree</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/discontinuous.tf">discontinuous</span>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the word is out of sequence in the xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/domain.tf">domain</span>
# </div>
# <div class="fmono">str</div>
#
# <span> domain</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/framespec.tf">framespec</span>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute framespec</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/function.tf">function</span>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute function</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/gender.tf">gender</span>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/gloss.tf">gloss</span>
# </div>
# <div class="fmono">str</div>
#
# <span> short translation</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/id.tf">id</span>
# </div>
# <div class="fmono">str</div>
#
# <span> xml id</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/junction.tf">junction</span>
# </div>
# <div class="fmono">str</div>
#
# <span> type of junction</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/lang.tf">lang</span>
# </div>
# <div class="fmono">str</div>
#
# <span> language the text is in</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/lemma.tf">lemma</span>
# </div>
# <div class="fmono">str</div>
#
# <span> lexical lemma</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/ln.tf">ln</span>
# </div>
# <div class="fmono">str</div>
#
# <span> ln</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/mood.tf">mood</span>
# </div>
# <div class="fmono">str</div>
#
# <span> verbal mood</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/morph.tf">morph</span>
# </div>
# <div class="fmono">str</div>
#
# <span> morphological code</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <span title="~/Downloads/XML-nestle1904/programs/tf/0.5.1/nodeId.tf">nodeId</span>
# </div>
# <div class="fmono">int</div>
#
# <span> node id (as in the XML source
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--borde
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>

# %% [markdown]
# ## Comparing queries between the BHSA and our results

# %%
A.showFormats()
# Out:
# format | level | template
# --- | --- | ---
# `text-orig-clean` | **word** | `{text}{punctuation}`
# `text-orig-full` | **word** | `{before}{text}{after}`

# %%
B.showFormats()
# Out:
# format | level | template
# --- | --- | ---
# `text-orig-full` | **word** | `{text}{after}`

# %%
F.before.freqList(nodeTypes={"word"})
# Out:
# (('—', 16), ('(', 10), ('[[', 7), ('[', 1))

# %%
F.after.freqList(nodeTypes={"word"})
# Out:
# ((' ', 119261),
#  (',', 9439),
#  ('.', 5704),
#  ('·', 2355),
#  (';', 969),
#  (',—', 18),
#  ('—', 7),
#  (').', 6),
#  ('.]]', 4),
#  ('·—', 4),
#  (',)', 3),
#  (']].', 2),
#  ('(,', 1),
#  ('.)', 1),
#  (';)', 1),
#  (';—', 1),
#  (']', 1),
#  (']]', 1),
#  ('—,', 1))

# %%
F.punctuation.freqList(nodeTypes={"word"})
# Out:
# ((' ', 119264), (',', 9462), ('.', 5717), ('·', 2359), (';', 971))

# %%
F.criticalsign.freqList(nodeTypes={"word"})
# Out:
# (('—', 25), ('(', 11), (')', 11), ('[[', 7), (']]', 7), ('[', 1), (']', 1))

# %%
results = A.search("""
w1:word before* after* criticalsign* unicode=Ἐφέσῳ] punctuation* text*
""")
A.show(results, multiFeatures=False, queryFeatures=True, condenseType='phrase',
       colorMap=color, hiddenTypes={"wg"})
# Out:
#   1.63s 1 result
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Ephesians@1:1</span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="before xft" ><span class="f">before=</span>[</span><span class="criticalsign xft" ><span class="f">criticalsign=</span>[</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>ἐν</span><span class="unicode xft" ><span class="f">unicode=</span>[ἐν</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">[ἐν </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="before xft" ><span class="f">before=</span>[</span><span class="criticalsign xft" ><span class="f">criticalsign=</span>[</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>ἐν</span><span class="unicode xft" ><span class="f">unicode=</span>[ἐν</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span>]</span><span class="criticalsign xft" ><span class="f">criticalsign=</span>]</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>Ἐφέσῳ</span><span class="unicode xft" ><span class="f">unicode=</span>Ἐφέσῳ]</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">Ἐφέσῳ]</span></div><div class="features"><span class="after xft" ><span class="f">after=</span>]</span><span class="criticalsign xft" ><span class="f">criticalsign=</span>]</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>Ἐφέσῳ</span><span class="unicode xft" ><span class="f">unicode=</span>Ἐφέσῳ]</span></div></div></div></div></div></div></div>

# %%
for formats in T.formats:
    print(f'fmt={formats}\t: {T.text(206334,formats)}')
# Out:
# fmt=text-orig-clean	: Ἀρχὴ τοῦ εὐαγγελίου Ἰησοῦ Χριστοῦ Υἱοῦ Θεοῦ.
# fmt=text-orig-full	: Ἀρχὴ τοῦ εὐαγγελίου Ἰησοῦ Χριστοῦ (Υἱοῦ Θεοῦ).

# %%
for formats in T.formats:
    print(f'fmt={formats}\t: {T.text(216371,formats)}')
# Out:
# fmt=text-orig-clean	: διὰ τῶν ἐπακολουθούντων σημείων.
# fmt=text-orig-full	: διὰ τῶν ἐπακολουθούντων σημείων.]]

# %%
results = A.search("""
phrase
    word before* after* criticalsign* unicode=(Υἱοῦ punctuation* book=Mark chapter=1 verse=1 text*
    word before* after* criticalsign* after* unicode=Θεοῦ). punctuation* book=Mark chapter=1 verse=1 text*
""")
A.show(results, end=1, multiFeatures=False, queryFeatures=True, condenseType='phrase',
       colorMap=color, hiddenTypes={"wg"}, withNodes=False)
# Out:
#   1.81s 5 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Mark@1:1</span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>Ἀρχὴ</span><span class="unicode xft" ><span class="f">unicode=</span>Ἀρχὴ</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἀρχὴ </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>Ἀρχὴ</span><span class="unicode xft" ><span class="f">unicode=</span>Ἀρχὴ</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>τοῦ</span><span class="unicode xft" ><span class="f">unicode=</span>τοῦ</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τοῦ </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>τοῦ</span><span class="unicode xft" ><span class="f">unicode=</span>τοῦ</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>εὐαγγελίου</span><span class="unicode xft" ><span class="f">unicode=</span>εὐαγγελίου</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">εὐαγγελίου </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>εὐαγγελίου</span><span class="unicode xft" ><span class="f">unicode=</span>εὐαγγελίου</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="punctuation xft" ><span class="f">punctuation=< ...
# <div class="tfsechead "><span class="ltr">Mark@1:1</span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="before xft" ><span class="f">before=</span>(</span><span class="criticalsign xft" ><span class="f">criticalsign=</span>(</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>Υἱοῦ</span><span class="unicode xft" ><span class="f">unicode=</span>(Υἱοῦ</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #1be7ff;" ><div class="lbl c0 trm hl"  style="background-color: #1be7ff;" ><span class="txtu">(Υἱοῦ </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="before xft" ><span class="f">before=</span>(</span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="criticalsign xft" ><span class="f">criticalsign=</span>(</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>Υἱοῦ</span><span class="unicode xft" ><span class="f">unicode=</span>(Υἱοῦ</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span>).</span><span class="criticalsign xft" ><span class="f">criticalsign=</span>)</span><span class="punctuation xft" ><span class="f">punctuation=</span>.</span><span class="text xft" ><span class="f">text=</span>Θεοῦ</span><span class="unicode xft" ><span class="f">unicode=</span>Θεοῦ).</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #6eeb83;" ><div class="lbl c0 trm hl"  style="background-color: #6eeb83;" ><span class="txtu">Θεοῦ).</span></div><div class="features"><span class="after xft" ><span class="f">after=</span>).</span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="criticalsign xft" ><span class="f">criticalsign=</span>)</span><span class="punctuation xft" ><span class="f">punctuation=</span>.</span><span class="text xft" ><span class="f">text=</span>Θεοῦ</span><span class="unicode xft" ><span class="f">unicode=</span>Θεοῦ).</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div></div></div></div>

# %%
results = B.search("""
phrase
    word after* unicode=(Υἱοῦ book=Mark chapter=1 verse=1
    word after* unicode=Θεοῦ). book=Mark chapter=1 verse=1
""")
B.show(results, end=1, multiFeatures=False, queryFeatures=True, condenseType='phrase',
       colorMap=color, hiddenTypes={"wg"})
# Out:
#   1.36s 5 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Mark/1/1&amp;version=0.5.0" title="Show this on the website" sec="Mark@1:1">Mark@1:1</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="unicode xft" ><span class="f">unicode=</span>Ἀρχὴ</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἀρχὴ </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="unicode xft" ><span class="f">unicode=</span>Ἀρχὴ</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="unicode xft" ><span class="f">unicode=</span>τοῦ</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τοῦ </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="unicode xft" ><span class="f">unicode=</span>τοῦ</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="unicode xft" ><span class="f">unicode=</span>εὐαγγελίου</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">εὐαγγελίου </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="unicode xft" ><span class="f">unicode=</span>εὐαγγελίου</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="unicode xft" ><span class="f">unicode=</span>Ἰησοῦ</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦ </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="unicode xft" ><span class="f">unicode=</span>Ἰησοῦ</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </s ...
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Mark/1/1&amp;version=0.5.0" title="Show this on the website" sec="Mark@1:1">Mark@1:1</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="unicode xft" ><span class="f">unicode=</span>(Υἱοῦ</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #1be7ff;" ><div class="lbl c0 trm hl"  style="background-color: #1be7ff;" ><span class="txtu">Υἱοῦ </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="unicode xft" ><span class="f">unicode=</span>(Υἱοῦ</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span>.</span><span class="unicode xft" ><span class="f">unicode=</span>Θεοῦ).</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #6eeb83;" ><div class="lbl c0 trm hl"  style="background-color: #6eeb83;" ><span class="txtu">Θεοῦ.</span></div><div class="features"><span class="after xft" ><span class="f">after=</span>.</span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="unicode xft" ><span class="f">unicode=</span>Θεοῦ).</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div></div></div></div>

# %%
results = A.search("""
c1:clause
    p1:phrase
        w1:word
w1 -parent> p1
""")
A.show(results, end=1, multiFeatures=False, queryFeatures=True,
       colorMap=color, hiddenTypes={"wg"})
# Out:
#   0.02s 936 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Jude@1:1</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c2    hl" ><div class="lbl c2  hl" ><span class="nd">clause </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="460">parent•</span>
# <span
#     ef="parent"
#     nd="460"
#     md="605"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="460"
#     md="611"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="460"
#     md="1007"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   rno hl"  style="background-color: #1be7ff;" ><div class="lbl c1  hl"  style="background-color: #1be7ff;" ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="605">parent•</span>
# <span
#     ef="parent"
#     nd="605"
#     md="1"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="605"
#     md="606"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="605"
#     md="460"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #6eeb83;" ><div class="lbl c0 trm hl"  style="background-color: #6eeb83;" ><span class="txtu">Ἰούδας </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="1">parent•</span>
# <span
#     ef="parent"
#     nd="1"
#     md="1322"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
#
# <span
#     ef="parent"
#     nd="1"
#     md="605"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="606">parent•</span>
# <span
#     ef="parent"
#     nd="606"
#     md="607"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="606"
#     md="461"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="606"
#     md="605"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="607">parent•</span>
# <span
#     ef="parent"
#     nd="607"
#     md="608"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="607"
#     md="4"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="607"
#     md="606"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="608">parent•</span>
# <span
#     ef="parent"
#     nd="608"
#     md="2"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="608"
#     md="3"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="608"
#     md="607"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦ </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="2">parent•</span>
# <span
#     ef="parent"
#     nd="2"
#     md="1325"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
#
# <span
#     ef="parent"
#     nd="2"
#     md="608"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Χριστοῦ </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="3">parent•</span>
# <span
#     ef="parent"
#     nd="3"
#     md="1325"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
#
# <span
#     ef="parent"
#     nd="3"
#     md="608"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δοῦλος,</span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="4">parent•</span>
# <span
#     ef="parent"
#     nd="4"
#     md="1324"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
#
# <span
#     ef="parent"
#     nd="4"
#     md="607"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div></div></div></div></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="461">parent•</span>
# <span
#     ef="parent"
#     nd="461"
#     md="609"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="461"
#     md="610"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="461"
#     md="6"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="461"
#     md="606"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   lno hl"  style="background-color: #1be7ff;" ><div class="lbl c1  hl"  style="background-color: #1be7ff;" ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="605">parent•</span>
# <span
#     ef="parent"
#     nd="605"
#     md="1"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="605"
#     md="606"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="605"
#     md="460"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="606">parent•</span>
# <span
#     ef="parent"
#     nd="606"
#     md="607"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="606"
#     md="461"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="606"
#     md="605"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="609">parent•</span>
# <span
#     ef="parent"
#     nd="609"
#     md="5"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></s

# %%
results = A.search("""
w1:word book=Mark chapter=16 verse=20 after* before* unicode* punctuation* text* criticalsign*
""")
A.show(results, end=1, multiFeatures=False, queryFeatures=True,
       colorMap=color, hiddenTypes={"wg", "clause"}, withNodes=True)
# Out:
#   0.84s 16 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Mark@16:20</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse:392465 </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>16</span><span class="verse xft" ><span class="f">verse=</span>20</span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">sentence:311726 </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase:216343 </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:216360 </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>ἐκεῖνοι</span><span class="unicode xft" ><span class="f">unicode=</span>ἐκεῖνοι</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="nd">29528 </span> <span class="txtu">ἐκεῖνοι </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>16</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>ἐκεῖνοι</span><span class="unicode xft" ><span class="f">unicode=</span>ἐκεῖνοι</span><span class="verse xft" ><span class="f">verse=</span>20</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:216361 </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>δὲ</span><span class="unicode xft" ><span class="f">unicode=</span>δὲ</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">29529 </span> <span class="txtu">δὲ </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>16</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>δὲ</span><span class="unicode xft" ><span class="f">unicode=</span>δὲ</span><span class="verse xft" ><span class="f">verse=</span>20</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase:216362 </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>ἐξελθόντες</span><span class="unicode xft" ><span class="f">unicode=</span>ἐξελθόντες</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">29530 </span> <span class="txtu">ἐξελθόντες </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>16</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>ἐξελθόντες</span><span class="unicode xft" ><span class="f">unicode=</span>ἐξελθόντες</span><span class="verse xft" ><span class="f">verse=</span>20</span></div></div></div></div><div cla ...

# %%
results = A.search("""
w1:word book=Mark chapter=2 verse=10 after* before* unicode* punctuation* text*
""")
A.show(results, end=1, multiFeatures=False, queryFeatures=True,
       colorMap=color, hiddenTypes={"wg", "clause", "phrase", "subphrase"}, withNodes=True)
# Out:
#   0.08s 18 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Mark@2:10</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse:32003 </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>2</span><span class="verse xft" ><span class="f">verse=</span>10</span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">sentence:26098 </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="nd">845 </span> <span class="txtu">ἵνα </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>2</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>ἵνα</span><span class="unicode xft" ><span class="f">unicode=</span>ἵνα</span><span class="verse xft" ><span class="f">verse=</span>10</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">846 </span> <span class="txtu">δὲ </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>2</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>δὲ</span><span class="unicode xft" ><span class="f">unicode=</span>δὲ</span><span class="verse xft" ><span class="f">verse=</span>10</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">847 </span> <span class="txtu">εἰδῆτε </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>2</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>εἰδῆτε</span><span class="unicode xft" ><span class="f">unicode=</span>εἰδῆτε</span><span class="verse xft" ><span class="f">verse=</span>10</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">848 </span> <span class="txtu">ὅτι </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>2</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>ὅτι</span><span class="unicode xft" ><span class="f">unicode=</span>ὅτι</span><span class="verse xft" ><span class="f">verse=</span>10</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">849 </span> <span class="txtu">ἐξουσίαν </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>2</span><span class="punctuation xft" ><span class="f">punctuation=</span> </span><span class="text xft" ><span class="f">text=</span>ἐξουσίαν</span><span class="unicode xft" ><span class="f">unicode=</span>ἐξουσίαν</span><span class="verse xft" ><span class="f">verse=</span>10</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">850 </span> <span class="txtu">ἔχει </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book ...

# %%
results = A.search("""
word book=Acts chapter=22 verse=2 after* before* unicode*
""")
A.show(results, end=1, multiFeatures=False, queryFeatures=True,
       colorMap=color, hiddenTypes={"wg"})
# Out:
#   0.35s 13 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Acts@22:2</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Acts</span><span class="chapter xft" ><span class="f">chapter=</span>22</span><span class="verse xft" ><span class="f">verse=</span>2</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Acts</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Acts</span></div><div class="children hor wrap "><div class="contnr c2   r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Acts</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="before xft" ><span class="f">before=</span>—</span><span class="unicode xft" ><span class="f">unicode=</span>—ἀκούσαντες</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">—ἀκούσαντες </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="before xft" ><span class="f">before=</span>—</span><span class="book xft" ><span class="f">book=</span>Acts</span><span class="chapter xft" ><span class="f">chapter=</span>22</span><span class="unicode xft" ><span class="f">unicode=</span>—ἀκούσαντες</span><span class="verse xft" ><span class="f">verse=</span>2</span></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="before xft" ><span class="f">before=</span> </span><span class="unicode xft" ><span class="f">unicode=</span>δὲ</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="before xft" ><span class="f">before=</span> </span><span class="book xft" ><span class="f">book=</span>Acts</span><span class="chapter xft" ><span class="f">chapter=</span>22</span><span class="unicode xft" ><span class="f">unicode=</span>δὲ</span><span class="verse xft" ><span class="f">verse=</span>2</span></div></div></div></div><div class="contnr c2   l " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Acts</span></div><div class="children hor wrap "><div class="contnr c2   l " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Acts</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="before xft" ><span class="f">before=</span> </span><span class="unicode xft" ><span class="f">unicode=</span>ὅτι</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὅτι </span></div><div class="features"><span class="after xft" ><span cl ...

# %%
Search0 = '''
phrase role* function#Subj
 word role=s


'''
Search0 = A.search(Search0)
A.show(Search0, start=1, end=1, condensed=False, colorMap={1:'pink', 2:'yellow'}, hiddenTypes={"wg"})
# Out:
#   0.80s 833 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Matthew@4:15</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>s</span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>adv</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>aux</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   rno hl"  style="background-color: pink;" ><div class="lbl c1  hl"  style="background-color: pink;" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Objc</span><span class="role xft" ><span class="f">role=</span>o</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Γῆ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ζαβουλὼν </span></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   lno rno hl"  style="background-color: pink;" ><div class="lbl c1  hl"  style="background-color: pink;" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Objc</span><span class="role xft" ><span class="f">role=</span>o</span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " > ...
# <div class="tfsechead "><span class="ltr">Matthew@4:16</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>s</span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>adv</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>s</span></div><div class="children hor wrap "><div class="contnr c1   lno rno hl"  style="background-color: pink;" ><div class="lbl c1  hl"  style="background-color: pink;" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Objc</span><span class="role xft" ><span class="f">role=</span>o</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">λαὸς </span></div></div></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>apposition</span></div><div class="children hor wrap "><div class="contnr c1   lno rno hl"  style="background-color: pink;" ><div class="lbl c1  hl"  style="background-color: pink;" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Objc</span><span class="role xft" ><span class="f">role=</span>o</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   lno rno hl"  style="background-color: pink;" ><div class="lbl c1  hl"  style="background-color: pink;" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Objc</span><span class="role xft" ><span class="f">role=</span>o</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class= ...

# %%
Search0 = '''
phrase role* function#Subj
 word role=s


'''
Search0 = A.search(Search0)
A.show(Search0, start=1, end=1, condensed=False, colorMap={1:'pink', 2:'yellow'}, hiddenTypes={"wg"})
# Out:
#   0.32s 833 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Matthew@4:15</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>s</span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>adv</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>aux</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   rno hl"  style="background-color: pink;" ><div class="lbl c1  hl"  style="background-color: pink;" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Objc</span><span class="role xft" ><span class="f">role=</span>o</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Γῆ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ζαβουλὼν </span></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   lno rno hl"  style="background-color: pink;" ><div class="lbl c1  hl"  style="background-color: pink;" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Objc</span><span class="role xft" ><span class="f">role=</span>o</span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " > ...
# <div class="tfsechead "><span class="ltr">Matthew@4:16</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>s</span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>adv</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>s</span></div><div class="children hor wrap "><div class="contnr c1   lno rno hl"  style="background-color: pink;" ><div class="lbl c1  hl"  style="background-color: pink;" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Objc</span><span class="role xft" ><span class="f">role=</span>o</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">λαὸς </span></div></div></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>apposition</span></div><div class="children hor wrap "><div class="contnr c1   lno rno hl"  style="background-color: pink;" ><div class="lbl c1  hl"  style="background-color: pink;" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Objc</span><span class="role xft" ><span class="f">role=</span>o</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   lno rno hl"  style="background-color: pink;" ><div class="lbl c1  hl"  style="background-color: pink;" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Objc</span><span class="role xft" ><span class="f">role=</span>o</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class= ...

# %%
results = A.search("""
book book=Jude
    verse verse=9
        c1:wg cls=cl
            p1:word role=s
            p2:word role=o

p1 -parent> c1
p2 -parent> c1
""")
A.show(results, multiFeatures=False, queryFeatures=True,
       colorMap=color, hiddenTypes={"wg"})
# Out:
#   0.01s 1 result
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Jude</span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">Jude</span></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div>
# <div class="tfsechead "><span class="ltr">Jude@1:9</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="verse xft" ><span class="f">verse=</span>9</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="518">parent•</span>
# <span
#     ef="parent"
#     nd="518"
#     md="741"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="518"
#     md="745"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="518"
#     md="1013"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c2   r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="cls xft" ><span class="f">cls=</span>cl</span><span class="parent xft" ><span class="e" edge="parent" nd="519">parent•</span>
# <span
#     ef="parent"
#     nd="519"
#     md="743"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="519"
#     md="754"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="519"
#     md="523"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="519"
#     md="742"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="741">parent•</span>
# <span
#     ef="parent"
#     nd="741"
#     md="742"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="741"
#     md="520"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="741"
#     md="518"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="742">parent•</span>
# <span
#     ef="parent"
#     nd="742"
#     md="519"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="742"
#     md="1123"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="742"
#     md="757"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="742"
#     md="524"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="742"
#     md="741"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="743">parent•</span>
# <span
#     ef="parent"
#     nd="743"
#     md="744"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="743"
#     md="746"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="743"
#     md="519"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="role xft" ><span class="f">role=</span>s</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>np</span><span class="parent xft" ><span class="e" edge="parent" nd="744">parent•</span>
# <span
#     ef="parent"
#     nd="744"
#     md="1113"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="744"
#     md="1114"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="744"
#     md="743"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>det</span><span class="parent xft" ><span class="e" edge="parent" nd="1113">parent•</span>
# <span
#     ef="parent"
#     nd="1113"
#     md="744"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="cls xft" ><span class="f">cls=</span>det</span><span class="parent xft" ><span class="e" edge="parent" nd="159">parent•</span>
# <span
#     ef="parent"
#     nd="159"
#     md="1450"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="verse xft" ><span class="f">verse=</span>9</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>conj</span><span class="parent xft" ><span class="e" edge="parent" nd="745">parent•</span>
# <span
#     ef="parent"
#     nd="745"
#     md="518"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="cls xft" ><span class="f">cls=</span>conj</span><span class="parent xft" ><span class="e" edge="parent" nd="160">parent•</span>
# <span
#     ef="parent"
#     nd="160"
#     md="1445"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="verse xft" ><span class="f">verse=</span>9</span></div></div></div></div><div class="contnr c2   l r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="cls xft" ><span class="f">cls=</span>cl</span><span class="parent xft" ><span class="e" edge="parent" nd="519">parent•</span>
# <span
#     ef="parent"
#     nd="519"
#     md="743"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="519"
#     md="754"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="519"
#     md="523"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="519"
#     md="742"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   l rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="741">parent•</span>
# <span
#     ef="parent"
#     nd="741"
#     md="742"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="741"
#     md="520"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="741"
#     md="518"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   l r " ><div class="lbl c1  " ><span class="nd">phrase </span

# %%
results = A.search("""
verse book=Matthew verse=19 chapter=1
    wg rule=CLaCL role=adv
""")
A.show(results, end=1, multiFeatures=False, queryFeatures=True,
       colorMap=color, hiddenTypes={"wg"}, extraFeatures={"role"})
# Out:
#   0.12s 1 result
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Matthew@1:19</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="verse xft" ><span class="f">verse=</span>19</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>Conj-CL</span></div><div class="children hor wrap "><div class="contnr c2   r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="rule xft" ><span class="f">rule=</span>S-ADV-V-O</span></div><div class="children hor wrap "><div class="contnr c2   r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰωσὴφ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div></div></div><div class="contnr c2   l " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="rule xft" ><span class="f">rule=</span>S-ADV-V-O</span></div><div class="children hor wrap "><div class="contnr c2   l " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>apposition</span><span class="rule xft" ><span class="f">rule=</span>DetNP</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPofNP</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class=" ...

# %%
import sys, os, collections
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt; plt.rcdefaults()
from matplotlib.pyplot import figure
from collections import Counter

# %%
results = A.search("""
w:word role=p
""")
# Out:
#   0.33s 1904 results

# %%
results = A.search("""
p:phrase role=p
    w:word role=p
""")
# Out:
#   0.61s 1910 results

# %%
def possui_mais_de_uma_palavra(texto):
    palavras = texto.split()
    return len(palavras) > 1

# %%
results = A.search("""
p:phrase role=p
    w:word role=p
""")
A.export(results, toDir='C:/Users/TF/Downloads', toFile='test2.tsv')
results=pd.read_csv('C:/Users/TF/Downloads/test2.tsv',delimiter='\t',encoding='utf-16')
pd.set_option('display.max_columns', 50)
results.head(50)

df = pd.DataFrame(results)
df['Possui_Mais_de_Uma_Palavra'] = df['TEXT1'].apply(possui_mais_de_uma_palavra)

df_filtrado = df.loc[df['Possui_Mais_de_Uma_Palavra'] == True]

# Exibir o DataFrame resultante
print(df_filtrado)
# Out:
#   0.63s 1910 results
#          R            S1  S2  S3   NODE1   TYPE1  \
# 253    254          Mark   4  31  218663  phrase
# 254    255          Mark   4  31  218663  phrase
# 1345  1346  1Corinthians  15   9  278203  phrase
# 1346  1347  1Corinthians  15   9  278203  phrase
# 1586  1587      1Timothy   1   5  290027  phrase
# 1624  1625         Titus   1   7  292115  phrase
#
#                                                   TEXT1 role1   NODE2 TYPE2  \
# 253   ὡς κόκκῳ σινάπεως,ὃς ὅταν σπαρῇ ἐπὶ τῆς γῆς,μι...     p   20590  word
# 254   ὡς κόκκῳ σινάπεως,ὃς ὅταν σπαρῇ ἐπὶ τῆς γῆς,μι...     p   20605  word
# 1345  ὁ ἐλάχιστος τῶν ἀποστόλων,ὃς οὐκ εἰμὶ ἱκανὸς κ...     p   95932  word
# 1346  ὁ ἐλάχιστος τῶν ἀποστόλων,ὃς οὐκ εἰμὶ ἱκανὸς κ...     p   95934  word
# 1586  ἀγάπη ἐκ καθαρᾶς καρδίας καὶ συνειδήσεως ἀγαθῆ...     p  111691  word
# 1624  ἀνέγκλητον μὴ αὐθάδη,μὴ ὀργίλον,μὴ πάροινον,μὴ...     p  114546  word
#
#                 TEXT2 role2  Possui_Mais_de_Uma_Palavra
# 253       μικρότερον      p                        True
# 254           μεῖζον      p                        True
# 1345          ἱκανὸς      p                        True
# 1346       ἀπόστολος,     p                        True
# 1586  νομοδιδάσκαλοι,     p                        True
# 1624         πλήκτην,     p                        True

# %%
results = A.search("""
p1:phrase role=apposition articular* rule* type* rela* appositioncontainer*
    word book=Jude
""")
A.show(results, end=10, multiFeatures=False, queryFeatures=True,
       condenseType="clause", colorMap=color, hiddenTypes={"wg"})
# Out:
#   0.49s 23 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Jude@1:1</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="rule xft" ><span class="f">rule=</span>S-IO</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰούδας </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div><div class="contnr c1   rno hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="rela xft" ><span class="f">rela=</span>Appo</span><span class="role xft" ><span class="f">role=</span>apposition</span><span class="rule xft" ><span class="f">rule=</span>NpaNp</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>ofNPNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #1be7ff;" ><div class="lbl c0 trm hl"  style="background-color: #1be7ff;" ><span class="txtu">Ἰησοῦ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Χριστοῦ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>common</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δοῦλος,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>common</span></div></div></div></div></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="type xft" > ...
# <div class="tfsechead "><span class="ltr">Jude@1:1</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>conjuncted-wg</span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   lno hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="rela xft" ><span class="f">rela=</span>Appo</span><span class="role xft" ><span class="f">role=</span>apposition</span><span class="rule xft" ><span class="f">rule=</span>NpaNp</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPofNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>common</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀδελφὸς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>common</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div></div><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPofNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰακώβου,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div></div></div></div></div></div></div></div></div></div>
# <p><b>result</b> <i>2</i>
# <div class="tfsechead "><span class="ltr">Jude@1:1</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="rule xft" ><span class="f">rule=</span>S-IO</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰούδας </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div><div class="contnr c1   rno hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="rela xft" ><span class="f">rela=</span>Appo</span><span class="role xft" ><span class="f">role=</span>apposition</span><span class="rule xft" ><span class="f">rule=</span>NpaNp</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>ofNPNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #1be7ff;" ><div class="lbl c0 trm hl"  style="background-color: #1be7ff;" ><span class="txtu">Χριστοῦ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>common</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δοῦλος,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>common</span></div></div></div></div></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="type xft" > ...
# <div class="tfsechead "><span class="ltr">Jude@1:1</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>conjuncted-wg</span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   lno hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="rela xft" ><span class="f">rela=</span>Appo</span><span class="role xft" ><span class="f">role=</span>apposition</span><span class="rule xft" ><span class="f">rule=</span>NpaNp</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPofNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>common</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀδελφὸς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>common</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div></div><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPofNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰακώβου,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div></div></div></div></div></div></div></div></div></div>
# <p><b>result</b> <i>3</i>
# <div class="tfsechead "><span class="ltr">Jude@1:1</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="rule xft" ><span class="f">rule=</span>S-IO</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰούδας </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div><div class="contnr c1   rno hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="rela xft" ><span class="f">rela=</span>Appo</span><span class="role xft" ><span class="f">role=</span>apposition</span><span class="rule xft" ><span class="f">rule=</span>NpaNp</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>ofNPNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Χριστοῦ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>common</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #1be7ff;" ><div class="lbl c0 trm hl"  style="background-color: #1be7ff;" ><span class="txtu">δοῦλος,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>common</span></div></div></div></div></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="type xft" > ...
# <div class="tfsechead "><span class="ltr">Jude@1:1</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>conjuncted-wg</span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   lno hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="rela xft" ><span class="f">rela=</span>Appo</span><span class="role xft" ><span class="f">role=</span>apposition</span><span class="rule xft" ><span class="f">rule=</span>NpaNp</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPofNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>common</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀδελφὸς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>common</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div></div><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPofNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰακώβου,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div></div></div></div></div></div></div></div></div></div>
# <p><b>result</b> <i>4</i>
# <div class="tfsechead "><span class="ltr">Jude@1:1</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="rule xft" ><span class="f">rule=</span>S-IO</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰούδας </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div><div class="contnr c1   rno hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="rela xft" ><span class="f">rela=</span>Appo</span><span class="role xft" ><span class="f">role=</span>apposition</span><span class="rule xft" ><span class="f">rule=</span>NpaNp</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>ofNPNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Χριστοῦ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>common</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δοῦλος,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>common</span></div></div></div></div></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>conjuncted-wg</span></div><div class="children h ...
# <div class="tfsechead "><span class="ltr">Jude@1:1</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>conjuncted-wg</span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   lno hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="rela xft" ><span class="f">rela=</span>Appo</span><span class="role xft" ><span class="f">role=</span>apposition</span><span class="rule xft" ><span class="f">rule=</span>NpaNp</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPofNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>common</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #1be7ff;" ><div class="lbl c0 trm hl"  style="background-color: #1be7ff;" ><span class="txtu">ἀδελφὸς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>common</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div></div><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPofNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰακώβου,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div></div></div></div></div></div></div></div></div></div>
# <p><b>result</b> <i>5</i>
# <div class="tfsechead "><span class="ltr">Jude@1:1</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="rule xft" ><span class="f">rule=</span>S-IO</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰούδας </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div><div class="contnr c1   rno hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="rela xft" ><span class="f">rela=</span>Appo</span><span class="role xft" ><span class="f">role=</span>apposition</span><span class="rule xft" ><span class="f">rule=</span>NpaNp</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>ofNPNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Χριστοῦ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>common</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δοῦλος,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>common</span></div></div></div></div></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>conjuncted-wg</span></div><div class="children h ...
# <div class="tfsechead "><span class="ltr">Jude@1:1</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>conjuncted-wg</span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   lno hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="rela xft" ><span class="f">rela=</span>Appo</span><span class="role xft" ><span class="f">role=</span>apposition</span><span class="rule xft" ><span class="f">rule=</span>NpaNp</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPofNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>common</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀδελφὸς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>common</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #1be7ff;" ><div class="lbl c0 trm hl"  style="background-color: #1be7ff;" ><span class="txtu">δὲ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div></div><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPofNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰακώβου,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div></div></div></div></div></div></div></div></div></div>
# <p><b>result</b> <i>6</i>
# <div class="tfsechead "><span class="ltr">Jude@1:1</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="rule xft" ><span class="f">rule=</span>S-IO</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰούδας </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div><div class="contnr c1   rno hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="rela xft" ><span class="f">rela=</span>Appo</span><span class="role xft" ><span class="f">role=</span>apposition</span><span class="rule xft" ><span class="f">rule=</span>NpaNp</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>ofNPNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Χριστοῦ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>common</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δοῦλος,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>common</span></div></div></div></div></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>conjuncted-wg</span></div><div class="children h ...
# <div class="tfsechead "><span class="ltr">Jude@1:1</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>conjuncted-wg</span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   lno hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="rela xft" ><span class="f">rela=</span>Appo</span><span class="role xft" ><span class="f">role=</span>apposition</span><span class="rule xft" ><span class="f">rule=</span>NpaNp</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPofNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>common</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀδελφὸς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>common</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div></div><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPofNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #1be7ff;" ><div class="lbl c0 trm hl"  style="background-color: #1be7ff;" ><span class="txtu">Ἰακώβου,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>proper</span></div></div></div></div></div></div></div></div></div></div></div></div></div>
# <p><b>result</b> <i>7</i>
# <div class="tfsechead "><span class="ltr">Jude@1:4</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>conjuncted-wg</span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>adv</span><span class="rule xft" ><span class="f">rule=</span>CLaCL</span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="articular xft" ><span class="f">articular=</span>1</span><span class="role xft" ><span class="f">role=</span>o</span><span class="rule xft" ><span class="f">rule=</span>DetNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NpaNp</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPofNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>common</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Κύριον </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>common</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>personal</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἡμῶν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>personal</span></div></div></div></div></div></div><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="rela xft" ><span class="f">rela=</span>Appo</span><span class="role xft" ><span class="f">role=</span>apposition</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #1be7ff;" ><div class="lbl c0 trm hl"  ...
# <p><b>result</b> <i>8</i>
# <div class="tfsechead "><span class="ltr">Jude@1:4</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>conjuncted-wg</span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>adv</span><span class="rule xft" ><span class="f">rule=</span>CLaCL</span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="articular xft" ><span class="f">articular=</span>1</span><span class="role xft" ><span class="f">role=</span>o</span><span class="rule xft" ><span class="f">rule=</span>DetNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NpaNp</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPofNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>common</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Κύριον </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>common</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>personal</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἡμῶν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="type xft" ><span class="f">type=</span>personal</span></div></div></div></div></div></div><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="rela xft" ><span class="f">rela=</span>Appo</span><span class="role xft" ><span class="f">role=</span>apposition</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ><span class="f">type=</span>proper</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦν </span></div> ...
# <p><b>result</b> <i>9</i>
# <div class="tfsechead "><span class="ltr">Jude@1:9</span></div><div class=" children"><div class="contnr c2   r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="rule xft" ><span class="f">rule=</span>S-V-O</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>ClCl2</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>notCLbutCL2CL</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="articular xft" ><span class="f">articular=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="articular xft" ><span class="f">articular=</span>1</span><span class="rule xft" ><span class="f">rule=</span>DetNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c2   l r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="rule xft" ><span class="f">rule=</span>S-V-O</span></div><div class="children hor wrap "><div class="contnr c1   l rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>ClCl2</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   l r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>notCLbutCL2CL</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="articular xft" ><span class="f">articular=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="articular xft" ><span class="f">articular=</span>1</span><span class="rule xft" ><span class="f">rule=</span>DetNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ...
# <p><b>result</b> <i>10</i>
# <div class="tfsechead "><span class="ltr">Jude@1:9</span></div><div class=" children"><div class="contnr c2   r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="rule xft" ><span class="f">rule=</span>S-V-O</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>ClCl2</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>notCLbutCL2CL</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="articular xft" ><span class="f">articular=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="articular xft" ><span class="f">articular=</span>1</span><span class="rule xft" ><span class="f">rule=</span>DetNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c2   l r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="rule xft" ><span class="f">rule=</span>S-V-O</span></div><div class="children hor wrap "><div class="contnr c1   l rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>ClCl2</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   l r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>notCLbutCL2CL</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="appositioncontainer xft" ><span class="f">appositioncontainer=</span>1</span><span class="articular xft" ><span class="f">articular=</span>1</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>Np-Appos</span><span class="type xft" ><span class="f">type=</span>group</span></div><div class="children hor wrap "><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="articular xft" ><span class="f">articular=</span>1</span><span class="rule xft" ><span class="f">rule=</span>DetNP</span><span class="type xft" ><span class="f">type=</span>modifier-scope</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="type xft" ...

# %%
results = A.search("""
word book=Luke chapter=2 verse=35 num=1 after* unicode*
""")
A.show(results, end=1, multiFeatures=False, queryFeatures=True,
       condenseType="clause", colorMap=color, hiddenTypes={"wg"})
# Out:
#   0.25s 1 result
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Luke@2:35</span></div><div class=" children"><div class="contnr c2   r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Luke</span><span class="num xft" ><span class="f">num=</span>746</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1356</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span>ὶ</span><span class="num xft" ><span class="f">num=</span>1357</span><span class="unicode xft" ><span class="f">unicode=</span>—καὶ</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">—καὶ </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Luke</span><span class="chapter xft" ><span class="f">chapter=</span>2</span><span class="num xft" ><span class="f">num=</span>1</span><span class="unicode xft" ><span class="f">unicode=</span>—καὶ</span><span class="verse xft" ><span class="f">verse=</span>35</span></div></div></div></div><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1358</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1359</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="num xft" ><span class="f">num=</span>1001</span><span class="unicode xft" ><span class="f">unicode=</span>σοῦ</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">σοῦ </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Luke</span><span class="chapter xft" ><span class="f">chapter=</span>2</span><span class="num xft" ><span class="f">num=</span>2</span><span class="unicode xft" ><span class="f">unicode=</span>σοῦ</span><span class="verse xft" ><span class="f">verse=</span>35</span></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c2   l " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Luke</span><span class="num xft" ><span class="f">num=</span>746</span></div><div class="children hor wrap "><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1356</span></div><div class="children hor wrap "><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1358</span></div><div class="children hor wrap "><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1359</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="num xft" ><span class="f">num=</span>1002</span><span class="unicode xft" ><span class="f">unicode=</span>αὐτῆς</span></div><div class="children ho ...

# %%
results = A.search("""
word unicode=σημείων.]] num* after*
""")
A.show(results, end=1, multiFeatures=False, queryFeatures=True,
       condenseType="clause", colorMap=color, hiddenTypes={"wg"})
# Out:
#   0.32s 1 result
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Mark@16:20</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>5596</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>9117</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="num xft" ><span class="f">num=</span>5145</span><span class="unicode xft" ><span class="f">unicode=</span>τὸν</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τὸν </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="num xft" ><span class="f">num=</span>10</span><span class="unicode xft" ><span class="f">unicode=</span>τὸν</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="num xft" ><span class="f">num=</span>5146</span><span class="unicode xft" ><span class="f">unicode=</span>λόγον</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">λόγον </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="num xft" ><span class="f">num=</span>11</span><span class="unicode xft" ><span class="f">unicode=</span>λόγον</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="num xft" ><span class="f">num=</span>9118</span><span class="unicode xft" ><span class="f">unicode=</span>βεβαιοῦντος</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">βεβαιοῦντος </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="num xft" ><span class="f">num=</span>12</span><span class="unicode xft" ><span class="f">unicode=</span>βεβαιοῦντος</span></div></div></div></div><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>9119</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="num xft" ><span class="f">num=</span>5147</span><span class="unicode xft" ><span class="f">unicode=</span>διὰ</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">διὰ </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="num xft" ><span class="f">num=</span>13</span><span class="unicode xft" ><span class="f">unicode=</span>διὰ</span></div></div></div></div><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>9120</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="num xft" ><span class="f">num=</span>5148</span><span class="unicode xft" ><span class="f">unicode=</span>τῶν</span></div><div class="children hor wrap "><div clas ...

# %%
results = A.search("""
word book* chapter* verse* unicode=[ἐν after*
""")
A.show(results, end=1, multiFeatures=False, queryFeatures=True,
       condenseType="clause", colorMap=color, hiddenTypes={"wg"})
# Out:
#   0.44s 1 result
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Ephesians@1:1</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Ephesians</span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="unicode xft" ><span class="f">unicode=</span>οὖσιν</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">οὖσιν </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Ephesians</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="unicode xft" ><span class="f">unicode=</span>οὖσιν</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="unicode xft" ><span class="f">unicode=</span>[ἐν</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">ἐν </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Ephesians</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="unicode xft" ><span class="f">unicode=</span>[ἐν</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="unicode xft" ><span class="f">unicode=</span>Ἐφέσῳ]</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἐφέσῳ </span></div><div class="features"><span class="after xft" ><span class="f">after=</span> </span><span class="book xft" ><span class="f">book=</span>Ephesians</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="unicode xft" ><span class="f">unicode=</span>Ἐφέσῳ]</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div>

# %%
results = A.search("""
book book=Matthew
    word framespec
    -frame> word
""")
A.show(results, end=1, multiFeatures=False, queryFeatures=True,
       condenseType="clause", colorMap=color, hiddenTypes={"wg"})
# Out:
#   0.77s 6019 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Matthew/1/1&amp;version=0.5.0" title="Show this on the website" sec="Matthew">Matthew</a></span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">Matthew</span></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/Matthew/1/2&amp;version=0.5.0" title="Show this on the website" sec="Matthew@1:2">Matthew@1:2</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #6eeb83;" ><div class="lbl c0 trm hl"  style="background-color: #6eeb83;" ><span class="txtu">Ἀβραὰμ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="frame xft" ><span class="e" edge="frame" nd="9">frame•</span>
# <span
#     ef="frame"
#     nd="9"
#     md="10"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A0</span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="framespec xft" ><span class="f">framespec=</span>A0:n40001002001 A1:n40001002004</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #1be7ff;" ><div class="lbl c0 trm hl"  style="background-color: #1be7ff;" ><span class="txtu">ἐγέννησεν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="frame xft" ><span class="e" edge="frame" nd="10">frame•</span>
# <span
#     ef="frame"
#     nd="10"
#     md="9"
#     arrow="right"
#     class="etf"
# >A0<span class="etfx">↦</span></span>
#
# <span
#     ef="frame"
#     nd="10"
#     md="12"
#     arrow="right"
#     class="etf"
# >A1<span class="etfx">↦</span></span>
# </span><span class="framespec xft" ><span class="f">framespec=</span>A0:n40001002001 A1:n40001002004</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τὸν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰσαάκ,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="frame xft" ><span class="e" edge="frame" nd="12">frame•</span>
# <span
#     ef="frame"
#     nd="12"
#     md="10"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>A1</span>
# </span></div></div></div></div></div></div></div></div></div></div></div>

# %%
results = A.search("""
wg role*
""")
A.show(results, end=1, multiFeatures=False, queryFeatures=True,
       condenseType="clause", colorMap=color)
# Out:
#   0.47s 106868 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Matthew@1:1</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   rno hl" ><div class="lbl c1  hl" ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>p</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>p</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Βίβλος </span></div></div></div></div></div></div><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>p</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">γενέσεως </span></div></div></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   lno rno hl" ><div class="lbl c1  hl" ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>p</span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>p</span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Χριστοῦ </span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c1   lno rno hl" ><div class="lbl c1  hl" ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr  ...
# <div class="tfsechead "><span class="ltr">Matthew@1:1</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   lno rno hl" ><div class="lbl c1  hl" ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>p</span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>p</span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Χριστοῦ </span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c1   lno rno hl" ><div class="lbl c1  hl" ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>p</span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>apposition</span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>p</span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>apposition</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">υἱοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class= ...

# %%
results = B.search("""
book book=Jude
    verse verse=9
        c1:wg cls=cl
            p1:word role=s
            p2:word role=o

p1 -parent> c1
p2 -parent> c1
""")
B.show(results, multiFeatures=False, queryFeatures=True,
       colorMap=color, hiddenTypes={"wg"})
# Out:
#   0.41s 1 result
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Jude</span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">Jude</span></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div>
# <div class="tfsechead "><span class="ltr">Jude@1:9</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="verse xft" ><span class="f">verse=</span>9</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="317402">parent•</span>
# <span
#     ef="parent"
#     nd="317402"
#     md="497129"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c2   r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>cl</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>s</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>np</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>det</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="cls xft" ><span class="f">cls=</span>det</span><span class="parent xft" ><span class="e" edge="parent" nd="127649">parent•</span>
# <span
#     ef="parent"
#     nd="127649"
#     md="497134"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="verse xft" ><span class="f">verse=</span>9</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>conj</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="cls xft" ><span class="f">cls=</span>conj</span><span class="parent xft" ><span class="e" edge="parent" nd="127650">parent•</span>
# <span
#     ef="parent"
#     nd="127650"
#     md="497129"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="verse xft" ><span class="f">verse=</span>9</span></div></div></div></div></div></div><div class="contnr c2   l r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>cl</span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   l rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   l r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>s</span></div><div class="children hor wrap "><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>np</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>noun</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Μιχαὴλ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="cls xft" ><span class="f">cls=</span>noun</span><span class="parent xft" ><span class="e" edge="parent" nd="127651">parent•</span>
# <span
#     ef="parent"
#     nd="127651"
#     md="497134"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="verse xft" ><span class="f">verse=</span>9</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>np</span><span class="role xft" ><span class="f">role=</span>apposition</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>det</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="cls xft" ><span class="f">cls=</span>det</span><span class="parent xft" ><span class="e" edge="parent" nd="127652">parent•</span>
# <span
#     ef="parent"
#     nd="127652"
#     md="497135"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="verse xft" ><span class="f">verse=</span>9</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>noun</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀρχάγγελος,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="cls xft" ><span class="f">cls=</span>noun</span><span class="parent xft" ><span class="e" edge="parent" nd="127653">parent•</span>
# <span
#     ef="parent"
#     nd="127653"
#     md="497135"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="verse xft" ><span class="f">verse=</span>9</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>conj</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὅτε </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="cls xft" ><span class="f">cls=</span>conj</span><span class="parent xft" ><span class="e" edge="parent" nd="127654">parent•</span>
# <span
#     ef="parent"
#     nd="127654"
#     md="497

# %%
results = A.search("""
book book=Jude
    verse verse=9
        c1:wg cls=cl
            p1:word role=s
            p2:word role=o

p1 -parent> c1
p2 -parent> c1
""")
A.show(results, multiFeatures=False, queryFeatures=True,
       colorMap=color, hiddenTypes={"wg"})
# Out:
#   0.00s 1 result
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Jude</span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">Jude</span></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div></div></div>
# <div class="tfsechead "><span class="ltr">Jude@1:9</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="verse xft" ><span class="f">verse=</span>9</span></div><div class="children hor wrap "><div class="contnr c2   r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>cl</span><span class="parent xft" ><span class="e" edge="parent" nd="495">parent•</span>
# <span
#     ef="parent"
#     nd="495"
#     md="715"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="495"
#     md="727"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="495"
#     md="498"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="495"
#     md="714"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="712">parent•</span>
# <span
#     ef="parent"
#     nd="712"
#     md="713"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="712"
#     md="717"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="712"
#     md="1013"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="713">parent•</span>
# <span
#     ef="parent"
#     nd="713"
#     md="714"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="713"
#     md="719"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="713"
#     md="712"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="714">parent•</span>
# <span
#     ef="parent"
#     nd="714"
#     md="495"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="714"
#     md="730"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="714"
#     md="499"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="714"
#     md="713"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="715">parent•</span>
# <span
#     ef="parent"
#     nd="715"
#     md="716"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="715"
#     md="718"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="715"
#     md="495"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="role xft" ><span class="f">role=</span>s</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>np</span><span class="parent xft" ><span class="e" edge="parent" nd="716">parent•</span>
# <span
#     ef="parent"
#     nd="716"
#     md="715"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>det</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="cls xft" ><span class="f">cls=</span>det</span><span class="parent xft" ><span class="e" edge="parent" nd="159">parent•</span>
# <span
#     ef="parent"
#     nd="159"
#     md="1450"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="verse xft" ><span class="f">verse=</span>9</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="712">parent•</span>
# <span
#     ef="parent"
#     nd="712"
#     md="713"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="712"
#     md="717"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="712"
#     md="1013"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>conj</span><span class="parent xft" ><span class="e" edge="parent" nd="717">parent•</span>
# <span
#     ef="parent"
#     nd="717"
#     md="712"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="cls xft" ><span class="f">cls=</span>conj</span><span class="parent xft" ><span class="e" edge="parent" nd="160">parent•</span>
# <span
#     ef="parent"
#     nd="160"
#     md="1445"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="verse xft" ><span class="f">verse=</span>9</span></div></div></div></div></div></div><div class="contnr c2   l r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="cls xft" ><span class="f">cls=</span>cl</span><span class="parent xft" ><span class="e" edge="parent" nd="495">parent•</span>
# <span
#     ef="parent"
#     nd="495"
#     md="715"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="495"
#     md="727"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="495"
#     md="498"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="495"
#     md="714"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="712">parent•</span>
# <span
#     ef="parent"
#     nd="712"
#     md="713"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="712"
#     md="717"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="712"
#     md="1013"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   l rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span cl

# %%
results = A.search("""
book book=Jude
  phrase
  -sibling> phrase
""")
A.show(results, end=1, queryFeatures=False, hiddenTypes="wg")
# Out:
#   0.00s 64 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Jude</span></div><div class=" children"><div class="contnr c4 trm   " ><div class="lbl c4 trm " ><span class="nd">book </span> <span class="txtu"><span class="tfsechead ltr"><span class="ltr">Jude</span></span></span></div></div></div>
# <div class="tfsechead "><span class="ltr">Jude@1:1</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰούδας </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Χριστοῦ </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δοῦλος,</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀδελφὸς </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ </span></div></div></div></div><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰακώβου,</span></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c1   rno hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τοῖς </span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   lno rno hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class=" ...

# %%
results = A.search("""
verse book=Jude verse=9
    c1:clause
        p1:phrase function=Objc
        p2:phrase function=Subj

p1 -parent> c1
p2 -parent> c1
""")
A.show(results, multiFeatures=False, queryFeatures=True,
       colorMap=color, condenseType="sentence", hiddenTypes={"wg"})
# Out:
#   0.00s 1 result
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Jude@1:9</span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="1013">parent•</span>
# <span
#     ef="parent"
#     nd="1013"
#     md="1445"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="1013"
#     md="712"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c3    hl" ><div class="lbl c3  hl" ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="verse xft" ><span class="f">verse=</span>9</span></div><div class="children hor wrap "><div class="contnr c2   r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="495">parent•</span>
# <span
#     ef="parent"
#     nd="495"
#     md="715"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="495"
#     md="727"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="495"
#     md="498"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="495"
#     md="714"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="712">parent•</span>
# <span
#     ef="parent"
#     nd="712"
#     md="713"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="712"
#     md="717"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="712"
#     md="1013"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="713">parent•</span>
# <span
#     ef="parent"
#     nd="713"
#     md="714"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="713"
#     md="719"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="713"
#     md="712"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="714">parent•</span>
# <span
#     ef="parent"
#     nd="714"
#     md="495"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="714"
#     md="730"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="714"
#     md="499"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="714"
#     md="713"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Subj</span><span class="parent xft" ><span class="e" edge="parent" nd="715">parent•</span>
# <span
#     ef="parent"
#     nd="715"
#     md="716"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="715"
#     md="718"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="715"
#     md="495"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="716">parent•</span>
# <span
#     ef="parent"
#     nd="716"
#     md="715"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="parent xft" ><span class="e" edge="parent" nd="159">parent•</span>
# <span
#     ef="parent"
#     nd="159"
#     md="1450"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="verse xft" ><span class="f">verse=</span>9</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="712">parent•</span>
# <span
#     ef="parent"
#     nd="712"
#     md="713"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="712"
#     md="717"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="712"
#     md="1013"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="717">parent•</span>
# <span
#     ef="parent"
#     nd="717"
#     md="712"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="parent xft" ><span class="e" edge="parent" nd="160">parent•</span>
# <span
#     ef="parent"
#     nd="160"
#     md="1445"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="verse xft" ><span class="f">verse=</span>9</span></div></div></div></div></div></div><div class="contnr c2   l r " ><div class="lbl c2  " ><span class="nd">clause </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="495">parent•</span>
# <span
#     ef="parent"
#     nd="495"
#     md="715"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="495"
#     md="727"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="495"
#     md="498"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="495"
#     md="714"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="712">parent•</span>
# <span
#     ef="parent"
#     nd="712"
#     md="713"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="712"
#     md="717"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="712"
#     md="1013"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   l rno " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div clas

# %%
results = B.search("""
verse book=Matthew chapter=4 verse=10
    c1:clause
        p1:phrase rule* cltype=Minor
        p2:phrase text=Σατανᾶ
""")
B.show(results, end=1, multiFeatures=False, queryFeatures=True, hiddenTypes={"wg"}, colorMap=color)
# Out:
#   0.27s 2 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Matthew@4:10</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>4</span><span class="verse xft" ><span class="f">verse=</span>10</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c2    hl"  style="background-color: #1be7ff;" ><div class="lbl c2  hl"  style="background-color: #1be7ff;" ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="text xft" ><span class="f">text=</span>τότε</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τότε </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>4</span><span class="text xft" ><span class="f">text=</span>τότε</span><span class="verse xft" ><span class="f">verse=</span>10</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="text xft" ><span class="f">text=</span>λέγει</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">λέγει </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>4</span><span class="text xft" ><span class="f">text=</span>λέγει</span><span class="verse xft" ><span class="f">verse=</span>10</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="text xft" ><span class="f">text=</span>αὐτῷ</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">αὐτῷ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>4</span><span class="text xft" ><span class="f">text=</span>αὐτῷ</span><span class="verse xft" ><span class="f">verse=</span>10</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>DetNP</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="text xft" ><span class="f">text=</span>ὁ</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>4</span><span class="text xft" ><span class="f">text=</span>ὁ</span><span class="verse xft" ><span class="f">verse=</span>10</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="text xft" ><span class="f">text=</span>Ἰησοῦς</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>4</span><span class="text xft" ><span class="f">text=</span>Ἰησοῦς</span><span class="verse xft" ><span class="f">verse=</span>10</span></div></div ...

# %%
B.displaySetup(withNodes=False,
               standardFeatures=True,
               hiddenTypes={"clause", "phrase","subphrase"},
               hideTypes=True,
               queryFeatures=False)

# %%
matthew = B.nodeFromSectionStr("Matthew")
#L is the Locality class looking for downward (d) nodes
print(matthew)
s = L.d(matthew, otype="sentence")[1]
#A.pretty(s)
# Out:
# 137780

# %%
results = A.search("""
verse book=Jude
  clause
  <parent- phrase
""")
A.show(results, end=1, queryFeatures=True, hiddenTypes={"wg"})
# Out:
#   0.00s 202 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Jude@1:1</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span></div><div class="children hor wrap "><div class="contnr c2    hl" ><div class="lbl c2  hl" ><span class="nd">clause </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="460">parent•</span>
# <span
#     ef="parent"
#     nd="460"
#     md="553"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="460"
#     md="560"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="460"
#     md="1007"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="553">parent•</span>
# <span
#     ef="parent"
#     nd="553"
#     md="554"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="553"
#     md="460"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰούδας </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="parent xft" ><span class="e" edge="parent" nd="1">parent•</span>
# <span
#     ef="parent"
#     nd="1"
#     md="1322"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="554">parent•</span>
# <span
#     ef="parent"
#     nd="554"
#     md="555"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="554"
#     md="557"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="554"
#     md="553"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="555">parent•</span>
# <span
#     ef="parent"
#     nd="555"
#     md="556"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="555"
#     md="554"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="556">parent•</span>
# <span
#     ef="parent"
#     nd="556"
#     md="555"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="parent xft" ><span class="e" edge="parent" nd="2">parent•</span>
# <span
#     ef="parent"
#     nd="2"
#     md="1325"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Χριστοῦ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="parent xft" ><span class="e" edge="parent" nd="3">parent•</span>
# <span
#     ef="parent"
#     nd="3"
#     md="1325"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δοῦλος,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="parent xft" ><span class="e" edge="parent" nd="4">parent•</span>
# <span
#     ef="parent"
#     nd="4"
#     md="1324"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="557">parent•</span>
# <span
#     ef="parent"
#     nd="557"
#     md="558"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="557"
#     md="559"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="557"
#     md="554"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="558">parent•</span>
# <span
#     ef="parent"
#     nd="558"
#     md="557"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀδελφὸς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="parent xft" ><span class="e" edge="parent" nd="5">parent•</span>
# <span
#     ef="parent"
#     nd="5"
#     md="1327"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="559">parent•</span>
# <span
#     ef="parent"
#     nd="559"
#     md="557"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">δὲ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="parent xft" ><span class="e" edge="parent" nd="6">parent•</span>
# <span
#     ef="parent"
#     nd="6"
#     md="1326"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="features"><span class="parent xft" ><span class="e" edge="parent" nd="558">parent•</span>
# <span
#     ef="parent"
#     nd="558"
#     md="557"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰακώβου,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="parent xft" ><span class="e" edge="parent" nd="7">parent•</span>
# <span
#     ef="parent"
#     nd="7"
#     md="1327"
#     arrow="right"
#     clas

# %%
results = A.search("""
verse book=John chapter=1 verse=9
  c1:clause
      p1:phrase function=Subj
      p2:phrase function=Pred

p1 <parent> c1
p2 <parent> c1
""")
A.show(results, start=1, end=1, condensed=True, multiFeatures=False, hiddenTypes={"wg"})
# Out:
#   0.10s 0 results

# %%
results = A.search("""
verse book=John chapter=1 verse=9
    phrase function* role* rule* typ*
        word ref*
""")
A.show(results, start=1, end=1, condensed=True, multiFeatures=False, hiddenTypes={"wg"})
# Out:
#   1.58s 28 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">John@1:9</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="verse xft" ><span class="f">verse=</span>9</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>S-V-ADV</span></div><div class="children hor wrap "><div class="contnr c1   r hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>v</span><span class="rule xft" ><span class="f">rule=</span>BeVerb</span><span class="typ xft" ><span class="f">typ=</span>VP</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="ref xft" ><span class="f">ref=</span>JHN 1:9!1</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">Ἦν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="ref xft" ><span class="f">ref=</span>JHN 1:9!1</span><span class="verse xft" ><span class="f">verse=</span>9</span></div></div></div></div></div></div><div class="contnr c1   rno hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Subj</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>NP-CL</span></div><div class="children hor wrap "><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>DetNP</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="ref xft" ><span class="f">ref=</span>JHN 1:9!2</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">τὸ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="ref xft" ><span class="f">ref=</span>JHN 1:9!2</span><span class="verse xft" ><span class="f">verse=</span>9</span></div></div></div></div><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>NPDetAdj</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="features"><span class="ref xft" ><span class="f">ref=</span>JHN 1:9!3</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">φῶς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="ref xft" ><span class="f">ref=</span>JHN 1:9!3</span><span class="verse xft" ><span class="f">verse=</span>9</span></div></div></div></div><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="rule xft" >< ...

# %%
results = A.search("""
book book=John
  phrase
  -sibling> phrase
""")
A.show(results, start=1, end=1, condensed=True, multiFeatures=False, hiddenTypes={"wg"})
# Out:
#   0.06s 0 results

# %%
results = C.search("""
book book=John
  word
  -sibling>3> word
""")
C.show(results, start=1, end=1, condensed=True, multiFeatures=False, hiddenTypes={"wg"})
# Out:
#   0.28s 13 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/John/1/27&amp;version=0.5.0" title="Show this on the website" sec="John@1:27">John@1:27</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span></div><div class="children hor wrap "><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="sibling xft" ><span class="e" edge="sibling" nd="49414">sibling•</span>
# <span
#     ef="sibling"
#     nd="49414"
#     md="405917"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὀπίσω </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="sibling xft" ><span class="e" edge="sibling" nd="49415">sibling•</span>
# <span
#     ef="sibling"
#     nd="49415"
#     md="49416"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">μου </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="sibling xft" ><span class="e" edge="sibling" nd="49416">sibling•</span>
# <span
#     ef="sibling"
#     nd="49416"
#     md="49415"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>1</span>
# </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐρχόμενος,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="sibling xft" ><span class="e" edge="sibling" nd="49417">sibling•</span>
# <span
#     ef="sibling"
#     nd="49417"
#     md="405918"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>1</span>
# </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">οὗ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="sibling xft" ><span class="e" edge="sibling" nd="49418">sibling•</span>
# <span
#     ef="sibling"
#     nd="49418"
#     md="49419"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="49418"
#     md="49420"
#     arrow="right"
#     class="etf"
# >2<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="49418"
#     md="49421"
#     arrow="right"
#     class="etf"
# >3<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="49418"
#     md="49422"
#     arrow="right"
#     class="etf"
# >4<span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">οὐκ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="sibling xft" ><span class="e" edge="sibling" nd="49419">sibling•</span>
# <span
#     ef="sibling"
#     nd="49419"
#     md="49418"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>1</span>
#
# <span
#     ef="sibling"
#     nd="49419"
#     md="49420"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="49419"
#     md="49421"
#     arrow="right"
#     class="etf"
# >2<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="49419"
#     md="49422"
#     arrow="right"
#     class="etf"
# >3<span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">εἰμὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="sibling xft" ><span class="e" edge="sibling" nd="49420">sibling•</span>
# <span
#     ef="sibling"
#     nd="49420"
#     md="49418"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>2</span>
#
# <span
#     ef="sibling"
#     nd="49420"
#     md="49419"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>1</span>
#
# <span
#     ef="sibling"
#     nd="49420"
#     md="49421"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
#
# <span
#     ef="sibling"
#     nd="49420"
#     md="49422"
#     arrow="right"
#     class="etf"
# >2<span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἐγὼ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="sibling xft" ><span class="e" edge="sibling" nd="49421">sibling•</span>
# <span
#     ef="sibling"
#     nd="49421"
#     md="49418"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>3</span>
#
# <span
#     ef="sibling"
#     nd="49421"
#     md="49419"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>2</span>
#
# <span
#     ef="sibling"
#     nd="49421"
#     md="49420"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>1</span>
#
# <span
#     ef="sibling"
#     nd="49421"
#     md="49422"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span></span>
# </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">ἄξιος </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="sibling xft" ><span class="e" edge="sibling" nd="49422">sibling•</span>
# <span
#     ef="sibling"
#     nd="49422"
#     md="49418"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>4</span>
#
# <span
#     ef="sibling"
#     nd="49422"
#     md="49419"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span>3</span>
#
# <span
#     ef="sibling"
#     nd="49422"
#     md="49420"
#     arrow="lef

# %%
results = A.search('''
verse book=Matthew chapter=6 verse=24
    clause
        phrase typ* function* rela*
                word role*
''')
A.show(results, start=1, end=1, condensed=True, multiFeatures=False, hiddenTypes={"wg"})
# Out:
#   1.25s 28 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr">Matthew@6:24</span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="verse xft" ><span class="f">verse=</span>24</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">clause </span></div><div class="children hor wrap "><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Subj</span><span class="role xft" ><span class="f">role=</span>s</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">Οὐδεὶς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="function xft" ><span class="f">function=</span>Subj</span><span class="role xft" ><span class="f">role=</span>s</span><span class="verse xft" ><span class="f">verse=</span>24</span></div></div></div></div><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>v</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">δύναται </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="role xft" ><span class="f">role=</span>v</span><span class="verse xft" ><span class="f">verse=</span>24</span></div></div></div></div><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">clause </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>o</span></div><div class="children hor wrap "><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Objc</span><span class="role xft" ><span class="f">role=</span>o</span><span class="typ xft" ><span class="f">typ=</span>NP</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">δυσὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="verse xft" ><span class="f">verse=</span>24</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">κυρίοις </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="verse xft" ><span class="f">verse=</span>24</span></div></div></div></div></div></div><div class="contnr c1    hl" ><div class="lbl c1  hl" ><span class="nd">phrase </span></div><div class="features"><span class="role xft" ><span class="f">role=</span>v</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu">δουλεύειν·</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span ...

# %% [markdown]
# # Browse
#
# We are ready to browse the data.
# If you run this notebook, then the next cell will open a browser window with the TF-browser
# on the Greek New Testament.

# %%
X.task(browse=True)

# %% [markdown]
# # Terminate
#
# You can stop the browser by pressing `i` twice.

# %% [markdown]
# # Create zip
#
# It is time to commit and push the repo to GitHub now:
#
# ```
# git add --all .
# git commit "new data version"
# git push origin master
# ```
#
# Then go over to GitHub and create a new release there.
#
# After that, fetch the new tags from GitHub by
#
# ```
# git pull --tags
# ```
#
# Then we are ready to create a zip file for publishing the dataset in a release on Github,
# so that users can get it easily.

# %%
A.zipAll()
# Out:
# Data to be zipped:
# 	missing  app                      (??)                : ~/github/None/None/app
# 	missing  main data                (??)                : ~/github/None/None/tf/0.5.0

# %% [markdown]
# # Fetch
#
# We now test wether users can use this dataset in the normal way.
#
# Run this after you have attached the complete.zip file that we create earlier, to the latest release on GitHub.

# %%
A = use("ETCBC/nestle1904:latest")
# Out:
# **Locating corpus resources ...**
# Status: latest release online <b>v0.4.0</b> versus <b>v0.3.1</b> locally
# downloading app, main data and requested additions ...
# <b title="latest release">app:</b> <span title="rv0.3.1=#gd1847f53703ffeb01670e324cfe60d5cec41dd47">~/text-fabric-data/github/ETCBC/nestle1904/app</span>
# <b title="local release">data:</b> <span title="rv0.4.0=#g61756f28da3d0fdf8053448afbccb9b20607c60c offline under /Users/me/text-fabric-data/github">~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0</span>
#    |     0.17s T otype                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     2.36s T oslots               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.36s T text                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.28s T after                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.28s T book                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.24s T chapter              from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.26s T verse                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |      |     0.05s C __levels__           from otype, oslots, otext
#    |      |     1.47s C __order__            from otype, oslots, __levels__
#    |      |     0.06s C __rank__             from otype, __order__
#    |      |     4.38s C __levUp__            from otype, oslots, __rank__
#    |      |     2.38s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.04s C __characters__       from otext
#    |      |     0.88s C __boundary__         from otype, oslots, __rank__
#    |      |     0.02s C __sections__         from otype, oslots, otext, __levUp__, __levels__, book, chapter, verse
#    |     0.00s T appositioncontainer  from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.11s T articular            from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.18s T case                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.02s T clauseType           from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.61s T cls                  from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.01s T cltype               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.03s T crule                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.00s T degree               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.01s T discontinuous        from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.28s T domain               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.19s T frame                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.08s T framespec            from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.17s T gender               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.35s T gloss                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.38s T id                   from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.08s T junction             from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.00s T lang                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.33s T lemma                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.31s T ln                   from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.07s T mood                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.30s T morph                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.03s T nodeId               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.36s T normalized           from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.00s T note                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.27s T num                  from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.22s T number               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     1.10s T parent               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.05s T person               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.39s T ref                  from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.04s T referent             from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.26s T role                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.37s T rule                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.76s T sibling              from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.27s T strong               from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.06s T subjref              from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.05s T subjrefspec          from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.07s T tense                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.36s T type                 from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.37s T unicode              from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#    |     0.07s T voice                from ~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.4.12</a>, <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/app" title="ETCBC/nestle1904 app">ETCBC/nestle1904/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/about.md" title="provenance of ETCBC - nestle1904/tf">ETCBC - nestle1904 0.4.0</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/greek.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="ETCBC - nestle1904 feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>27</td>
#     <td>5102.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>260</td>
#     <td>529.92</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>7944</td>
#     <td>17.34</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>8011</td>
#     <td>17.20</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>wg</th>
#     <td>114879</td>
#     <td>7.60</td>
#     <td><i>633</i></td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>30152</td>
#     <td>7.37</td>
#     <td><i>161</i></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>42636</td>
#     <td>3.21</td>
#     <td>99</td>
# </tr>
#
# <tr>
#     <th><i>w</i></th>
#     <td>137779</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>ETCBC - nestle1904/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> material after the end of the word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/appositioncontainer.tf">appositioncontainer</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if it is an apposition container</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/articular.tf">articular</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the wg has an article</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> book name (abbreviated), from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/case.tf">case</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> chapter number, from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/clauseType.tf">clauseType</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/cls.tf">cls</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute cls</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/cltype.tf">cltype</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type for verbless, verb-elided, and minor clauses</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/crule.tf">crule</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause rule (from xml attribute Rule)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/degree.tf">degree</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical degree</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/discontinuous.tf">discontinuous</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the word is out of sequence in the xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/domain.tf">domain</a>
# </div>
# <div class="fmono">str</div>
#
# <span> domain</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/framespec.tf">framespec</a>
# </div>
# <div class="fmono">str</div>
#
# <span> this is XML attribute framespec</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/gender.tf">gender</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/gloss.tf">gloss</a>
# </div>
# <div class="fmono">str</div>
#
# <span> short translation</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/id.tf">id</a>
# </div>
# <div class="fmono">str</div>
#
# <span> xml id</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/junction.tf">junction</a>
# </div>
# <div class="fmono">str</div>
#
# <span> type of junction</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/text-fabric-data/github/ETCBC/nestle1904/tf/0.4.0/lang.tf">lang</a>
# </div>
# <div class="fmono">str</div>
#
# <span> lan
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>

# %% [markdown]
# Indeed, downloading and installing went without hassle.

# %% [markdown]
# # Demo
#
# We demo the effect of the reshuffling of the words.
#
# Our test corpus is the letter of Jude, first sentence, twice.
#
# The first time we do not shuffle the words in the sentence, the second time we do.
#
# We run the conversion with `demo = True` in `lowfat.py`.

# %%
X = XML(
    convertTaskCustom=convertTaskCustom,
    keywordAtts=keywordAtts,
    trimAtts=trimAtts,
    renameAtts=renameAtts,
    verbose=1,
    xml=-1,
    tf="0.3.1t",
)
# Out:
# Working in repository ETCBC/nestle1904 in backend github
# XML data version is 2000-01-01 (oldest)
# TF data version is 0.3.1t (explicit new)

# %%
X.task(convert=True, load=True, app=True)
# Out:
# XML to TF converting: ~/github/ETCBC/nestle1904/xml/2000-01-01 => ~/github/ETCBC/nestle1904/tf/0.3.1t
#   0.00s Not all of the warp features otype and oslots are present in
# ~/github/ETCBC/nestle1904/tf/0.3.1t
#   0.00s Only the Feature and Edge APIs will be enabled
#   0.00s Warp feature "otext" not found. Working without Text-API
#
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s No structure nodes will be set up
#    |   SECTION   TYPES:    book, chapter, verse
#    |   SECTION   FEATURES: book, chapter, verse
#    |   STRUCTURE TYPES:
#    |   STRUCTURE FEATURES:
#    |   TEXT      FEATURES:
#    |      |   text-orig-full       after, text
#    |     0.00s OK
#    |     0.00s Following director...
#    1 26-jude.xml
# source reading done
#    |     0.00s "edge" actions: 0
#    |     0.00s "feature" actions: 71
#    |     0.00s "node" actions: 39
#    |     0.00s "resume" actions: 0
#    |     0.00s "slot" actions: 34
#    |     0.00s "terminate" actions: 39
#    |          1 x "book" node
#    |          1 x "chapter" node
#    |          2 x "sentence" node
#    |          1 x "verse" node
#    |         34 x "w" node  = slot type
#    |         34 x "wg" node
#    |         73 nodes of all types
#    |     0.01s OK
#    |     0.00s checking for nodes and edges ...
#    |     0.00s OK
#    |     0.00s checking (section) features ...
#    |     0.00s OK
#    |     0.00s reordering nodes ...
#    |     0.00s Sorting 34 slots (node type "w")
#    |     0.00s Sorting 1 nodes of type "book"
#    |     0.00s Sorting 1 nodes of type "chapter"
#    |     0.00s Sorting 2 nodes of type "sentence"
#    |     0.00s Sorting 1 nodes of type "verse"
#    |     0.00s Sorting 34 nodes of type "wg"
#    |     0.00s Max node = 73
#    |     0.00s OK
#    |     0.00s reassigning feature values ...
#    |      |   node feature "after" with 34 nodes
#    |      |   node feature "appositioncontainer" with 8 nodes
#    |      |   node feature "articular" with 2 nodes
#    |      |   node feature "book" with 35 nodes
#    |      |   node feature "case" with 28 nodes
#    |      |   node feature "chapter" with 35 nodes
#    |      |   node feature "class" with 50 nodes
#    |      |   node feature "clauseType" with 2 nodes
#    |      |   node feature "cltype" with 2 nodes
#    |      |   node feature "discontinuous" with 2 nodes
#    |      |   node feature "domain" with 28 nodes
#    |      |   node feature "frame" with 4 nodes
#    |      |   node feature "gender" with 28 nodes
#    |      |   node feature "gloss" with 34 nodes
#    |      |   node feature "junction" with 6 nodes
#    |      |   node feature "lang" with 1 node
#    |      |   node feature "lemma" with 34 nodes
#    |      |   node feature "ln" with 28 nodes
#    |      |   node feature "mood" with 4 nodes
#    |      |   node feature "morph" with 34 nodes
#    |      |   node feature "normalized" with 34 nodes
#    |      |   node feature "num" with 37 nodes
#    |      |   node feature "number" with 28 nodes
#    |      |   node feature "ref" with 34 nodes
#    |      |   node feature "role" with 14 nodes
#    |      |   node feature "rule" with 28 nodes
#    |      |   node feature "strong" with 34 nodes
#    |      |   node feature "subjref" with 4 nodes
#    |      |   node feature "tense" with 4 nodes
#    |      |   node feature "text" with 34 nodes
#    |      |   node feature "type" with 42 nodes
#    |      |   node feature "unicode" with 34 nodes
#    |      |   node feature "verse" with 35 nodes
#    |      |   node feature "voice" with 4 nodes
#    |     0.01s OK
#   0.02s Features ready to write
#   0.00s Exporting 35 node and 1 edge and 1 config features to ~/github/ETCBC/nestle1904/tf/0.3.1t:
#   0.00s VALIDATING oslots feature
#   0.00s VALIDATING oslots feature
#   0.00s maxSlot=         34
#   0.00s maxNode=         73
#   0.00s OK: oslots is valid
#    |     0.00s T after                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T appositioncontainer  to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T articular            to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T book                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T case                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T chapter              to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T class                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T clauseType           to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T cltype               to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T discontinuous        to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T domain               to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T frame                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T gender               to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T gloss                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T junction             to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T lang                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T lemma                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T ln                   to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T mood                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T morph                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T normalized           to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T num                  to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T number               to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T otype                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T ref                  to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T role                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T rule                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T strong               to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T subjref              to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T tense                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T text                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T type                 to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T unicode              to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T verse                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T voice                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T oslots               to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s M otext                to ~/github/ETCBC/nestle1904/tf/0.3.1t
#   0.03s Exported 35 node features and 1 edge features and 1 config features to ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T otype                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T oslots               from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T verse                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T after                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T book                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T text                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |     0.00s T chapter              from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s C __levels__           from otype, oslots, otext
#    |      |     0.00s C __order__            from otype, oslots, __levels__
#    |      |     0.00s C __rank__             from otype, __order__
#    |      |     0.00s C __levUp__            from otype, oslots, __rank__
#    |      |     0.00s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.00s C __characters__       from otext
#    |      |     0.00s C __boundary__         from otype, oslots, __rank__
#    |      |     0.00s C __sections__         from otype, oslots, otext, __levUp__, __levels__, book, chapter, verse
#    |      |     0.00s T appositioncontainer  from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T articular            from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T case                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T class                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T clauseType           from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T cltype               from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T discontinuous        from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T domain               from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T frame                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T gender               from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T gloss                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T junction             from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T lang                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T lemma                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T ln                   from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T mood                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T morph                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T normalized           from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T num                  from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T number               from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T ref                  from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T role                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T rule                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T strong               from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T subjref              from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T tense                from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T type                 from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T unicode              from ~/github/ETCBC/nestle1904/tf/0.3.1t
#    |      |     0.00s T voice                from ~/github/ETCBC/nestle1904/tf/0.3.1t
# max node = 73
# App updating ...
# 	~/github/ETCBC/nestle1904/app/static/logo.png (already exists, not overwritten)
# 	~/github/ETCBC/nestle1904/app/static/display.css (no custom info, older orginal exists)
# 	~/github/ETCBC/nestle1904/app/config.yaml (generated with custom info)
# 	~/github/ETCBC/nestle1904/app/app.py (deleted)
# Done
# True

# %%
A = use("ETCBC/nestle1904:clone", checkout="clone", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/nestle1904/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/me/github">~/github/ETCBC/nestle1904/tf/0.3.1t</span>
#             <b>Text-Fabric:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric-api">Text-Fabric API 11.4.11</a>, <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/app" title="ETCBC/nestle1904 app">ETCBC/nestle1904/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/about.md" title="provenance of ETCBC - nestle1904/tf">ETCBC - nestle1904 0.3.1t</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/greek.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="ETCBC - nestle1904 feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots/node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>1</td>
#     <td>34.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>1</td>
#     <td>34.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>1</td>
#     <td>34.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>2</td>
#     <td>17.00</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>wg</th>
#     <td>34</td>
#     <td>6.00</td>
#     <td><i>600</i></td>
# </tr>
#
# <tr>
#     <th><i>w</i></th>
#     <td>34</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b>ETCBC - nestle1904/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/after.tf">after</a>
# </div>
# <div class="fmono">str</div>
#
# <span> material after the end of the word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/appositioncontainer.tf">appositioncontainer</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if it is an apposition container</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/articular.tf">articular</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the wg has an article</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/book.tf">book</a>
# </div>
# <div class="fmono">str</div>
#
# <span> book name (abbreviated), from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/case.tf">case</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/chapter.tf">chapter</a>
# </div>
# <div class="fmono">int</div>
#
# <span> chapter number, from ref attribute in xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/class.tf">class</a>
# </div>
# <div class="fmono">str</div>
#
# <span> morphological class (on w); syntactical class (on wg)</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/clauseType.tf">clauseType</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/cltype.tf">cltype</a>
# </div>
# <div class="fmono">str</div>
#
# <span> clause type</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/discontinuous.tf">discontinuous</a>
# </div>
# <div class="fmono">int</div>
#
# <span> 1 if the word is out of sequence in the xml</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/domain.tf">domain</a>
# </div>
# <div class="fmono">str</div>
#
# <span> domain</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/frame.tf">frame</a>
# </div>
# <div class="fmono">str</div>
#
# <span> frame</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/gender.tf">gender</a>
# </div>
# <div class="fmono">str</div>
#
# <span> grammatical gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/gloss.tf">gloss</a>
# </div>
# <div class="fmono">str</div>
#
# <span> short translation</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/junction.tf">junction</a>
# </div>
# <div class="fmono">str</div>
#
# <span> type of junction</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/lang.tf">lang</a>
# </div>
# <div class="fmono">str</div>
#
# <span> language the text is in</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/lemma.tf">lemma</a>
# </div>
# <div class="fmono">str</div>
#
# <span> lexical lemma</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/ln.tf">ln</a>
# </div>
# <div class="fmono">str</div>
#
# <span> ln</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/mood.tf">mood</a>
# </div>
# <div class="fmono">str</div>
#
# <span> verbal mood</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/morph.tf">morph</a>
# </div>
# <div class="fmono">str</div>
#
# <span> morphological code</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/ETCBC/nestle1904/blob/main/docs/transcription.md" title="~/github/ETCBC/nestle1904/tf/0.3.1t/normalized.tf">normalized</a>
# </div>
# <div class="fmono">str</div>
#
# <span> lemma nor
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/server/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/server/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/server/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/server/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/server/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/server/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/server/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/server/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/server/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .lex {
#   color: var(--lex-color);;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .contnr.trm {
#     background-attachment: local;
# }
# .contnr.cnul {
#     padding:  0;
#     margin: 0;
#     border-style: solid;
#     font-size: xx-small;
# }
# .contnr.cnul,.lbl.cnul {
#     border-color: var(--border-color-nul);
#     border-width: var(--border-width-nul);
#     border-radius: var(--border-width-nul);
# }
# .contnr.c0,.lbl.c0 {
#     border-color: var(--border-color0);
#     border-width: var(--border-width0);
#     border-radius: var(--border-width0);
# }
# .contnr.c1,.lbl.c1 {
#     border-color: var(--border-color1);
#     border-width: var(--border-width1);
#     border-radius: var(--border-width1);
# }
# .contnr.c2,.lbl.c2 {
#     border-color: var(--border-color2);
#     border-width: var(--border-width2);
#     border-radius: var(--border-width2);
# }
# .contnr.c3,.lbl.c3 {
#     border-color: var(--border-
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>Text-Fabric API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF</a> directly usable</div><hr>

# %%
(s1, s2) = F.otype.s("sentence")

# %%
color1 = "cyan"
color2 = "goldenrod"
start = 5
offset = 17
highlights = {
    start: color1,
    start + 1: color2,
    start + offset: color2,
    start + offset + 1: color1,
}
A.displaySetup(standardFeatures=True, highlights=highlights)

# %%
A.pretty(s1)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.ETCBC.org/nestle1904/JUD/1/1&amp;version=0.3.1t" title="Show this on the website" sec="JUD@1:1">JUD@1:1</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰούδας </span></div><div class="features"><span class="num " title="num">1</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰησοῦ </span></div><div class="features"><span class="num " title="num">2</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Χριστοῦ </span></div><div class="features"><span class="num " title="num">3</span></div></div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">δοῦλος,</span></div><div class="features"><span class="num " title="num">4</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: cyan;" ><div class="lbl c0 trm hl"  style="background-color: cyan;" ><span class="txtu grc">δὲ </span></div><div class="features"><span class="num " title="num">6</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: goldenrod;" ><div class="lbl c0 trm hl"  style="background-color: goldenrod;" ><span class="txtu grc">ἀδελφὸς </span></div><div class="features"><span class="num " title="num">5</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰακώβου,</span></div><div class="features"><span class="num " title="num">7</span></div></div></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τοῖς </span></div><div class="features"><span class="num " title="num">8</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐν </span></div><div class="features"><span class="num " title="num">9</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Θεῷ </span></div><div class="features"><span class="num " title="num">10</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Πατρὶ < ...

# %%
A.pretty(s2)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.ETCBC.org/nestle1904/JUD/1/1&amp;version=0.3.1t" title="Show this on the website" sec="JUD@1:1">JUD@1:1</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰούδας </span></div><div class="features"><span class="num " title="num">1</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰησοῦ </span></div><div class="features"><span class="num " title="num">2</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Χριστοῦ </span></div><div class="features"><span class="num " title="num">3</span></div></div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">δοῦλος,</span></div><div class="features"><span class="num " title="num">4</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: goldenrod;" ><div class="lbl c0 trm hl"  style="background-color: goldenrod;" ><span class="txtu grc">ἀδελφὸς </span></div><div class="features"><span class="num " title="num">5</span></div></div></div></div><div class="contnr c0 trm   hl"  style="background-color: cyan;" ><div class="lbl c0 trm hl"  style="background-color: cyan;" ><span class="txtu grc">δὲ </span></div><div class="features"><span class="num " title="num">6</span></div></div><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰακώβου,</span></div><div class="features"><span class="num " title="num">7</span></div></div></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τοῖς </span></div><div class="features"><span class="num " title="num">8</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐν </span></div><div class="features"><span class="num " title="num">9</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Θεῷ </span></div><div class="features"><span cla ...

# %% [markdown]
# # Restore
#
# We restore the app so that it uses the normal tf version again.

# %%
X = XML(
    convertTaskCustom=convertTaskCustom,
    keywordAtts=keywordAtts,
    trimAtts=trimAtts,
    renameAtts=renameAtts,
    verbose=1,
    tf="0.3.1",
)
# Out:
# Working in repository ETCBC/nestle1904 in backend github
# XML data version is 2022-11-01 (most recent)
# TF data version is 0.3.1 (explicit existing)

# %%
X.task(app=True)
# Out:
# App updating ...
# 	~/github/ETCBC/nestle1904/app/static/logo.png (already exists, not overwritten)
# 	~/github/ETCBC/nestle1904/app/static/display.css (no custom info, older orginal exists)
# 	~/github/ETCBC/nestle1904/app/config.yaml (generated with custom info)
# 	~/github/ETCBC/nestle1904/app/app.py (deleted)
# Done
# True

# %% [markdown]
# Now save this notebook, commit and push the repo again to publish this very notebook.
#
# ```
# git add --all .
# git commit "maker notebook updated"
# git push origin master
# ```
