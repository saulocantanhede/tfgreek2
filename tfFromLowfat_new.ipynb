# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf.convert.xml import XML
from lowfat import convertTaskCustom
from tf.advanced.helpers import dm
from tf.advanced.zipdata import zipAll, addCheckout
from tf.app import use
color = {1: "#47edff", 2: "#81ee93", 3: "#eaff47", 4: "#ffcb47", 5: "#ffa647", 6: "#ff7b47", 7: "#ff479d", 8: "#ff4747", 9: "#477eff", 10: "#a647ff"}

# %%
keywordAtts = set(
    """
    case
    class
    number
    gender
    mood
    person
    role
    tense
    type
    voice
    degree
    articular
""".strip().split()
)

trimAtts = set(
    """
    domain
    frame
    gloss
    id
    lemma
    ln
    morph
    normalized
    ref
    referent
    rule
    strong
    subjref
    unicode
""".strip().split()
)

# %%
renameAtts = {
    "Rule": "crule",
    "frame": "framespec",
    "subjref": "subjrefspec",
    "class": "cls",
    "type": "typems",
}

# %%
X = XML(
    convertTaskCustom=convertTaskCustom,
    keywordAtts=keywordAtts,
    trimAtts=trimAtts,
    renameAtts=renameAtts,
    verbose=1,
    xml=0,
    tf="1.0.0"
)
# Out:
# Working in repository XML-nestle1904/programs in back-end Downloads
# XML data version is 2022-11-01 (most recent)
# TF data version is 1.0.0 (explicit new)
# Processing instructions will be ignored

# %%
X = XML(
    convertTaskCustom=convertTaskCustom,
    keywordAtts=keywordAtts,
    trimAtts=trimAtts,
    renameAtts=renameAtts,
    verbose=1,
    xml="2000-01-01",
    tf="0.5.10"
)
# Out:
# Working in repository XML-nestle1904/programs in back-end Downloads
# XML data version is 2000-01-01 (oldest)
# TF data version is 0.5.10 (explicit existing)
# Processing instructions will be ignored

# %%
X.task(convert=True)
X.task(load=True)
X.task(app=True)
# Out:
# XML to TF converting: ~/Downloads/XML-nestle1904/programs/xml/2022-11-01 => ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#   0.00s Not all of the warp features otype and oslots are present in
# ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#   0.00s Only the Feature and Edge APIs will be enabled
#   0.00s Warp feature "otext" not found. Working without Text-API
#
#   0.00s Importing data from walking through the source ...
#    |     0.00s Preparing metadata...
#    |     0.00s No structure nodes will be set up
#    |   SECTION   TYPES:    book, chapter, verse
#    |   SECTION   FEATURES: book, chapter, verse
#    |   STRUCTURE TYPES:
#    |   STRUCTURE FEATURES:
#    |   TEXT      FEATURES:
#    |      |   lex-orig-plain       lemma, trailer
#    |      |   lex-translit-plain   lemmatranslit, trailer
#    |      |   text-orig-full       after, before, text
#    |      |   text-orig-plain      text, trailer
#    |      |   text-translit-plain  trailer, translit
#    |      |   text-unaccent-plain  trailer, unaccent
#    |     0.01s OK
#    |     0.00s Following director...
#   27 27-revelation.xml
# There are no broken subjref references.
# There are 9 broken frame references.
# gnt/01-matthew.xml            : n40003016026, n40004024030
# gnt/03-luke.xml               : n42001054008, n42001054011
# gnt/04-john.xml               : n43019024036
# gnt/07-1corinthians.xml       : n46012026017
# gnt/09-galatians.xml          : n48005007009
# gnt/10-ephesians.xml          : n49005014021, n49005019017
# source reading done
#    |    5m 09s "delete" actions: 0
#    |    5m 09s "edge" actions: 6977842
#    |    5m 09s "feature" actions: 497525
#    |    5m 09s "node" actions: 359746
#    |    5m 09s "resume" actions: 0
#    |    5m 09s "slot" actions: 137779
#    |    5m 09s "terminate" actions: 497525
#    |         27 x "book" node
#    |        260 x "chapter" node
#    |      42506 x "clause" node
#    |       8945 x "group" node
#    |      69007 x "phrase" node
#    |       8011 x "sentence" node
#    |     116178 x "subphrase" node
#    |       7944 x "verse" node
#    |     106868 x "wg" node
#    |     137779 x "word" node  = slot type
#    |     497525 nodes of all types
#    |    5m 09s OK
#    |     0.00s checking for nodes and edges ...
#    |     1.43s OK
#    |     0.00s checking (section) features ...
#    |     3.75s OK
#    |     0.00s reordering nodes ...
#    |     0.00s Sorting 137779 slots (node type "word")
#    |     1.96s Sorting 27 nodes of type "book"
#    |     1.97s Sorting 260 nodes of type "chapter"
#    |     1.98s Sorting 42506 nodes of type "clause"
#    |     2.09s Sorting 8945 nodes of type "group"
#    |     2.11s Sorting 69007 nodes of type "phrase"
#    |     2.27s Sorting 8011 nodes of type "sentence"
#    |     2.30s Sorting 116178 nodes of type "subphrase"
#    |     2.65s Sorting 7944 nodes of type "verse"
#    |     2.68s Sorting 106868 nodes of type "wg"
#    |     3.28s Max node = 497525
#    |     3.28s OK
#    |     0.00s reassigning feature values ...
#    |      |   node feature "after" with 275558 nodes
#    |      |   node feature "appositioncontainer" with 3816 nodes
#    |      |   node feature "articular" with 57544 nodes
#    |      |   node feature "before" with 68 nodes
#    |      |   node feature "book" with 497525 nodes
#    |      |   node feature "bookshort" with 489321 nodes
#    |      |   node feature "case" with 159036 nodes
#    |      |   node feature "chapter" with 497498 nodes
#    |      |   node feature "clausetype" with 10592 nodes
#    |      |   node feature "cls" with 421134 nodes
#    |      |   node feature "cltype" with 5686 nodes
#    |      |   node feature "criticalsign" with 126 nodes
#    |      |   node feature "crule" with 11116 nodes
#    |      |   node feature "degree" with 1026 nodes
#    |      |   node feature "discontinuous" with 12068 nodes
#    |      |   node feature "domain" with 253758 nodes
#    |      |   node feature "framespec" with 50986 nodes
#    |      |   node feature "function" with 182706 nodes
#    |      |   node feature "gender" with 147950 nodes
#    |      |   node feature "gloss" with 275558 nodes
#    |      |   node feature "id" with 275558 nodes
#    |      |   node feature "junction" with 35842 nodes
#    |      |   node feature "lang" with 27 nodes
#    |      |   node feature "lemma" with 275558 nodes
#    |      |   node feature "lemmatranslit" with 275558 nodes
#    |      |   node feature "ln" with 253758 nodes
#    |      |   node feature "mood" with 56714 nodes
#    |      |   node feature "morph" with 275558 nodes
#    |      |   node feature "nodeid" with 11116 nodes
#    |      |   node feature "normalized" with 275558 nodes
#    |      |   node feature "note" with 2 nodes
#    |      |   node feature "num" with 489321 nodes
#    |      |   node feature "number" with 197874 nodes
#    |      |   node feature "person" with 38838 nodes
#    |      |   node feature "punctuation" with 37018 nodes
#    |      |   node feature "ref" with 275558 nodes
#    |      |   node feature "referent" with 28942 nodes
#    |      |   node feature "rela" with 1958 nodes
#    |      |   node feature "role" with 168436 nodes
#    |      |   node feature "rule" with 186468 nodes
#    |      |   node feature "sp" with 275558 nodes
#    |      |   node feature "strong" with 275558 nodes
#    |      |   node feature "subjrefspec" with 33150 nodes
#    |      |   node feature "tense" with 56714 nodes
#    |      |   node feature "text" with 275558 nodes
#    |      |   node feature "trailer" with 275558 nodes
#    |      |   node feature "trans" with 275558 nodes
#    |      |   node feature "translit" with 275558 nodes
#    |      |   node feature "typ" with 103466 nodes
#    |      |   node feature "typems" with 226336 nodes
#    |      |   node feature "unaccent" with 275558 nodes
#    |      |   node feature "unicode" with 275558 nodes
#    |      |   node feature "variant" with 338 nodes
#    |      |   node feature "verse" with 497238 nodes
#    |      |   node feature "voice" with 56714 nodes
#    |      |   edge feature "frame" with 25491 start nodes
#    |      |   edge feature "parent" with 373115 start nodes
#    |      |   edge feature "sibling" with 171862 start nodes
#    |      |   edge feature "subjref" with 16575 start nodes
#    |     7.34s OK
#  5m 25s Features ready to write
#   0.00s Exporting 56 node and 5 edge and 1 configuration features to ~/Downloads/XML-nestle1904/programs/tf/1.0.0:
#   0.00s VALIDATING oslots feature
#   0.04s VALIDATING oslots feature
#   0.04s maxSlot=     137779
#   0.04s maxNode=     497525
#   0.10s OK: oslots is valid
#    |     0.28s T after                to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.01s T appositioncontainer  to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.06s T articular            to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.00s T before               to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.51s T book                 to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.54s T bookshort            to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.20s T case                 to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.53s T chapter              to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.01s T clausetype           to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.48s T cls                  to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.01s T cltype               to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.00s T criticalsign         to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.02s T crule                to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.00s T degree               to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.01s T discontinuous        to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.30s T domain               to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.07s T framespec            to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.20s T function             to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.18s T gender               to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.31s T gloss                to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.32s T id                   to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.05s T junction             to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.00s T lang                 to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.36s T lemma                to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.31s T lemmatranslit        to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.29s T ln                   to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.07s T mood                 to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.31s T morph                to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.02s T nodeid               to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.36s T normalized           to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.00s T note                 to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.47s T num                  to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.23s T number               to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.12s T otype                to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.04s T person               to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.04s T punctuation          to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.32s T ref                  to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.06s T referent             to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.00s T rela                 to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.19s T role                 to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.22s T rule                 to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.29s T sp                   to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.30s T strong               to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.04s T subjrefspec          to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.07s T tense                to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.36s T text                 to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.28s T trailer              to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.32s T trans                to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.31s T translit             to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.11s T typ                  to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.28s T typems               to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.35s T unaccent             to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.36s T unicode              to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.00s T variant              to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.53s T verse                to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.07s T voice                to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.14s T frame                to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     1.07s T oslots               to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.95s T parent               to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |       19s T sibling              to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.06s T subjref              to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.00s M otext                to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#     32s Exported 56 node features and 5 edge features and 1 config features to ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.75s T otype                from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     9.28s T oslots               from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     1.77s T unaccent             from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     1.49s T after                from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     1.62s T lemmatranslit        from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     1.80s T text                 from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     1.50s T trailer              from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     1.73s T lemma                from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     1.72s T translit             from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     0.00s T before               from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     2.77s T book                 from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     2.39s T verse                from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |     2.32s T chapter              from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.24s C __levels__           from otype, oslots, otext
#    |      |     5.62s C __order__            from otype, oslots, __levels__
#    |      |     0.23s C __rank__             from otype, __order__
#    |      |       19s C __levUp__            from otype, oslots, __rank__
#    |      |       10s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.50s C __characters__       from otext
#    |      |     2.84s C __boundary__         from otype, oslots, __rank__
#    |      |     0.06s C __sections__         from otype, oslots, otext, __levUp__, __levels__, book, chapter, verse
#    |      |     0.02s T appositioncontainer  from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.30s T articular            from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     2.66s T bookshort            from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.96s T case                 from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.07s T clausetype           from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     2.36s T cls                  from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.04s T cltype               from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.00s T criticalsign         from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.07s T crule                from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.01s T degree               from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.07s T discontinuous        from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     1.48s T domain               from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.48s T frame                from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.39s T framespec            from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     1.07s T function             from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.87s T gender               from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     1.77s T gloss                from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     1.95s T id                   from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.22s T junction             from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.00s T lang                 from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     1.62s T ln                   from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.35s T mood                 from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     1.61s T morph                from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.09s T nodeid               from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     1.82s T normalized           from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.00s T note                 from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     2.48s T num                  from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     1.18s T number               from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     4.33s T parent               from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.26s T person               from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.23s T punctuation          from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     1.91s T ref                  from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.21s T referent             from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.01s T rela                 from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.96s T role                 from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     1.13s T rule                 from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |       42s T sibling              from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     1.53s T sp                   from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     1.39s T strong               from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.15s T subjref              from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.24s T subjrefspec          from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.36s T tense                from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     1.73s T trans                from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.62s T typ                  from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     1.38s T typems               from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     1.87s T unicode              from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.00s T variant              from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
#    |      |     0.36s T voice                from ~/Downloads/XML-nestle1904/programs/tf/1.0.0
# max node = 497525
# App updating ...
# 	~/Downloads/XML-nestle1904/programs/app/static/logo.png (already exists, not overwritten)
# 	~/Downloads/XML-nestle1904/programs/app/static/display.css (no custom info, older original exists)
# 	~/Downloads/XML-nestle1904/programs/app/config.yaml (generated with custom info)
# 	~/Downloads/XML-nestle1904/programs/app/app.py (deleted)
# Done
# True

# %%
#A = use("saulocantanhede/tfgreek2", version="0.1.1", hoist=globals())
#N1904 = use("app:~/Downloads/XML-nestle1904/programs/app", locations="/Users/saulo/Downloads/XML-nestle1904/programs/tf", version="1.0.0", hoist=globals())
#B = use("app:~/Downloads/XML-nestle1904/programs/app", locations="/Users/saulo/Downloads/XML-nestle1904/programs/tf", version="0.5.8", hoist=globals())
#B = use("app:~/Downloads/XML-nestle1904/programs/app", version="0.5.7", hoist=globals())
#N1904 = use("saulocantanhede/tfgreek2", version="0.5.7", mod="saulocantanhede/tfgreek2/BOLcomplement/tf", hoist=globals())
#N1904 = use("saulocantanhede/tfgreek2:clone", version="0.5.9", checkout="clone", mod="saulocantanhede/tfgreek2/BOLcomplement/tf:clone", hoist=globals())
N1904 = use("CenterBLC/N1904:clone", version="1.0.0", checkout="clone", mod="CenterBLC/N1904/BOLcomplement/tf:clone", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/saulo/github">~/github/CenterBLC/N1904/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/saulo/github">~/github/CenterBLC/N1904/tf/1.0.0</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/saulo/github">~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0</span>
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.5.1</a>, <a target="_blank" href="https://github.com/CenterBLC/N1904/blob/main/app" title="CenterBLC/N1904 app">CenterBLC/N1904/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/tree/main/docs/about.md" title="provenance of Nestle 1904 Greek New Testament">CenterBLC - N1904 1.0.0</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/greek.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/tree/main/docs/features/README.md" title="CenterBLC - N1904 feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>27</td>
#     <td>5102.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>260</td>
#     <td>529.92</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>7944</td>
#     <td>17.34</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>8011</td>
#     <td>17.20</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>group</th>
#     <td>8945</td>
#     <td>7.01</td>
#     <td>46</td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>42506</td>
#     <td>8.36</td>
#     <td><i>258</i></td>
# </tr>
#
# <tr>
#     <th>wg</th>
#     <td>106868</td>
#     <td>6.88</td>
#     <td><i>533</i></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>69007</td>
#     <td>1.90</td>
#     <td>95</td>
# </tr>
#
# <tr>
#     <th>subphrase</th>
#     <td>116178</td>
#     <td>1.60</td>
#     <td><i>135</i></td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>137779</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b><github>CenterBLC/N1904/BOLcomplement/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AU_declension.tf">AU_declension</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Andrews University declension selection for exercises</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AU_exercise_selection.tf">AU_exercise_selection</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Andrews University declension selection for exercises</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AU_vocab_builder_chapter.tf">AU_vocab_builder_chapter</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Andrews University vocab builder booklet chapter</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AlandSynopChapter.tf">AlandSynopChapter</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Aland Synoptic Parallel Chapter</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AlandSynopChapterNr.tf">AlandSynopChapterNr</a>
# </div>
# <div class="fmono">int</div>
#
# <span> Aland Synoptic Parallel Number</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AlandSynopEvent.tf">AlandSynopEvent</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Aland Synoptic Parallel Event</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AlandSynopEventNr.tf">AlandSynopEventNr</a>
# </div>
# <div class="fmono">int</div>
#
# <span> Aland Synoptic Parallel Event</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AlandSynopNo.tf">AlandSynopNo</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Aland Synoptic Parallel Number</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/BGVB.tf">BGVB</a>
# </div>
# <div class="fmono">str</div>
#
# <span> chapter categoried vocab as it appears in Larry Richards Textbook "Learning Greek in 30 days"</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/abc_order.tf">abc_order</a>
# </div>
# <div class="fmono">int</div>
#
# <span> the dictionary position of a given word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_case.tf">bol_case</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_dict_abc.tf">bol_dict_abc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based dictionary position of a given word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_frequency_rank.tf">bol_frequency_rank</a>
# </div>
# <div class="fmono">int</div>
#
# <span> Bible Online Learner based frequency rank of a given lexeme</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_gender.tf">bol_gender</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_gloss_EN.tf">bol_gloss_EN</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based English gloss</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_gloss_PT.tf">bol_gloss_PT</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based Portuguese gloss</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_lemma.tf">bol_lemma</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based lexeme</span>
#
# </div>
#
# <div class="frow">
#     <div class="fn
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# Display is setup for viewtype [syntax-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/syntax-view.md#start)
# See [here](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/viewtypes.md#start) for more information on viewtypes

# %%
results = A.search("""
w lemma=δέ
""")
A.show(results, end=2, condensed=True, multiFeatures=False, queryFeatures=False, withNodes=False)
# Out:
#   0.14s 2787 results
# <p><b>sentence</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/MAT/1/2&amp;version=0.1.1" title="Show this on the website" sec="MAT@1:2">MAT@1:2</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἀβραὰμ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐγέννησεν </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τὸν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰσαάκ,,</span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu grc">δὲ </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰσαὰκ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐγέννησεν </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τὸν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰακώβ,,</span></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu grc">δὲ </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰακὼβ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐγέννησεν </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τὸν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰούδαν </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">καὶ </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τοὺς </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἀδελφοὺς </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">αὐτοῦ,,</span></div></div></div></div></div></div></div></div></div></div ...
# <p><b>sentence</b> <i>2</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://public.saulocantanhede.org/tfgreek2/MAT/1/6&amp;version=0.1.1" title="Show this on the website" sec="MAT@1:6">MAT@1:6</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu grc">δὲ </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Δαυεὶδ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐγέννησεν </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τὸν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Σολομῶνα </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐκ </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τῆς </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τοῦ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Οὐρίου,,</span></div></div></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu grc">δὲ </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Σολομὼν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐγέννησεν </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τὸν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ῥοβοάμ,,</span></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu grc">δὲ </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ῥοβοὰμ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐγέννησεν </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τὸν </span></div></div><div class="contnr c0 t ...

# %%
N1904.viewtype("wg")
results = N1904.search("""
verse book=Mark chapter=1 verse=1
""")
N1904.show(results, end=2, condensed=True, multiFeatures=False, queryFeatures=False, withNodes=False, colorMap=color, condenseType='verse')
# Out:
# Display is setup for viewtype [wg-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/wg-view.md#start)
#   0.01s 1 result
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/1/1" title="Show this on the website" sec="Mark 1:1">Mark 1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Mark</span> <span title="chapter">1</span>:<span title="verse">1</span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="rule">P2CL</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="typems"></span> <span title="role"></span> <span title="rule">P2CL</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="typems">modifier-scope</span> <span title="role">p</span> <span title="rule">NPofNP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἀρχὴ </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="typems">modifier-scope</span> <span title="role"></span> <span title="rule">DetNP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τοῦ </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="typems">modifier-scope</span> <span title="role"></span> <span title="rule">NPofNP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">εὐαγγελίου </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="typems">group</span> <span title="role"></span> <span title="rule">Np-Appos</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="typems">group</span> <span title="role"></span> <span title="rule">Np-Appos</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰησοῦ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Χριστοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="typems">modifier-scope</span> <span title="role">apposition</span> <span title="rule">NPofNP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">(Υἱοῦ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Θεοῦ). </span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div>

# %%
for formats in T.formats:
    print(f'fmt={formats}\t: {T.text(383782,formats)}')
# Out:
# fmt=lex-orig-plain	: ἀρχή ὁ εὐαγγέλιον Ἰησοῦς Χριστός υἱός θεός.
# fmt=lex-translit-plain	: arkhe o euaggelion Iesous Khristos uios theos.
# fmt=text-orig-full	: Ἀρχὴ τοῦ εὐαγγελίου Ἰησοῦ Χριστοῦ (Υἱοῦ Θεοῦ).
# fmt=text-orig-plain	: Ἀρχὴ τοῦ εὐαγγελίου Ἰησοῦ Χριστοῦ Υἱοῦ Θεοῦ.
# fmt=text-translit-plain	: Arkhe tou euaggeliou Iesou Khristou Uiou Theou.
# fmt=text-unaccent-plain	: Αρχη του ευαγγελιου Ιησου Χριστου Υιου Θεου.

# %% [markdown]
# ### Generating release to GitHub

# %%
#N1904 = use("saulocantanhede/tfgreek2:clone", version="0.5.9", checkout="clone", mod="saulocantanhede/tfgreek2/BOLcomplement/tf:clone", hoist=globals())
N1904 = use("CenterBLC/N1904:clone", version="1.0.0", checkout="clone", mod="CenterBLC/N1904/BOLcomplement/tf:clone", hoist=globals())
# Out:
# **Locating corpus resources ...**
# <b title="local github">app:</b> <span title="repo clone offline under /Users/saulo/github">~/github/CenterBLC/N1904/app</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/saulo/github">~/github/CenterBLC/N1904/tf/1.0.0</span>
# <b title="local github">data:</b> <span title="repo clone offline under /Users/saulo/github">~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0</span>
#    |     0.79s T otype                from ~/github/CenterBLC/N1904/tf/1.0.0
#    |       10s T oslots               from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.77s T unaccent             from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.48s T after                from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.61s T lemmatranslit        from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.78s T text                 from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.48s T trailer              from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.85s T lemma                from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.72s T translit             from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.00s T before               from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     3.18s T book                 from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     4.16s T verse                from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     2.47s T chapter              from ~/github/CenterBLC/N1904/tf/1.0.0
#    |      |     0.24s C __levels__           from otype, oslots, otext
#    |      |     6.11s C __order__            from otype, oslots, __levels__
#    |      |     0.28s C __rank__             from otype, __order__
#    |      |       20s C __levUp__            from otype, oslots, __rank__
#    |      |       10s C __levDown__          from otype, __levUp__, __rank__
#    |      |     0.51s C __characters__       from otext
#    |      |     2.70s C __boundary__         from otype, oslots, __rank__
#    |      |     0.06s C __sections__         from otype, oslots, otext, __levUp__, __levels__, book, chapter, verse
#    |     0.67s T AU_declension        from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.66s T AU_exercise_selection from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.77s T AU_vocab_builder_chapter from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.70s T AlandSynopChapter    from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.34s T AlandSynopChapterNr  from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.71s T AlandSynopEvent      from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.35s T AlandSynopEventNr    from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.71s T AlandSynopNo         from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.75s T BGVB                 from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.67s T abc_order            from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.02s T appositioncontainer  from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.30s T articular            from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.70s T bol_case             from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.79s T bol_dict_abc         from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.65s T bol_frequency_rank   from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.70s T bol_gender           from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.82s T bol_gloss_EN         from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.85s T bol_gloss_PT         from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.85s T bol_lemma            from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.88s T bol_lemma_dict       from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.89s T bol_lemma_occ        from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.97s T bol_monad_num        from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.69s T bol_mood             from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.66s T bol_noun_declension  from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.66s T bol_noun_stem        from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.75s T bol_number           from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.66s T bol_person           from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.63s T bol_possessor_number from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.75s T bol_psp              from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.82s T bol_ref              from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.63s T bol_suffix           from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.94s T bol_surface          from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.67s T bol_tense            from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.67s T bol_verb_type        from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.66s T bol_voice            from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     2.68s T bookshort            from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.93s T case                 from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.68s T clause_number        from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.07s T clausetype           from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     2.41s T cls                  from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.04s T cltype               from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.00s T criticalsign         from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.07s T crule                from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.01s T degree               from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.07s T discontinuous        from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.57s T domain               from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.49s T frame                from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.45s T framespec            from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.14s T function             from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.92s T gender               from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.84s T gloss                from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.84s T gloss_BGVB           from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     2.00s T id                   from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.23s T junction             from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.00s T lang                 from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.89s T lemma_dict           from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.85s T lemma_noaccent       from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.82s T lemma_translit       from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     1.57s T ln                   from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.35s T mood                 from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.61s T morph                from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.09s T nodeid               from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.84s T normalized           from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.90s T normalized_noaccent  from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.00s T note                 from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     2.57s T num                  from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.29s T number               from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     4.30s T parent               from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.25s T person               from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.23s T punctuation          from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.94s T ref                  from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.23s T referent             from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.01s T rela                 from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.96s T role                 from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.12s T rule                 from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.65s T sentence_number      from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     1.56s T sp                   from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.42s T strong               from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.15s T subjref              from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.23s T subjrefspec          from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.35s T tense                from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.75s T trans                from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.62s T typ                  from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.39s T typems               from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     1.89s T unicode              from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.02s T variant              from ~/github/CenterBLC/N1904/tf/1.0.0
#    |     0.73s T vocab_ReadGreekin30Days from ~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0
#    |     0.36s T voice                from ~/github/CenterBLC/N1904/tf/1.0.0
#             <b>TF:</b> <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="text-fabric api">TF API 12.5.1</a>, <a target="_blank" href="https://github.com/CenterBLC/N1904/blob/main/app" title="CenterBLC/N1904 app">CenterBLC/N1904/app  v3</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/about/searchusage.html" title="Search Templates Introduction and Reference">Search Reference</a><br>
#             <b>Data:</b> <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/tree/main/docs/about.md" title="provenance of Nestle 1904 Greek New Testament">CenterBLC - N1904 1.0.0</a>, <a target="_blank" href="https://annotation.github.io/text-fabric/tf/writing/greek.html" title="How TF features represent text">Character table</a>, <a target="_blank" href="https://github.com/saulocantanhede/tfgreek2/tree/main/docs/features/README.md" title="CenterBLC - N1904 feature documentation">Feature docs</a><br>
#             <details class="nodeinfo"><summary><b>Node types</b></summary>
# <table class="nodeinfo">
#     <tr>
#         <th>Name</th>
#         <th># of nodes</th>
#         <th># slots / node</th>
#         <th>% coverage</th>
#     </tr>
#
# <tr>
#     <th>book</th>
#     <td>27</td>
#     <td>5102.93</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>chapter</th>
#     <td>260</td>
#     <td>529.92</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>verse</th>
#     <td>7944</td>
#     <td>17.34</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>sentence</th>
#     <td>8011</td>
#     <td>17.20</td>
#     <td><b>100</b></td>
# </tr>
#
# <tr>
#     <th>group</th>
#     <td>8945</td>
#     <td>7.01</td>
#     <td>46</td>
# </tr>
#
# <tr>
#     <th>clause</th>
#     <td>42506</td>
#     <td>8.36</td>
#     <td><i>258</i></td>
# </tr>
#
# <tr>
#     <th>wg</th>
#     <td>106868</td>
#     <td>6.88</td>
#     <td><i>533</i></td>
# </tr>
#
# <tr>
#     <th>phrase</th>
#     <td>69007</td>
#     <td>1.90</td>
#     <td>95</td>
# </tr>
#
# <tr>
#     <th>subphrase</th>
#     <td>116178</td>
#     <td>1.60</td>
#     <td><i>135</i></td>
# </tr>
#
# <tr>
#     <th><i>word</i></th>
#     <td>137779</td>
#     <td>1.00</td>
#     <td><b>100</b></td>
# </tr>
# </table></details>
#             <b>Sets:</b> no custom sets<br>
#             <b>Features:</b><br>
# <details><summary><b><github>CenterBLC/N1904/BOLcomplement/tf</b></summary>
#     <div class="fcorpus">
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AU_declension.tf">AU_declension</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Andrews University declension selection for exercises</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AU_exercise_selection.tf">AU_exercise_selection</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Andrews University declension selection for exercises</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AU_vocab_builder_chapter.tf">AU_vocab_builder_chapter</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Andrews University vocab builder booklet chapter</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AlandSynopChapter.tf">AlandSynopChapter</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Aland Synoptic Parallel Chapter</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AlandSynopChapterNr.tf">AlandSynopChapterNr</a>
# </div>
# <div class="fmono">int</div>
#
# <span> Aland Synoptic Parallel Number</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AlandSynopEvent.tf">AlandSynopEvent</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Aland Synoptic Parallel Event</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AlandSynopEventNr.tf">AlandSynopEventNr</a>
# </div>
# <div class="fmono">int</div>
#
# <span> Aland Synoptic Parallel Event</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/AlandSynopNo.tf">AlandSynopNo</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Aland Synoptic Parallel Number</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/BGVB.tf">BGVB</a>
# </div>
# <div class="fmono">str</div>
#
# <span> chapter categoried vocab as it appears in Larry Richards Textbook "Learning Greek in 30 days"</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/abc_order.tf">abc_order</a>
# </div>
# <div class="fmono">int</div>
#
# <span> the dictionary position of a given word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_case.tf">bol_case</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based case</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_dict_abc.tf">bol_dict_abc</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based dictionary position of a given word</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_frequency_rank.tf">bol_frequency_rank</a>
# </div>
# <div class="fmono">int</div>
#
# <span> Bible Online Learner based frequency rank of a given lexeme</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_gender.tf">bol_gender</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based gender</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_gloss_EN.tf">bol_gloss_EN</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based English gloss</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_gloss_PT.tf">bol_gloss_PT</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based Portuguese gloss</span>
#
# </div>
#
# <div class="frow">
#     <div class="fnamecat ">
# <a target="_blank" href="https://github.com/CenterBLC/N1904/tree/main/BOLcomplement/tf" title="~/github/CenterBLC/N1904/BOLcomplement/tf/1.0.0/bol_lemma.tf">bol_lemma</a>
# </div>
# <div class="fmono">str</div>
#
# <span> Bible Online Learner based lexeme</span>
#
# </div>
#
# <div class="frow">
#     <div class="fn
# <style>tr.tf.ltr, td.tf.ltr, th.tf.ltr { text-align: left ! important;}
# tr.tf.rtl, td.tf.rtl, th.tf.rtl { text-align: right ! important;}
# @font-face {
#   font-family: "Gentium Plus";
#   src: local('Gentium Plus'), local('GentiumPlus'),
#     url('/browser/static/fonts/GentiumPlus-R.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/GentiumPlus-R.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Ezra SIL";
#   src: local('Ezra SIL'), local('EzraSIL'),
#     url('/browser/static/fonts/SILEOT.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SILEOT.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SBL Hebrew";
#   src: local('SBL Hebrew'), local('SBLHebrew'),
#     url('/browser/static/fonts/SBL_Hbrw.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SBL_Hbrw.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Estrangelo Edessa";
#   src: local('Estrangelo Edessa'), local('EstrangeloEdessa');
#     url('/browser/static/fonts/SyrCOMEdessa.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SyrCOMEdessa.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuran;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran'), local('AmiriQuran'),
#     url('/browser/static/fonts/AmiriQuran.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuran.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: AmiriQuranColored;
#   font-style: normal;
#   font-weight: 400;
#   src: local('Amiri Quran Colored'), local('AmiriQuranColored'),
#     url('/browser/static/fonts/AmiriQuranColored.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/AmiriQuranColored.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "Santakku";
#   src: local('Santakku'),
#     url('/browser/static/fonts/Santakku.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/Santakku.woff?raw=true') format('woff');
# }
#
# @font-face {
#   font-family: "SantakkuM";
#   src: local('SantakkuM'),
#     url('/browser/static/fonts/SantakkuM.woff') format('woff'),
#     url('https://github.com/annotation/text-fabric/blob/master/tf/browser/static/fonts/SantakkuM.woff?raw=true') format('woff');
# }
#
# /* bypassing some classical notebook settings */
# div#notebook {
#   line-height: unset;
# }
# /* neutral text */
# .txtn,.txtn a:visited,.txtn a:link {
#     font-family: sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* transcription text */
# .txtt,.txtt a:visited,.txtt a:link {
#     font-family: monospace;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* source text */
# .txto,.txto a:visited,.txto a:link {
#     font-family: serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* phonetic text */
# .txtp,.txtp a:visited,.txtp a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr;
#     unicode-bidi: embed;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* original script text */
# .txtu,.txtu a:visited,.txtu a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     text-decoration: none;
#     color: var(--text-color);
# }
# /* hebrew */
# .txtu.hbo,.lex.hbo {
#     font-family: "Ezra SIL", "SBL Hebrew", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* syriac */
# .txtu.syc,.lex.syc {
#     font-family: "Estrangelo Edessa", sans-serif;
#     font-size: medium;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* neo aramaic */
# .txtu.cld,.lex.cld {
#     font-family: "CharisSIL-R", sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* standard arabic */
# .txtu.ara,.lex.ara {
#     font-family: "AmiriQuran", sans-serif;
#     font-size: large;
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# /* cuneiform */
# .txtu.akk,.lex.akk {
#     font-family: Santakku, sans-serif;
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .txtu.uga,.lex.uga {
#     font-family: sans-serif;
#     /*font-family: Noto Sans Ugaritic, sans-serif;*/
#     font-size: large;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# /* greek */
# .txtu.grc,.lex.grc a:link {
#     font-family: Gentium, sans-serif;
#     font-size: medium;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# a:hover {
#     text-decoration: underline | important;
#     color: #0000ff | important;
# }
# .ltr {
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .rtl {
#     direction: rtl ! important;
#     unicode-bidi: embed;
# }
# .ubd {
#     unicode-bidi: embed;
# }
# .col {
#    display: inline-block;
# }
# .features {
#     font-family: monospace;
#     font-size: medium;
#     font-weight: bold;
#     color: var(--features);
#     display: flex;
#     flex-flow: column nowrap;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     padding: 2px;
#     margin: 2px;
#     direction: ltr;
#     unicode-bidi: embed;
#     border: var(--meta-width) solid var(--meta-color);
#     border-radius: var(--meta-width);
# }
# .features div,.features span {
#     padding: 0;
#     margin: -2px 0;
# }
# .features .f {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: normal;
#     color: #5555bb;
# }
# .features .xft {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: medium;
#   margin: 2px 0px;
# }
# .features .xft .f {
#   color: #000000;
#   background-color: #eeeeee;
#   font-size: small;
#   font-weight: normal;
# }
# .tfsechead {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--tfsechead);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .structure {
#     font-family: sans-serif;
#     font-size: small;
#     font-weight: bold;
#     color: var(--structure);
#     unicode-bidi: embed;
#     text-align: start;
# }
# .comments {
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
# }
# .nd, a:link.nd {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     vertical-align: super;
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .nde, a:link.nde {
#     font-family: sans-serif;
#     font-size: small;
#     color: var(--node);
#     direction: ltr ! important;
#     unicode-bidi: embed;
# }
# .etf {
#     font-size: normal;
#     border-radius: 0.2rem;
#     border: 1pt solid white;
#     padding: 0 0.2rem ! important;
#     margin: 0 0.2rem ! important;
# }
# .etfx {
#     font-size: x-large;
# }
# .lex {
#   color: var(--lex-color);;
# }
# #colormapplus, #colormapmin, .ecolormapmin {
#   font-weight: bold;
#   border-radius: 0.1rem;
#   background-color: #eeeeff;
#   padding: 0 1rem;
#   margin: 0 1rem;
# }
# .clr {
#   font-style: italic;
#   font-size: small;
# }
# .clmap,.eclmap {
#   padding: 0;
# }
# .children,.children.ltr {
#     display: flex;
#     border: 0;
#     background-color: #ffffff;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
# }
# .children.stretch {
#     align-items: stretch;
# }
# .children.hor {
#     flex-flow: row nowrap;
# }
# .children.hor.wrap {
#     flex-flow: row wrap;
# }
# .children.ver {
#     flex-flow: column nowrap;
# }
# .children.ver.wrap {
#     flex-flow: column wrap;
# }
# .contnr {
#     width: fit-content;
#     display: flex;
#     justify-content: flex-start;
#     align-items: flex-start;
#     align-content: flex-start;
#     flex-flow: column nowrap;
#     background: #ffffff none repeat scroll 0 0;
#     padding:  10px 2px 2px 2px;
#     margin: 16px 2px 2px 2px;
#     border-style: solid;
#     font-size: small;
# }
# .c
# <script>
# globalThis.copyChar = (el, c) => {
#     for (const el of document.getElementsByClassName('ccon')) {
#         el.className = 'ccoff'
#     }
#     el.className = 'ccon'
#     navigator.clipboard.writeText(String.fromCharCode(c))
# }
# </script>
# <div><b>TF API:</b> names <a target="_blank" href="https://annotation.github.io/text-fabric/tf/cheatsheet.html" title="doc">N F E L T S C TF Fs Fall Es Eall Cs Call</a> directly usable</div><hr>
# Display is setup for viewtype [syntax-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/syntax-view.md#start)
# See [here](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/viewtypes.md#start) for more information on viewtypes

# %%
N1904.zipAll()
# Out:
# Data to be zipped:
# 	OK       app                      (1.0.0 de4f18)      : ~/github/CenterBLC/N1904/app
# 	OK       main data                (1.0.0 de4f18)      : ~/github/CenterBLC/N1904/tf/1.0.0
# Writing zip file ...
# '~/Downloads/github/CenterBLC/N1904/complete.zip'

# %%
from tf.advanced.helpers import dm
from tf.advanced.repo import checkoutRepo

# %%
def do(task):
    md = f"""
commit | release | local | base | subdir
--- | --- | --- | --- | ---
`{task[0]}` | `{task[1]}` | `{task[2]}` | `{task[3]}` | `{task[4]}`
"""
    dm(md)

# %%
do(checkoutRepo(backend='github', org='saulocantanhede', repo='tfgreek2', folder='tf', version='0.5.9'))
# Out:
# <b title="local commit">data:</b> <span title="#6bcd9bc3335dc17e7c9fcae7bc5e965c0273d5aa offline under /Users/saulo/text-fabric-data/github">~/text-fabric-data/github/saulocantanhede/tfgreek2/tf/0.5.9</span>
# commit | release | local | base | subdir
# --- | --- | --- | --- | ---
# `6bcd9bc3335dc17e7c9fcae7bc5e965c0273d5aa` | `None` | `local` | `/Users/saulo/text-fabric-data/github` | `saulocantanhede/tfgreek2/tf`

# %% [markdown]
# ## Understanding discontinuous words

# %%
import pandas as pd

search='''
word discontinuous=1
'''
results=A.search(search)

freq = {}
punctuation_signs = r"[ ,.;·]"

for words in results:
    word = T.text(words[0],fmt='lex-orig-full')
    if word[-1] in punctuation_signs:
        word = word[:-1]
    freq[word] = freq.get(word, 0) + 1

table_freq = pd.DataFrame(list(freq.items()), columns=['Word', 'Frequency'])

table_freq = table_freq.sort_values(by='Frequency', ascending=False)

#pd.set_option('display.max_rows', None)

print(table_freq)

#table_freq.to_csv('table_freq_discontinuous.csv', index=False)
# Out:
#   0.16s 6034 results
#                Word  Frequency
# 0                δέ       2626
# 2               γάρ        985
# 1               οὖν        463
# 53               τέ        195
# 8               μέν        142
# 13               ἄν        123
# 9              εἰμί        108
# 12              ἐάν         83
# 236         ἀδελφός         54
# 7             αὐτός         49
# 100             ἔχω         38
# 16               σύ         38
# 37              ἐγώ         29
# 18           Ἰησοῦς         27
# 125            θεός         24
# 14            ποιέω         24
# 38              δεῖ         21
# 141         γίνομαι         19
# 36         ἄνθρωπος         16
# 24             ὁράω         15
# 64            οὗτος         14
# 48             θέλω         14
# 40              ἆρα         14
# 39               οὐ         13
# 21          δύναμαι         12
# 91              τὶς         11
# 10              πᾶς         10
# 93           Πέτρος          9
# 341        ἀγαπητός          9
# 71             λέγω          9
# 268          Παῦλος          8
# 206         λαμβάνω          8
# 149         ἔρχομαι          8
# 168          κύριος          8
# 196       ἀποκτείνω          7
# 32             φημί          7
# 164              ὡς          7
# 221             ἵνα          7
# 191          μέντοι          7
# 174            οἶδα          6
# 128           χάρις          6
# 205             ζάω          6
# 204           μέλλω          6
# 179          ὑπάρχω          6
# 187        Ἰουδαῖος          6
# 332             ἄρα          6
# 55             γυνή          6
# 177         εὑρίσκω          5
# 167            μένω          5
# 225           πατήρ          5
# 35          μαθητής          5
# 30               δή          5
# 138     προσεύχομαι          5
# 131              εἰ          5
# 305         θάνατος          5
# 11            μέγας          5
# 6             ἀκούω          5
# 190         Χριστός          5
# 175       λογίζομαι          4
# 72             σῴζω          4
# 188              ὅς          4
# 144              γέ          4
# 217           γράφω          4
# 99              ὅτι          4
# 213           ἡμέρα          4
# 28            ἐσθίω          4
# 197           βλέπω          4
# 22              καί          4
# 239           λαλέω          4
# 283        βούλομαι          4
# 52          ἐκεῖνος          4
# 331          ἀγαθός          4
# 3             ἅγιος          4
# 101           βάλλω          3
# 487          εἰρήνη          3
# 286        ἐκκλησία          3
# 310         τυγχάνω          3
# 328         ἁμαρτία          3
# 383        διάκονος          3
# 289          πνεῦμα          3
# 139      Ἱεροσόλυμα          3
# 110           ζητέω          3
# 195          χρόνος          3
# 281           δοκέω          3
# 273         πιστεύω          3
# 259             ἀπό          3
# 171         διδάσκω          3
# 172          πράσσω          3
# 237            ἀνήρ          3
# 97              δέω          3
# 176         κάθημαι          3
# 203       πορεύομαι          3
# 184         βαπτίζω          3
# 185         σημεῖον          3
# 150     παραγίνομαι          3
# 173          Ἰσραήλ          3
# 62           κόσμος          3
# 68           μάρτυς          3
# 26               μή          3
# 94                ὁ          3
# 92        περιπατέω          3
# 90          γινώσκω          3
# 45        νεανίσκος          3
# 57            λίθος          3
# 27       ἀποκαλύπτω          3
# 20           ἰατρός          3
# 504         τεκνίον          3
# 297       κατηγορέω          2
# 61           δοῦλος          2
# 46           πρῶτος          2
# 192           χαίρω          2
# 449           νόμος          2
# 299           Φῆλιξ          2
# 23          θεάομαι          2
# 292       χιλίαρχος          2
# 58              ὥρα          2
# 304            φέρω          2
# 379          πληρόω          2
# 303           κρίνω          2
# 51        Φαρισαῖος          2
# 180          κεῖμαι          2
# 178    ἑκατοντάρχης          2
# 306        Ἀγρίππας          2
# 73             υἱός          2
# 74            Μαρία          2
# 75        ἀκάθαρτος          2
# 170           πόλις          2
# 375       οἰκονόμος          2
# 77          νηστεύω          2
# 78           καινός          2
# 516             πῦρ          2
# 210           καλός          2
# 50       γραμματεύς          2
# 459           θυσία          2
# 258           πάσχω          2
# 411           λόγος          2
# 34         διακρίνω          2
# 250          ἵστημι          2
# 248         Ἁνανίας          2
# 414         ἀλήθεια          2
# 263           κωλύω          2
# 417        διάβολος          2
# 264        δεύτερος          2
# 419         ὡσαύτως          2
# 241         οὐρανός          2
# 421       ἀναστρέφω          2
# 511           τάχος          2
# 401       παρακαλέω          2
# 423           ὀρέγω          2
# 231          ἀφίημι          2
# 31           Ἡρῴδης          2
# 95              εἷς          2
# 434        προφήτης          2
# 435           ὄνομα          2
# 218           νίπτω          2
# 280           κακός          2
# 390         ἡγέομαι          2
# 212          οὐδείς          2
# 284           γραφή          2
# 312          γράμμα          2
# 69            ὄχλος          2
# 334     ἀπεκδέχομαι          2
# 81           σπείρω          2
# 142        διακονέω          2
# 4             Ἰωσήφ          2
# 470          νεκρόω          1
# 496       ἐπάγγελμα          1
# 409         ἀστοχέω          1
# 472           αἱρέω          1
# 490            τιμή          1
# 489     προσέρχομαι          1
# 488       παρακύπτω          1
# 492          τέκνον          1
# 486           κενός          1
# 485       βασιλικός          1
# 484        θρησκεία          1
# 483        ὀνειδίζω          1
# 482        ποικίλος          1
# 480         εἰσφέρω          1
# 493            βιόω          1
# 479       ἀναστροφή          1
# 478         ἐκφεύγω          1
# 477      δικαιοσύνη          1
# 476       ἀποτίθημι          1
# 474          πλανάω          1
# 473       ἀλλότριος          1
# 494            νέος          1
# 495         λαγχάνω          1
# 453      λειτουργός          1
# 452           πρέπω          1
# 501             ἤδη          1
# 502        ἐπιστολή          1
# 432      παράκλησις          1
# 431     παραχειμάζω          1
# 430        τοιοῦτος          1
# 429         πραΰτης          1
# 428      ἐπιστομίζω          1
# 427          κριτής          1
# 426         ἀσέβεια          1
# 425    ἐπαγγέλλομαι          1
# 424       ἀπρόσιτος          1
# 422           τιμάω          1
# 510       βλασφημία          1
# 512           κλείω          1
# 420       προΐστημι          1
# 418         ἐμπίπτω          1
# 416        ἐπιτρέπω          1
# 415             διά          1
# 413          ἀπωθέω          1
# 412        Τιμόθεος          1
# 410      ἀντίκειμαι          1
# 433          δεσμός          1
# 509            χαρά          1
# 436         παλαιόω          1
# 444          διδαχή          1
# 451          ἔγγυος          1
# 503       ὑπόμνησις          1
# 450        ἀνίστημι          1
# 448      πατριάρχης          1
# 505          παράγω          1
# 447           ὀμνύω          1
# 446          σπουδή          1
# 445         γεύομαι          1
# 443       καταβάλλω          1
# 437          ἀμελέω          1
# 506          ἀγαπάω          1
# 507             ζωή          1
# 442           τροφή          1
# 441        ἀπείθεια          1
# 440           ὁρίζω          1
# 439            δόξα          1
# 508           κυρία          1
# 438         δουλεία          1
# 349          γνῶσις          1
# 260     ἐκπορεύομαι          1
# 347        περίψημα          1
# 153        ἀσθένεια          1
# 162           καθώς          1
# 161            δέκα          1
# 160        μετάνοια          1
# 159          ἐγγίζω          1
# 157           πέντε          1
# 156    συνανάκειμαι          1
# 155       ὑδρωπικός          1
# 154        σάββατον          1
# 152        δοκιμάζω          1
# 165           ἄρχων          1
# 151       διαμερίζω          1
# 147        γρηγορέω          1
# 145            φωνή          1
# 140           οἰκία          1
# 137  πεντακισχίλιοι          1
# 136        θεραπεία          1
# 134       Γερασηνός          1
# 133           βόσκω          1
# 163           ἀλήθω          1
# 166       διέρχομαι          1
# 219      διδάσκαλος          1
# 200       πλοιάριον          1
# 215       ἀποθνῄσκω          1
# 214            πρός          1
# 211           πιάζω          1
# 209             ἄγω          1
# 208             ἐπί          1
# 207          τυφλός          1
# 202           πόσις          1
# 201          βρῶσις          1
# 199            ὄρος          1
# 169             μνᾶ          1
# 198           ἔργον          1
# 194           πάλιν          1
# 193       Σαμαρίτης          1
# 189       προσκυνέω          1
# 186           κέρμα          1
# 183         εὐλογέω          1
# 182        ὀφθαλμός          1
# 181       παρασκευή          1
# 132            ὕδωρ          1
# 130            ἄρχω          1
# 129         τελώνης          1
# 44         πιπράσκω          1
# 65         Ἰσκαριώθ          1
# 63       καταράομαι          1
# 60         φρόνιμος          1
# 59      κατακλυσμός          1
# 56       εἰσέρχομαι          1
# 54         βασιλεύς          1
# 49       καταστρέφω          1
# 47             πίνω          1
# 43           συνάγω          1
# 123           θυμός          1
# 42             ἀμήν          1
# 41            τρεῖς          1
# 33           πλήρης          1
# 29         μακάριος          1
# 25            φίλος          1
# 19          ἐκεῖθεν          1
# 17              ὑπό          1
# 5            Ἰούδας          1
# 66            βαρέω          1
# 67      ψευδόμαρτυς          1
# 70          Πιλᾶτος          1
# 76        ἐπισυνάγω          1
# 120         θαυμάζω          1
# 119        δεσπότης          1
# 118       χρηματίζω          1
# 117        συντηρέω          1
# 115          ῥύομαι          1
# 112       προσδοκάω          1
# 105           μέσος          1
# 104      καταβαρύνω          1
# 103           πίπτω          1
# 102      εὐαγγέλιον          1
# 96               ἐκ          1
# 88            πωρόω          1
# 86      σπεκουλάτωρ          1
# 84           λεγιών          1
# 83       κατασκηνόω          1
# 82         παραβολή          1
# 79            ξηρός          1
# 216         ὀνάριον          1
# 220       ἀνάκειμαι          1
# 346        ἀνακρίνω          1
# 298         ἀδίκημα          1
# 313          Φῆστος          1
# 311          Μωϋσῆς          1
# 309             φῶς          1
# 308        καταντάω          1
# 307     ἀπολογέομαι          1
# 302          Καῖσαρ          1
# 301     ἀποδείκνυμι          1
# 300          ἄτοπος          1
# 296         βεβηλόω          1
# 315          Λασαία          1
# 295      εὐχαριστία          1
# 294         ἔγκλημα          1
# 293       διακόσιοι          1
# 291          στάσις          1
# 290         μαστίζω          1
# 288       ὑποστέλλω          1
# 287         Εὔτυχος          1
# 285         ἐργάτης          1
# 314         Ἰούλιος          1
# 316           χῶρος          1
# 222       ἀκολουθέω          1
# 333       κατάκριμα          1
# 345      εὐχαριστέω          1
# 342           διώκω          1
# 340        διάφορος          1
# 339          πρᾶξις          1
# 338          φρονέω          1
# 337      ἀγριέλαιος          1
# 336          σκεῦος          1
# 335        κεραμεύς          1
# 329         δυνατός          1
# 317        ὑποτρέχω          1
# 326           εἶπον          1
# 325         θειότης          1
# 324     πνευματικός          1
# 323      μεταδίδωμι          1
# 322            οὔτε          1
# 321          πλοῖον          1
# 320        κατανοέω          1
# 319         ἐκτείνω          1
# 282           πολύς          1
# 279      δεσμοφύλαξ          1
# 278          καρδία          1
# 234          ἐκλέγω          1
# 246            ψυχή          1
# 245    τεσσεράκοντα          1
# 244        ἀντιλέγω          1
# 243        θεραπεύω          1
# 242         Ἰωάννης          1
# 240          ἕνδεκα          1
# 238        κατοικέω          1
# 235            ὁδός          1
# 233        Θεόφιλος          1
# 277        διατρίβω          1
# 232          οἴομαι          1
# 230        μνημεῖον          1
# 229          σκέλος          1
# 228          μεστός          1
# 227             ὅτε          1
# 226          ἁγιάζω          1
# 224         τελειόω          1
# 223              ἐν          1
# 247       ἀνάστασις          1
# 249            ἅπας          1
# 251           κακόω          1
# 252           Ἰακώβ          1
# 276            ἐκεῖ          1
# 275           βάρος          1
# 274           τέρας          1
# 272         βαστάζω          1
# 271            πούς          1
# 270          ἑαυτοῦ          1
# 269       ἀναγκαῖος          1
# 267       ἀνθύπατος          1
# 266         ὑπακούω          1
# 265          ἱκανός          1
# 262            ῥῆμα          1
# 261           Λύδδα          1
# 257        Φίλιππος          1
# 256           Σίμων          1
# 255        ἐπιπίπτω          1
# 254       ἀπόστολος          1
# 253        Αἴγυπτος          1
# 520          ἀρνίον          1

# %%
results = A.search("""
word lemma* discontinuous=1 cls*
""")

A.export(results, toDir='~/Downloads/XML-nestle1904/programs', toFile='table_discontinuous.tsv')

data=pd.read_csv('~/Downloads/XML-nestle1904/programs/table_discontinuous.tsv',delimiter='\t',encoding='utf-16')

newdata=data[['lemma1','cls1']]

final = newdata.sort_values(by='lemma1', ascending=[True])
table_freq = final.groupby(['lemma1', 'cls1']).size().reset_index(name='Frequency').sort_values(by='Frequency', ascending=[False])

print(table_freq.to_string(index=False))

#table_freq.to_csv('table_discontinuous_final.csv', index=False)
# Out:
#   0.27s 6034 results
#         lemma1 cls1  Frequency
#             δέ conj       2626
#            γάρ conj        985
#            οὖν conj        463
#             τέ conj        195
#            μέν conj        131
#             ἄν ptcl        123
#           εἰμί verb        108
#            ἐάν ptcl         62
#        ἀδελφός noun         54
#          αὐτός pron         49
#            ἔχω verb         38
#             σύ pron         38
#            ἐγώ pron         29
#         Ἰησοῦς noun         27
#           θεός noun         24
#          ποιέω verb         24
#            ἐάν conj         21
#            δεῖ verb         21
#        γίνομαι verb         19
#       ἄνθρωπος noun         16
#           ὁράω verb         15
#           θέλω verb         14
#          οὗτος pron         14
#        δύναμαι verb         12
#            ἆρα conj         12
#            τὶς pron         11
#            μέν ptcl         11
#            πᾶς  adj         10
#             οὐ  adv          9
#       ἀγαπητός  adj          9
#         Πέτρος noun          9
#           λέγω verb          9
#        ἔρχομαι verb          8
#         κύριος noun          8
#        λαμβάνω verb          8
#         Παῦλος noun          8
#             ὡς conj          7
#         μέντοι conj          7
#            ἵνα conj          7
#      ἀποκτείνω verb          7
#           φημί verb          7
#           γυνή noun          6
#         ὑπάρχω verb          6
#          μέλλω verb          6
#           οἶδα verb          6
#            ἄρα conj          6
#            ζάω verb          6
#          χάρις noun          6
#       Ἰουδαῖος  adj          6
#    προσεύχομαι verb          5
#          ἀκούω verb          5
#        Χριστός noun          5
#           μένω verb          5
#        θάνατος noun          5
#        εὑρίσκω verb          5
#          πατήρ noun          5
#             δή ptcl          5
#        μαθητής noun          5
#          μέγας  adj          5
#             εἰ conj          5
#             γέ ptcl          4
#         ἀγαθός  adj          4
#          βλέπω verb          4
#          ἐσθίω verb          4
#       βούλομαι verb          4
#            ὅτι conj          4
#          ἡμέρα noun          4
#      λογίζομαι verb          4
#          γράφω verb          4
#          ἅγιος  adj          4
#           σῴζω verb          4
#        ἐκεῖνος pron          4
#          λαλέω verb          4
#             ὅς pron          4
#             οὐ ptcl          4
#      διέρχομαι verb          1
#       διάφορος  adj          1
#            διά prep          1
#     δικαιοσύνη noun          1
#     διδάσκαλος noun          1
#         διδαχή noun          1
#       διατρίβω verb          1
#      διαμερίζω verb          1
#      διακόσιοι  adj          1
#       δεσπότης noun          1
#         δεσμός noun          1
#     δεσμοφύλαξ noun          1
#       γρηγορέω verb          1
#         γνῶσις noun          1
#        γνωρίζω verb          1
#         γλῶσσα noun          1
#        γεύομαι verb          1
#          βόσκω verb          1
#          βάρος noun          1
#         βρῶσις noun          1
#      βλασφημία noun          1
#       κοινωνία noun          1
#       κοινωνός noun          1
#         κριτής noun          1
#          πόσις noun          1
#          πίπτω verb          1
#           πίνω verb          1
#          πέντε  num          1
#         πένθος noun          1
#          πάλιν  adv          1
#           πάλη noun          1
#          πωρόω verb          1
#         πρᾶξις noun          1
#           πρός prep          1
#          πρέπω verb          1
#      προΐστημι verb          1
#    προσέρχομαι verb          1
#       προσφέρω verb          1
#      προσκυνέω verb          1
#       προσκοπή noun          1
#      προσδοκάω verb          1
#        πραΰτης noun          1
#           πούς noun          1
#      Γερασηνός noun          1
#        πολεμέω verb          1
#       ποικίλος  adj          1
#           πόμα noun          1
#         σκεῦος noun          1
#          κυρία noun          1
#         σκέλος noun          1
#         τυφλός  adj          1
#          τροφή noun          1
#          τρεῖς  adj          1
#         τοίνυν conj          1
#        τοιόσδε pron          1
#       τοιοῦτος pron          1
#           τιμή noun          1
#          τιμάω verb          1
#        τιμωρία noun          1
#   τεσσεράκοντα  num          1
#        τελώνης noun          1
#        τελειόω verb          1
#        σάλπιγξ noun          1
#       σάββατον noun          1
#         συνάγω verb          1
#       συντηρέω verb          1
#   συνανάκειμαι verb          1
#      συλαγωγέω verb          1
#         στάσις noun          1
#         σπουδή noun          1
#    σπεκουλάτωρ noun          1
#    πνευματικός  adj          1
#         πλήρης  adj          1
#         πλοῖον noun          1
#      πλοιάριον noun          1
#         νεκρόω verb          1
#         μᾶλλον  adv          1
#          μέσος  adj          1
#            μνᾶ noun          1
#      μνημονεύω verb          1
#       μνημεῖον noun          1
#       μετάνοια noun          1
#     μεταδίδωμι verb          1
#        μεσίτης noun          1
#         μεστός  adj          1
#        μαστίζω verb          1
#     μαρτύρομαι verb          1
#       μαρτυρέω verb          1
#       μακάριος  adj          1
#     λειτουργός noun          1
#     λειτουργία noun          1
#         λεγιών noun          1
#        λαγχάνω verb          1
#          κέρμα noun          1
#         κάμπτω verb          1
#           κἀγώ pron          1
#           νέος  adj          1
#            νύξ noun          1
#          ξηρός  adj          1
#       παρουσία noun          1
#         πλανάω verb          1
#          πιάζω verb          1
#       πιπράσκω verb          1
#          πείθω verb          1
#       περίψημα noun          1
# πεντακισχίλιοι  adj          1
#     πατριάρχης noun          1
#     παράκλησις noun          1
#         παράγω verb          1
#    παραχειμάζω verb          1
#          οἰκία noun          1
#      παρατηρέω verb          1
#      παρασκευή noun          1
#      παρανομία noun          1
#      παρακύπτω verb          1
#       παραβολή noun          1
#        παλαιόω verb          1
#           οὔτε conj          1
#         οὐκέτι  adv          1
#         οἴομαι verb          1
#           ῥῆμα noun          1

# %% [markdown]
# ## Text with lexemme

# %%
results = A.search("""
wg rule=NPofNP
""")
A.show(results, end=1, multiFeatures=False, queryFeatures=False,
       colorMap=color, hiddenTypes={"subphrase", "phrase", "clause", "sentence", "group"})
# Out:
#   0.28s 6819 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/1/1" title="Show this on the website" sec="Matthew@1:1">Matthew@1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Matthew</span> <span title="chapter">1</span> <span title="verse">1</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    hl"  style="background-color: #47edff;" ><div class="lbl c1  hl"  style="background-color: #47edff;" ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Βίβλος </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">γενέσεως </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Χριστοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">υἱοῦ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Δαυεὶδ </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">υἱοῦ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἀβραάμ.</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div>

# %%
results = A.search("""
verse book=Mark chapter=1 verse=1
""")
print('Normal text')
A.show(results, end=1, multiFeatures=False, queryFeatures=False,
       colorMap=color, hiddenTypes={"wg"}, fmt='text-orig-full')
print('\nLexeme text')
A.show(results, end=1, multiFeatures=False, queryFeatures=False,
       colorMap=color, hiddenTypes={"wg"}, fmt='lex-orig-full')
# Out:
#   0.02s 1 result
# Normal text
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/1/1" title="Show this on the website" sec="Mark@1:1">Mark@1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Mark</span> <span title="chapter">1</span> <span title="verse">1</span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">PreC</span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἀρχὴ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">εὐαγγελίου </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Χριστοῦ </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela">Appo</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">(Υἱοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Θεοῦ).</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div>
# Lexeme text
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/1/1" title="Show this on the website" sec="Mark@1:1">Mark@1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Mark</span> <span title="chapter">1</span> <span title="verse">1</span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">PreC</span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀρχή </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">εὐαγγέλιον </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦς </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Χριστός </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela">Appo</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">υἱός </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">θεός.</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div>

# %%
results = A.search("""
verse book=John chapter=1 verse=6
    c1:clause
    c2:clause

c1 -sibling> c2
""")
A.show(results, end=1, multiFeatures=False, queryFeatures=True, withNodes=True,
       colorMap=color, hiddenTypes={"wg"})
# Out:
#   0.15s 1 result
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/John/1/6" title="Show this on the website" sec="John@1:6">John@1:6</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse:385610 </span> <span class=""><span title="book">John</span> <span title="chapter">1</span> <span title="verse">6</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="verse xft" ><span class="f">verse=</span>6</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:298002 </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="sibling xft" ><span class="e" edge="sibling" nd="298002">sibling•</span>
# <span
#     ef="sibling"
#     nd="298002"
#     md="297996"
#     arrow="left"
#     class="etf"
# ><span class="nde">297996</span><span class="etfx">⇥</span>5</span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="297997"
#     arrow="left"
#     class="etf"
# ><span class="nde">297997</span><span class="etfx">⇥</span>4</span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="297998"
#     arrow="left"
#     class="etf"
# ><span class="nde">297998</span><span class="etfx">⇥</span>3</span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="297999"
#     arrow="left"
#     class="etf"
# ><span class="nde">297999</span><span class="etfx">⇥</span>2</span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298000"
#     arrow="left"
#     class="etf"
# ><span class="nde">298000</span><span class="etfx">⇥</span>1</span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298003"
#     arrow="right"
#     class="etf"
# >1<span class="etfx">↦</span><span class="nde">298003</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298006"
#     arrow="right"
#     class="etf"
# >2<span class="etfx">↦</span><span class="nde">298006</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298008"
#     arrow="right"
#     class="etf"
# >3<span class="etfx">↦</span><span class="nde">298008</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298009"
#     arrow="right"
#     class="etf"
# >4<span class="etfx">↦</span><span class="nde">298009</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298010"
#     arrow="right"
#     class="etf"
# >5<span class="etfx">↦</span><span class="nde">298010</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298011"
#     arrow="right"
#     class="etf"
# >6<span class="etfx">↦</span><span class="nde">298011</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298014"
#     arrow="right"
#     class="etf"
# >7<span class="etfx">↦</span><span class="nde">298014</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298016"
#     arrow="right"
#     class="etf"
# >8<span class="etfx">↦</span><span class="nde">298016</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298019"
#     arrow="right"
#     class="etf"
# >9<span class="etfx">↦</span><span class="nde">298019</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298022"
#     arrow="right"
#     class="etf"
# >10<span class="etfx">↦</span><span class="nde">298022</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298023"
#     arrow="right"
#     class="etf"
# >11<span class="etfx">↦</span><span class="nde">298023</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298025"
#     arrow="right"
#     class="etf"
# >12<span class="etfx">↦</span><span class="nde">298025</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298029"
#     arrow="right"
#     class="etf"
# >13<span class="etfx">↦</span><span class="nde">298029</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298032"
#     arrow="right"
#     class="etf"
# >14<span class="etfx">↦</span><span class="nde">298032</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298035"
#     arrow="right"
#     class="etf"
# >15<span class="etfx">↦</span><span class="nde">298035</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298036"
#     arrow="right"
#     class="etf"
# >16<span class="etfx">↦</span><span class="nde">298036</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298037"
#     arrow="right"
#     class="etf"
# >17<span class="etfx">↦</span><span class="nde">298037</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298038"
#     arrow="right"
#     class="etf"
# >18<span class="etfx">↦</span><span class="nde">298038</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298043"
#     arrow="right"
#     class="etf"
# >19<span class="etfx">↦</span><span class="nde">298043</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298045"
#     arrow="right"
#     class="etf"
# >20<span class="etfx">↦</span><span class="nde">298045</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298046"
#     arrow="right"
#     class="etf"
# >21<span class="etfx">↦</span><span class="nde">298046</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298050"
#     arrow="right"
#     class="etf"
# >22<span class="etfx">↦</span><span class="nde">298050</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298053"
#     arrow="right"
#     class="etf"
# >23<span class="etfx">↦</span><span class="nde">298053</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298054"
#     arrow="right"
#     class="etf"
# >24<span class="etfx">↦</span><span class="nde">298054</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298062"
#     arrow="right"
#     class="etf"
# >25<span class="etfx">↦</span><span class="nde">298062</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298065"
#     arrow="right"
#     class="etf"
# >26<span class="etfx">↦</span><span class="nde">298065</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298070"
#     arrow="right"
#     class="etf"
# >27<span class="etfx">↦</span><span class="nde">298070</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298072"
#     arrow="right"
#     class="etf"
# >28<span class="etfx">↦</span><span class="nde">298072</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298074"
#     arrow="right"
#     class="etf"
# >29<span class="etfx">↦</span><span class="nde">298074</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298076"
#     arrow="right"
#     class="etf"
# >30<span class="etfx">↦</span><span class="nde">298076</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298077"
#     arrow="right"
#     class="etf"
# >31<span class="etfx">↦</span><span class="nde">298077</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298078"
#     arrow="right"
#     class="etf"
# >32<span class="etfx">↦</span><span class="nde">298078</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298079"
#     arrow="right"
#     class="etf"
# >33<span class="etfx">↦</span><span class="nde">298079</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298081"
#     arrow="right"
#     class="etf"
# >34<span class="etfx">↦</span><span class="nde">298081</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298082"
#     arrow="right"
#     class="etf"
# >35<span class="etfx">↦</span><span class="nde">298082</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298084"
#     arrow="right"
#     class="etf"
# >36<span class="etfx">↦</span><span class="nde">298084</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298085"
#     arrow="right"
#     class="etf"
# >37<span class="etfx">↦</span><span class="nde">298085</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298086"
#     arrow="right"
#     class="etf"
# >38<span class="etfx">↦</span><span class="nde">298086</span></span>
#
# <span
#     ef="sibling"
#     nd="298002"
#     md="298087"
#     arrow="right"
#     class="etf"
# >39<span class="etfx">↦</span><span class="nde">298087</span

# %% [markdown]
# ## Jan 17 experiment

# %%
A.viewtype('syntax')
# Out:
# setup for syntax-view

# %%
results = A.search("""
clause rule=V-ADV-S
""")
A.show(results, end=1, colorMap=color, condenseType='clause')
# Out:
#   0.03s 111 results
# <p><b>clause</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/2/23" title="Show this on the website" sec="Matthew@2:23">Matthew@2:23</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span> <span class="">#<span title="num">191</span>: <span title="typ"></span> <span title="function">Pred-Cmpl-Subj</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="rule">V-ADV-S</span> <span title="junction"></span></span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>V-ADV-S</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">728</span>: <span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">v</span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ῥηθὲν </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">729</span>: <span title="typ">PP</span> <span title="function">Cmpl</span> <span title="rela"></span> \\ <span title="type">wrapper-scope</span> <span title="role">adv</span> <span title="rule">PrepNp</span></span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>PrepNp</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class="">#<span title="num">1245</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">διὰ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class="">#<span title="num">1246</span>: <span title="typ">NP</span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">modifier-scope</span> <span title="role"></span> <span title="rule">DetNP</span></span></div><div class="features"><span class="rule xft" ><span class="f">rule=</span>DetNP</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class="">#<span title="num">1248</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τῶν </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class="">#<span title="num">1250</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">common</span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">προφητῶν </span></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class="">#<span title="num">1252</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ὅτι </span></div></div></div></div><div class="contnr c2    " ><div class="lbl c2   ...

# %%
A.viewtype('syntax')
# Out:
# setup for syntax-view

# %%
#syntax view
results = A.search("""
verse book=Mark
""")
A.show(results, end=1, colorMap=color)
# Out:
#   0.01s 674 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/1/1" title="Show this on the website" sec="Mark@1:1">Mark@1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book"></span> <span title="chapter"></span>:<span title="verse"></span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class="">#<span title="num">1</span>: <span title="typ"></span> <span title="function">P2CL</span> <span title="rela"></span> \\ <span title="rule">P2CL</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">1</span>: <span title="typ">NP</span> <span title="function">PreC</span> <span title="rela"></span> \\ <span title="role">p</span> <span title="rule">NPofNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class="">#<span title="num">2</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="role"></span> <span title="rule"></span> <span title="type">common</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἀρχὴ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class="">#<span title="num">3</span>: <span title="typ">NP</span> <span title="function"></span> <span title="rela"></span> \\ <span title="role"></span> <span title="rule">DetNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class="">#<span title="num">5</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="role"></span> <span title="rule"></span> <span title="type"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class="">#<span title="num">6</span>: <span title="typ">NP</span> <span title="function"></span> <span title="rela"></span> \\ <span title="role"></span> <span title="rule">NPofNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class="">#<span title="num">8</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="role"></span> <span title="rule"></span> <span title="type">common</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">εὐαγγελίου </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class="">#<span title="num">9</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="role"></span> <span title="rule">Np-Appos</span> <span title="type">group</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class="">#<span title="num">10</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="role"></span> <span title="rule">Np-Appos</span> <span title="type">group</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class= ...

# %%
A.viewtype('wg')
# Out:
# setup for wg-view

# %%
#wg view
results = A.search("""
verse book=Mark
""")
A.show(results, end=1, colorMap=color)
# Out:
#   0.01s 674 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/1/1" title="Show this on the website" sec="Mark@1:1">Mark@1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book"></span> <span title="chapter"></span>:<span title="verse"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">1</span>: <span title="type"></span> <span title="role"></span> <span title="rule">P2CL</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">1</span>: <span title="type">modifier-scope</span> <span title="role">p</span> <span title="rule">NPofNP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἀρχὴ </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">3</span>: <span title="type">modifier-scope</span> <span title="role"></span> <span title="rule">DetNP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τοῦ </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">6</span>: <span title="type">modifier-scope</span> <span title="role"></span> <span title="rule">NPofNP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">εὐαγγελίου </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">9</span>: <span title="type">group</span> <span title="role"></span> <span title="rule">Np-Appos</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">10</span>: <span title="type">group</span> <span title="role"></span> <span title="rule">Np-Appos</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰησοῦ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Χριστοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">15</span>: <span title="type">modifier-scope</span> <span title="role">apposition</span> <span title="rule">NPofNP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">(Υἱοῦ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Θεοῦ).</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div>

# %%
#syntax view old version
results = B.search("""
verse book=Mark verse=1
""")
B.show(results, end=1, colorMap=color, hiddenTypes='wg',
            condensed=True, multiFeatures=False, suppress={'book','chapter','verse'})
# Out:
#   0.01s 16 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/1/1" title="Show this on the website" sec="Mark@1:1">Mark@1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book"></span> <span title="chapter"></span>:<span title="verse"></span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class="">#<span title="num">1</span>: <span title="rule">P2CL</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">1</span>: <span title="function">PreC</span> <span title="role">p</span> <span title="rule">NPofNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἀρχὴ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">2</span>: <span title="function"></span> <span title="role"></span> <span title="rule">DetNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">3</span>: <span title="function"></span> <span title="role"></span> <span title="rule">NPofNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">εὐαγγελίου </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">4</span>: <span title="function"></span> <span title="role"></span> <span title="rule">Np-Appos</span> <span title="type">group</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">5</span>: <span title="function"></span> <span title="role"></span> <span title="rule">Np-Appos</span> <span title="type">group</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰησοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Χριστοῦ </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">6</span>: <span title="function"></span> <span title="role">apposition</span> <span title="rule">NPofNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">(Υἱοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphra ...

# %%
#syntax view
results = NA1904.search("""
verse book=Mark verse=5
""")
NA1904.show(results, end=1, colorMap=color, hiddenTypes='phrase, subphrase, sentence, group, clause',
            condensed=True, multiFeatures=False)
# Out:
#   0.01s 16 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/1/5" title="Show this on the website" sec="Mark@1:5">Mark@1:5</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Mark</span> <span title="chapter">1</span>:<span title="verse">5</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span><span class="verse xft" ><span class="f">verse=</span>5</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">5</span>: <span title="type">wrapper-clause-scope</span> <span title="role"></span> <span title="rule">Conj-CL</span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span><span class="verse xft" ><span class="f">verse=</span>5</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">6</span>: <span title="type"></span> <span title="role"></span> <span title="rule">CLaCL</span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">13</span>: <span title="type"></span> <span title="role"></span> <span title="rule">V-ADV-S</span> <span title="junction">coordinate</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐξεπορεύετο </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span><span class="verse xft" ><span class="f">verse=</span>5</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">46</span>: <span title="type">wrapper-scope</span> <span title="role">adv</span> <span title="rule">PrepNp</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">πρὸς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span><span class="verse xft" ><span class="f">verse=</span>5</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">αὐτὸν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span><span class="verse xft" ><span class="f">verse=</span>5</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">47</span>: <span title="type"></span> <span title="role">s</span> <span title="rule">NpaNp</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">48</span>: <span title="type">modifier-scope</span> <span title="role"></span> <span title="rule">All-NP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">πᾶσα </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span><span class="verse xft" ><span class="f">verse=</span>5</span></div></div><div class="contnr c1    " ><div class="lb ...

# %%
#syntax view
results = NA1904.search("""
verse book=Mark verse=5
""")
NA1904.show(results, end=1, colorMap=color, hiddenTypes='wg',
            condensed=True, multiFeatures=False, suppress='book, verse')
# Out:
#   0.00s 16 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/1/5" title="Show this on the website" sec="Mark@1:5">Mark@1:5</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Mark</span> <span title="chapter">1</span>:<span title="verse"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class="">#<span title="num">5</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="rule">Conj-CL</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class="">#<span title="num">6</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="rule">CLaCL</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span></div><div class="children hor wrap "><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class="">#<span title="num">13</span>: <span title="typ"></span> <span title="function">Pred-Cmpl-Subj</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="rule">V-ADV-S</span> <span title="junction">coordinate</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">45</span>: <span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="role">v</span> <span title="rule"></span> <span title="type"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐξεπορεύετο </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">46</span>: <span title="typ">PP</span> <span title="function">Cmpl</span> <span title="rela"></span> \\ <span title="role">adv</span> <span title="rule">PrepNp</span> <span title="type">wrapper-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">πρὸς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">αὐτὸν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span></div></div></div></div></div></div><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">47</span>: <span title="typ"></span> <span title="function">Subj</span> <span title="rela"></span> \\ <span title="role">s</span> <span title="rule">NpaNp</span> <span ti ...

# %% [markdown]
# ## Transliterated text

# %%
A.viewtype('syntax')
# Out:
# setup for syntax-view

# %%
results = A.search("""
word unaccent* lextranslit* translit* book=Jude
""")
A.show(results, end=1, colorMap=color, condensed=True, multiFeatures=False, hiddenTypes={'wg'}, condenseType='subphrase')
# Out:
#   0.23s 457 results
# <p><b>subphrase</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Jude/1/1" title="Show this on the website" sec="Jude@1:1">Jude@1:1</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class="">#<span title="num">2</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">proper</span> <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="lextranslit xft" ><span class="f">lextranslit=</span>Ioudas</span><span class="translit xft" ><span class="f">translit=</span>Ioudas</span><span class="unaccent xft" ><span class="f">unaccent=</span>Ιουδας</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #81ee93;" ><div class="lbl c0 trm hl"  style="background-color: #81ee93;" ><span class="txtu grc">Ἰούδας </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Jude</span><span class="lextranslit xft" ><span class="f">lextranslit=</span>Ioudas</span><span class="translit xft" ><span class="f">translit=</span>Ioudas</span><span class="unaccent xft" ><span class="f">unaccent=</span>Ιουδας</span></div></div></div></div></div>

# %%
for formats in T.formats:
    print(f'fmt={formats}\t: {T.text(383782,formats)}')
# Out:
# fmt=lex-orig-plain	: ἀρχή ὁ εὐαγγέλιον Ἰησοῦς Χριστός υἱός θεός.
# fmt=lex-translit-plain	: arkhe o euaggelion Iesous Khristos uios theos.
# fmt=text-orig-full	: Ἀρχὴ τοῦ εὐαγγελίου Ἰησοῦ Χριστοῦ (Υἱοῦ Θεοῦ).
# fmt=text-orig-plain	: Ἀρχὴ τοῦ εὐαγγελίου Ἰησοῦ Χριστοῦ Υἱοῦ Θεοῦ.
# fmt=text-translit-plain	: Arkhe tou euaggeliou Iesou Khristou Uiou Theou.
# fmt=text-unaccent-plain	: Αρχη του ευαγγελιου Ιησου Χριστου Υιου Θεου.

# %% [markdown]
# ## March 5 experiment

# %%
A.viewtype('wg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15832\3395963970.py in <module>
# ----> 1 A.viewtype('wg')
#
# AttributeError: 'App' object has no attribute 'viewtype'

# %%
F.cls.freqList(nodeTypes='sentence')
# Out:
# (('cl', 1476),)

# %% [raw]
# results = A.search("""
# phrase note=discontinuous\ discourse
# """)
# A.show(results, end=1, colorMap=color, condenseType='sentence', hiddenTypes={'sentence', 'group', 'subphrase', 'clause'}, withNodes=True)

# %%
results = A.search("""
verse book=Matthew chapter=6 verse=19
    word role*
""")
A.show(results, end=1, colorMap=color, condenseType='sentence', hiddenTypes={'sentence', 'group', 'phrase', 'subphrase', 'clause'})
# Out:
#   0.14s 18 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/6/19" title="Show this on the website" sec="Matthew 6:19">Matthew 6:19</a></span></div><div class=" children"><div class="contnr c3 trm   " ><div class="lbl c3 trm " ><span class="nd">verse </span> <span class=""><span title="book">Matthew</span> <span title="chapter">6</span>:<span title="verse">19</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/6/19" title="Show this on the website" sec="Matthew 6:19">Matthew 6:19</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule"></span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #81ee93;" ><div class="lbl c0 trm hl"  style="background-color: #81ee93;" ><span class="txtu grc">Μὴ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="role xft" ><span class="f">role=</span>adv</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">θησαυρίζετε </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="role xft" ><span class="f">role=</span>v</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ὑμῖν </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="role xft" ><span class="f">role=</span>io</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">θησαυροὺς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="role xft" ><span class="f">role=</span>o</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">wrapper-scope</span> <span title="role">adv</span> <span title="rule">PrepNp</span> <span title="junction"></span></span></div><div class="features"><span class="role xft" ><span class="f">role=</span>adv</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐπὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">modifier-scope</span> <span title="role"></span> <span title="rule">DetNP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τῆς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">γῆς,</span></div><div class="features"><span ...

# %%
results = A.search("""
verse book=Matthew chapter=6 verse=19
    clause function*
""")
A.show(results, end=1, colorMap=color, condenseType='sentence', hiddenTypes={'wg', 'subphrase'})
# Out:
#   0.04s 2 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/6/19" title="Show this on the website" sec="Matthew 6:19">Matthew 6:19</a></span></div><div class=" children"><div class="contnr c3 trm   " ><div class="lbl c3 trm " ><span class="nd">verse </span> <span class=""><span title="book">Matthew</span> <span title="chapter">6</span>:<span title="verse">19</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/6/19" title="Show this on the website" sec="Matthew 6:19">Matthew 6:19</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="role">apposition</span> <span title="rule">CLaCL</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span></div><div class="children hor wrap "><div class="contnr c2   rno hl"  style="background-color: #81ee93;" ><div class="lbl c2  hl"  style="background-color: #81ee93;" ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Cmpl-Subj-Pred</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction">coordinate</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="function xft" ><span class="f">function=</span>Cmpl-Subj-Pred</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Adv</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">adv</span> <span title="rule"></span></span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Adv</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ὅπου </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="function xft" ><span class="f">function=</span>Adv</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div></div></div><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Subj</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">s</span> <span title="rule">NpaNp</span></span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Subj</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">σὴς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">group </span> <span class=""><span title="typ">conjuncted</span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">conjuncted-wg</span> <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span></div><div class="children hor wrap "><div class="contnr c2   lno rno hl"  style="background-color: #81ee93;" ><div class="lbl c2  hl"  style="background-color: #81ee93;" ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Cmpl-Subj-Pred</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction">coordinate</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="function xft" ><span class="f">function=</span>Cmpl-Subj-Pred</span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Subj</span>  ...

# %%
results = B.search("""
verse book=Matthew chapter=6 verse=19
    clause function*
""")
B.show(results, end=1, colorMap=color, condenseType='sentence', hiddenTypes={'wg', 'subphrase'})
# Out:
#   0.01s 3 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/6/19" title="Show this on the website" sec="Matthew 6:19">Matthew 6:19</a></span></div><div class=" children"><div class="contnr c3 trm   " ><div class="lbl c3 trm " ><span class="nd">verse </span> <span class=""><span title="book">Matthew</span> <span title="chapter">6</span>:<span title="verse">19</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/6/19" title="Show this on the website" sec="Matthew 6:19">Matthew 6:19</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="role">apposition</span> <span title="rule">CLaCL</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span></div><div class="children hor wrap "><div class="contnr c2   rno hl"  style="background-color: #81ee93;" ><div class="lbl c2  hl"  style="background-color: #81ee93;" ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Cmpl-Subj-Pred</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction">coordinate</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="function xft" ><span class="f">function=</span>Cmpl-Subj-Pred</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Adv</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">adv</span> <span title="rule"></span></span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Adv</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ὅπου </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="function xft" ><span class="f">function=</span>Adv</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div></div></div><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Subj</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">s</span> <span title="rule">NpaNp</span></span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Subj</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">σὴς </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>6</span><span class="verse xft" ><span class="f">verse=</span>19</span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">group </span> <span class=""><span title="typ">conjuncted</span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">conjuncted-wg</span> <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span></div><div class="children hor wrap "><div class="contnr c2   lno rno hl"  style="background-color: #81ee93;" ><div class="lbl c2  hl"  style="background-color: #81ee93;" ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Cmpl-Subj-Pred</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction">coordinate</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="function xft" ><span class="f">function=</span>Cmpl-Subj-Pred</span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Subj</span>  ...

# %%
results = A.search("""
verse book=Matthew chapter=5 verse=6
    wg role=v rule=Conj2VP
""")
A.show(results, end=1, colorMap=color, condenseType='sentence', hiddenTypes={'sentence', 'group', 'phrase', 'subphrase', 'clause'})
# Out:
#   0.11s 1 result
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/5/6" title="Show this on the website" sec="Matthew 5:6">Matthew 5:6</a></span></div><div class=" children"><div class="contnr c3 trm   " ><div class="lbl c3 trm " ><span class="nd">verse </span> <span class=""><span title="book">Matthew</span> <span title="chapter">5</span>:<span title="verse">6</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/5/6" title="Show this on the website" sec="Matthew 5:6">Matthew 5:6</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="role">s</span> <span title="rule">DetCL</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>DetCL</span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule"></span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">wrapper-clause-scope</span> <span title="role">s</span> <span title="rule">DetCL</span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>DetCL</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">οἱ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule">V-O</span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="rule xft" ><span class="f">rule=</span>V-O</span></div><div class="children hor wrap "><div class="contnr c1    hl"  style="background-color: #81ee93;" ><div class="lbl c1  hl"  style="background-color: #81ee93;" ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role">v</span> <span title="rule">Conj2VP</span> <span title="junction"></span></span></div><div class="features"><span class="role xft" ><span class="f">role=</span>v</span><span class="rule xft" ><span class="f">rule=</span>Conj2VP</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">πεινῶντες </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">conjuncted-wg</span> <span title="role"></span> <span title="rule"></span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">διψῶντες </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthe ...

# %%
results = A.search("""
verse book=Matthew chapter=5 verse=6
    wg role=v rule=Conj2VP
""")
A.show(results, end=1, colorMap=color, condenseType='sentence', hiddenTypes={'wg', 'subphrase'})
# Out:
#   0.11s 1 result
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/5/6" title="Show this on the website" sec="Matthew 5:6">Matthew 5:6</a></span></div><div class=" children"><div class="contnr c3 trm   " ><div class="lbl c3 trm " ><span class="nd">verse </span> <span class=""><span title="book">Matthew</span> <span title="chapter">5</span>:<span title="verse">6</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/5/6" title="Show this on the website" sec="Matthew 5:6">Matthew 5:6</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="role">s</span> <span title="rule">DetCL</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="role xft" ><span class="f">role=</span>s</span><span class="rule xft" ><span class="f">rule=</span>DetCL</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">οἱ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Obj</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="rule xft" ><span class="f">rule=</span>V-O</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">πεινῶντες </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">group </span> <span class=""><span title="typ">conjuncted</span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">conjuncted-wg</span> <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Obj</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="rule xft" ><span class="f">rule=</span>V-O</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">διψῶντες </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div></div></div></div></div><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Obj</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="rule xft" ><span class="f">rule=</span>V-O</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class= ...

# %%
results = B.search("""
verse book=Matthew chapter=5 verse=6
    c:clause function*
        w:word

c <parent- w
""")
B.show(results, end=1, colorMap=color, condenseType='sentence', hiddenTypes={'wg', 'subphrase'})
# Out:
#   0.03s 3 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/5/6" title="Show this on the website" sec="Matthew 5:6">Matthew 5:6</a></span></div><div class=" children"><div class="contnr c3 trm   " ><div class="lbl c3 trm " ><span class="nd">verse </span> <span class=""><span title="book">Matthew</span> <span title="chapter">5</span>:<span title="verse">6</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/5/6" title="Show this on the website" sec="Matthew 5:6">Matthew 5:6</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="role">s</span> <span title="rule">DetCL</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="parent xft" ><span class="e" edge="parent" nd="56521">parent•</span>
# <span
#     ef="parent"
#     nd="56521"
#     md="1701"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="56521"
#     md="31125"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="56521"
#     md="56520"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">οἱ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="parent xft" ><span class="e" edge="parent" nd="1701">parent•</span>
# <span
#     ef="parent"
#     nd="1701"
#     md="56521"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
#
# <span
#     ef="parent"
#     nd="1701"
#     md="88273"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Obj</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="function xft" ><span class="f">function=</span>Pred-Obj</span><span class="parent xft" ><span class="e" edge="parent" nd="31125">parent•</span>
# <span
#     ef="parent"
#     nd="31125"
#     md="31126"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="31125"
#     md="41044"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="31125"
#     md="56521"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c2   rno hl"  style="background-color: #81ee93;" ><div class="lbl c2  hl"  style="background-color: #81ee93;" ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="cls"></span> <span title="role">v</span> <span title="junction"></span></span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Pred</span><span class="parent xft" ><span class="e" edge="parent" nd="31126">parent•</span>
# <span
#     ef="parent"
#     nd="31126"
#     md="1702"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="31126"
#     md="38334"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="31126"
#     md="31125"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #eaff47;" ><div class="lbl c0 trm hl"  style="background-color: #eaff47;" ><span class="txtu grc">πεινῶντες </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="parent xft" ><span class="e" edge="parent" nd="1702">parent•</span>
# <span
#     ef="parent"
#     nd="1702"
#     md="31126"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
#
# <span
#     ef="parent"
#     nd="1702"
#     md="88275"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">group </span> <span class=""><span title="typ">conjuncted</span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">conjuncted-wg</span> <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="parent xft" ><span class="e" edge="parent" nd="38334">parent•</span>
# <span
#     ef="parent"
#     nd="38334"
#     md="1703"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="38334"
#     md="1704"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="38334"
#     md="31126"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Obj</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="function xft" ><span class="f">function=</span>Pred-Obj</span><span class="parent xft" ><span class="e" edge="parent" nd="31125">parent•</span>
# <span
#     ef="parent"
#     nd="31125"
#     md="31126"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="31125"
#     md="41044"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="31125"
#     md="56521"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c2   lno hl"  style="background-color: #81ee93;" ><div class="lbl c2  hl"  style="background-color: #81ee93;" ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="cls"></span> <span title="role">v</span> <span title="junction"></span></span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Pred</span><span class="parent xft" ><span class="e" edge="parent" nd="31126">parent•</span>
# <span
#     ef="parent"
#     nd="31126"
#     md="1702"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="31126"
#     md="38334"
#     arrow="left"
#     class="etf"
# ><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="31126"
#     md="31125"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="parent xft" ><span class="e" edge="parent" nd="1703">parent•</span>
# <span
#     ef="parent"
#     nd="1703"
#     md="38334"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
#
# <span
#     ef="parent"
#     nd="1703"
#     md="88276"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span></span>
# </span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">διψῶντες </span></div><div class="features"><span class="book

# %%
results = B.search("""
verse
    c:clause function=Pred
        word
""")
B.show(results, end=1, colorMap=color, condenseType='sentence', hiddenTypes={'wg', 'subphrase'})
# Out:
#   0.02s 60 results
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/5/6" title="Show this on the website" sec="Matthew 5:6">Matthew 5:6</a></span></div><div class=" children"><div class="contnr c3 trm   " ><div class="lbl c3 trm " ><span class="nd">verse </span> <span class=""><span title="book">Matthew</span> <span title="chapter">5</span>:<span title="verse">6</span></span></div></div></div>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/5/6" title="Show this on the website" sec="Matthew 5:6">Matthew 5:6</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="role">s</span> <span title="rule">DetCL</span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">οἱ </span></div></div><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Obj</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction"></span></span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Pred-Obj</span></div><div class="children hor wrap "><div class="contnr c2   rno hl"  style="background-color: #81ee93;" ><div class="lbl c2  hl"  style="background-color: #81ee93;" ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="cls"></span> <span title="role">v</span> <span title="junction"></span></span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Pred</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #eaff47;" ><div class="lbl c0 trm hl"  style="background-color: #eaff47;" ><span class="txtu grc">πεινῶντες </span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">group </span> <span class=""><span title="typ">conjuncted</span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">conjuncted-wg</span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c2   lno rno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Obj</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction"></span></span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Pred-Obj</span></div><div class="children hor wrap "><div class="contnr c2   lno hl"  style="background-color: #81ee93;" ><div class="lbl c2  hl"  style="background-color: #81ee93;" ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="cls"></span> <span title="role">v</span> <span title="junction"></span></span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Pred</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">καὶ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">διψῶντες </span></div></div></div></div></div></div></div></div><div class="contnr c2   lno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Obj</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction"></span></span></div><div class="features"><span class="function xft" ><span class="f">function=</span>Pred-Obj</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">Objc</span> <span title="rela"></span> \\ <span title="type">modifier-scope</span> <span title="role">o</span> <span title="rule">DetNP</span></span></div><d ...

# %%
results = B.search('''
verse
    word book_short=Matt chapter=1 verse=1
''')
B.show(results, start=1, end=1, condensed=True, colorMap={1: 'pink'}, multiFeatures=True)
# Out:
#   0.18s 8 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://bibleol.3bmoodle.dk/text/show_text/nestle1904/Matthew/1/1" sec="Matthew 1:1">Matthew 1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span></div><div class="features"><span class="verse xft" ><span class="f">verse=</span>1</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu grc">Βίβλος </span></div><div class="features"><span class="gloss_en " title="gloss_EN">written book, roll, or volume</span><span class="lemma " ><span class="f">lemma=</span>βίβλος</span><span class="strongs " ><span class="f">strongs=</span>976</span><span class="book_short xft" ><span class="f">book_short=</span>Matt</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="verse xft" ><span class="f">verse=</span>1</span><span class="au_vocab_builder_chapter xft" ><span class="f">AU_vocab_builder_chapter=</span>6i</span><span class="alandsynopchapter xft" ><span class="f">AlandSynopChapter=</span>Preface</span><span class="alandsynopevent xft" ><span class="f">AlandSynopEvent=</span>Prologue</span><span class="alandsynopno xft" ><span class="f">AlandSynopNo=</span>1</span><span class="abc_order xft" ><span class="f">abc_order=</span>965</span><span class="alt_morphology xft" ><span class="f">alt_morphology=</span></span><span class="bol_case xft" ><span class="f">bol_case=</span>nominative</span><span class="bol_dict_abc xft" ><span class="f">bol_dict_abc=</span>969</span><span class="bol_frequency_rank xft" ><span class="f">bol_frequency_rank=</span>1052</span><span class="bol_gender xft" ><span class="f">bol_gender=</span>feminine</span><span class="bol_gloss_en xft" ><span class="f">bol_gloss_EN=</span>written book, roll, or volume</span><span class="bol_gloss_pt xft" ><span class="f">bol_gloss_PT=</span>livro, rolo, escrito</span><span class="bol_lemma xft" ><span class="f">bol_lemma=</span>βίβλος</span><span class="bol_lemma_dict xft" ><span class="f">bol_lemma_dict=</span>βίβλος, -ου, ἡ</span><span class="bol_lemma_occ xft" ><span class="f">bol_lemma_occ=</span>10</span><span class="bol_monad_num xft" ><span class="f">bol_monad_num=</span>1</span><span class="bol_mood xft" ><span class="f">bol_mood=</span></span><span class="bol_noun_declension xft" ><span class="f">bol_noun_declension=</span>second_d</span><span class="bol_noun_stem xft" ><span class="f">bol_noun_stem=</span>omicron</span><span class="bol_number xft" ><span class="f">bol_number=</span>singular</span><span class="bol_person xft" ><span class="f">bol_person=</span></span><span class="bol_possessor_number xft" ><span class="f">bol_possessor_number=</span></span><span class="bol_psp xft" ><span class="f">bol_psp=</span>noun</span><span class="bol_ref xft" ><span class="f">bol_ref=</span>Matt 1:1</span><span class="bol_suffix xft" ><span class="f">bol_suffix=</span></span><span class="bol_surface xft" ><span class="f">bol_surface=</span>Βίβλος</span><span class="bol_tense xft" ><span class="f">bol_tense=</span></span><span class="bol_verb_type xft" ><span class="f">bol_verb_type=</span></span><span class="bol_voice xft" ><span class="f">bol_voice=</span></span><span class="book_long xft" ><span class="f">book_long=</span>Matthew</span><span class="booknum xft" ><span class="f">booknum=</span>1</span><span class="case xft" ><span class="f">case=</span>nom</span><span class="clause_number xft" ><span class="f">clause_number=</span>1</span><span class="clause_stop xft" ><span class="f">clause_stop=</span></span><span class="declension xft" ><span class="f">declension=</span>2nd</span><span class="degree xft" ><span class="f">degree=</span></span><span class="extra xft" ><span class="f">extra=</span></span><span class="form_tag xft" ><span class="f">form_tag=</span>N-NSF</span><span class="freq_lemma xft" ><span class="f">freq_lemma=</span>10</span>< ...

# %% [markdown]
# ## March 27 experiment

# %%
N1904.viewtype('syntax')
# Out:
# Display is setup for viewtype [syntax-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/syntax-view.md#start)

# %%
data = F.function.freqList('clause')

for i in data:
    if i[0] == 'Pred':
        print(i)
    if i[0] == 'PreC':
        print(i)
# Out:
# ('Pred', 90)
# ('PreC', 75)

# %%
data = F.rule.freqList('clause')

for i in data:
    if "Conj" in i[0]:
        print(i)
# Out:
# ('Conj2VP', 167)
# ('Conj3CL', 18)
# ('Conj4CL', 7)
# ('Conj-CL', 2)
# ('ConjNp', 2)
# ('Conj5CL', 1)
# ('Conj6CL', 1)
# ('Conj8Np', 1)

# %%
results = N1904.search("""
wg rule=Conj2VP role=v
    clause function=PreC
        word mood=participle|infinitive
""")
#N1904.show(results, end=3, colorMap=color, condensed=True, multiFeatures=False, withNodes=True, condenseType='wg')
#N1904.show(results, end=3, colorMap=color, condensed=True, multiFeatures=False, withNodes=True, condenseType='clause')
N1904.table(results, end=3, colorMap=color, condensed=True)
# Out:
#   0.19s 150 results
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">sentence</th><th class="tf">clause <span title="wg, word">(+2)</span></th><th class="tf">clause <span title="wg, word">(+2)</span></th><th class="tf">word <span title="clause">(+1)</span></th><th class="tf">word <span title="wg">(+1)</span></th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/5/6" title="Show this on the website" sec="Matthew 5:6">Matthew 5:6</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="txtu grc">οἱ </span><span class="plain  rno hlbx"  style="border-color: #ffcb47;" ><span class="plain   hl"  style="background-color: #ffa647;" ><span class="txtu grc">πεινῶντες </span></span></span><span class="plain  lno hlbx"  style="border-color: #ffcb47;" ><span class="txtu grc">καὶ </span><span class="plain   hl"  style="background-color: #81ee93;" ><span class="txtu grc">διψῶντες </span></span></span><span class="txtu grc">τὴν </span><span class="txtu grc">δικαιοσύνην,</span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl"  style="background-color: #81ee93;" ><span class="txtu grc">διψῶντες </span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hlbx"  style="border-color: #eaff47;" ><span class="plain   hl"  style="background-color: #ffa647;" ><span class="txtu grc">πεινῶντες </span></span><span class="txtu grc">καὶ </span><span class="plain   hl"  style="background-color: #81ee93;" ><span class="txtu grc">διψῶντες </span></span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hlbx"  style="border-color: #ffcb47;" ><span class="plain   hl"  style="background-color: #ffa647;" ><span class="txtu grc">πεινῶντες </span></span><span class="txtu grc">καὶ </span><span class="plain   hl"  style="background-color: #81ee93;" ><span class="txtu grc">διψῶντες </span></span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl"  style="background-color: #ffa647;" ><span class="txtu grc">πεινῶντες </span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">2</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/8/14" title="Show this on the website" sec="Matthew 8:14">Matthew 8:14</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="txtu grc">Καὶ </span><span class="plain  r " ><span class="txtu grc">ἐλθὼν </span></span><span class="txtu grc">ὁ </span><span class="txtu grc">Ἰησοῦς </span><span class="plain  l " ><span class="txtu grc">εἰς </span><span class="txtu grc">τὴν </span><span class="txtu grc">οἰκίαν </span><span class="txtu grc">Πέτρου </span></span><span class="txtu grc">εἶδεν </span><span class="txtu grc">τὴν </span><span class="txtu grc">πενθερὰν </span><span class="txtu grc">αὐτοῦ </span><span class="plain  rno hlbx"  style="border-color: #eaff47;" ><span class="plain   hl"  style="background-color: #ffcb47;" ><span class="txtu grc">βεβλημένην </span></span></span><span class="plain  lno hlbx"  style="border-color: #eaff47;" ><span class="txtu grc">καὶ </span><span class="plain   hl"  style="background-color: #ffa647;" ><span class="txtu grc">πυρέσσουσαν·</span></span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hlbx"  style="border-color: #81ee93;" ><span class="plain   hl"  style="background-color: #ffcb47;" ><span class="txtu grc">βεβλημένην </span></span><span class="txtu grc">καὶ </span><span class="plain   hl"  style="background-color: #ffa647;" ><span class="txtu grc">πυρέσσουσαν·</span></span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hlbx"  style="border-color: #eaff47;" ><span class="plain   hl"  style="background-color: #ffcb47;" ><span class="txtu grc">βεβλημένην </span></span><span class="txtu grc">καὶ </span><span class="plain   hl"  style="background-color: #ffa647;" ><span class="txtu grc">πυρέσσουσαν·</span></span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl"  style="background-color: #ffcb47;" ><span class="txtu grc">βεβλημένην </span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl"  style="background-color: #ffa647;" ><span class="txtu grc">πυρέσσουσαν·</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">3</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/11/1" title="Show this on the website" sec="Matthew 11:1">Matthew 11:1</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="txtu grc">τοῦ </span><span class="plain  rno hlbx"  style="border-color: #81ee93;" ><span class="plain   hl"  style="background-color: #eaff47;" ><span class="txtu grc">διδάσκειν </span></span></span><span class="plain  lno hlbx"  style="border-color: #81ee93;" ><span class="txtu grc">καὶ </span><span class="plain   hl"  style="background-color: #ffcb47;" ><span class="txtu grc">κηρύσσειν </span></span></span><span class="txtu grc">ἐν </span><span class="txtu grc">ταῖς </span><span class="txtu grc">πόλεσιν </span><span class="txtu grc">αὐτῶν.</span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hlbx"  style="border-color: #81ee93;" ><span class="plain   hl"  style="background-color: #eaff47;" ><span class="txtu grc">διδάσκειν </span></span><span class="txtu grc">καὶ </span><span class="plain   hl"  style="background-color: #ffcb47;" ><span class="txtu grc">κηρύσσειν </span></span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl"  style="background-color: #eaff47;" ><span class="txtu grc">διδάσκειν </span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl"  style="background-color: #ffcb47;" ><span class="txtu grc">κηρύσσειν </span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hlbx"  style="border-color: #ffa647;" ><span class="plain   hl"  style="background-color: #eaff47;" ><span class="txtu grc">διδάσκειν </span></span><span class="txtu grc">καὶ </span><span class="plain   hl"  style="background-color: #ffcb47;" ><span class="txtu grc">κηρύσσειν </span></span></span></span></td></tr></table>

# %%
results = N1904.search("""
wg rule=Conj2VP role=v
    clause function=Pred
        word mood=indicative|subjunctive|imperative|optative
""")
#N1904.show(results, end=3, colorMap=color, condensed=True, multiFeatures=False, withNodes=True, condenseType='wg')
#N1904.show(results, end=3, colorMap=color, condensed=True, multiFeatures=False, withNodes=True, condenseType='clause')
N1904.table(results, end=3, colorMap=color, condensed=True)
# Out:
#   0.26s 180 results
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">wg</th><th class="tf">word</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/6/19" title="Show this on the website" sec="Matthew 6:19">Matthew 6:19</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl"  style="background-color: #81ee93;" ><span class="txtu grc">διορύσσουσιν </span></span><span class="txtu grc">καὶ </span><span class="txtu grc">κλέπτουσιν·</span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl"  style="background-color: #81ee93;" ><span class="txtu grc">διορύσσουσιν </span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">2</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/6/19" title="Show this on the website" sec="Matthew 6:19">Matthew 6:19</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="txtu grc">καὶ </span><span class="plain   hl"  style="background-color: #81ee93;" ><span class="txtu grc">κλέπτουσιν·</span></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl"  style="background-color: #81ee93;" ><span class="txtu grc">κλέπτουσιν·</span></span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">3</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/6/20" title="Show this on the website" sec="Matthew 6:20">Matthew 6:20</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl"  style="background-color: #81ee93;" ><span class="txtu grc">διορύσσουσιν </span></span><span class="txtu grc">οὐδὲ </span><span class="txtu grc">κλέπτουσιν·</span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain   hl"  style="background-color: #81ee93;" ><span class="txtu grc">διορύσσουσιν </span></span></span></td></tr></table>

# %%
results = N1904.search("""
wg rule=Conj2VP role=v
    word book=Matthew chapter=5 verse=6 function*
""")
N1904.show(results, end=1, colorMap=color, condensed=True, multiFeatures=False, withNodes=True, condenseType='wg')
N1904.show(results, end=1, colorMap=color, condensed=True, multiFeatures=False, withNodes=True, condenseType='clause', hiddenTypes='wg')
#N1904.table(results, end=5, colorMap=color, condensed=True)
# Out:
#   0.24s 3 results
# <p><b>wg</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/5/6" title="Show this on the website" sec="Matthew 5:6">Matthew 5:6</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg:391956 </span> <span class=""><span title="type"></span> <span title="role">v</span> <span title="rule">Conj2VP</span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="function xft" ><span class="f">function=</span>PreC</span><span class="role xft" ><span class="f">role=</span>v</span><span class="rule xft" ><span class="f">rule=</span>Conj2VP</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:268017 </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #81ee93;" ><div class="lbl c0 trm hl"  style="background-color: #81ee93;" ><span class="nd">1702 </span> <span class="txtu grc">πεινῶντες </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg:391957 </span> <span class=""><span title="type">conjuncted-wg</span> <span title="role"></span> <span title="rule"></span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:268018 </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1703 </span> <span class="txtu grc">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:268019 </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1704 </span> <span class="txtu grc">διψῶντες </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div></div></div></div></div></div></div></div>
# <p><b>clause</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/5/6" title="Show this on the website" sec="Matthew 5:6">Matthew 5:6</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause:138429 </span> <span class=""><span title="typ"></span> <span title="function">PreC</span> <span title="rela"></span> \\ <span title="cls"></span> <span title="role">v</span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="function xft" ><span class="f">function=</span>PreC</span><span class="role xft" ><span class="f">role=</span>v</span><span class="rule xft" ><span class="f">rule=</span>Conj2VP</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:268017 </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #ffcb47;" ><div class="lbl c0 trm hl"  style="background-color: #ffcb47;" ><span class="nd">1702 </span> <span class="txtu grc">πεινῶντες </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:268018 </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #ffa647;" ><div class="lbl c0 trm hl"  style="background-color: #ffa647;" ><span class="nd">1703 </span> <span class="txtu grc">καὶ </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase:268019 </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #81ee93;" ><div class="lbl c0 trm hl"  style="background-color: #81ee93;" ><span class="nd">1704 </span> <span class="txtu grc">διψῶντες </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Matthew</span><span class="chapter xft" ><span class="f">chapter=</span>5</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div></div></div></div></div></div>

# %% [markdown]
# ### Discontinuos discourse

# %%
F.note.freqList('word')
# Out:
# (('discontinuous discourse', 1),)

# %%
N1904.viewtype('wg')
results = N1904.search("""
word note=discontinuous\ discourse
""")
N1904.show(results, end=2, colorMap=color, condensed=True, multiFeatures=False, withNodes=False, condenseType='wg')
# Out:
# Display is setup for viewtype [wg-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/wg-view.md#start)
#   0.13s 1 result
# <p><b>wg</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Acts/7/7" title="Show this on the website" sec="Acts 7:7">Acts 7:7</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule"></span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role">adv</span> <span title="rule">O-V-S</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">modifier-clause-scope</span> <span title="role">o</span> <span title="rule">DetNP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τὸ </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">apposition-group</span> <span title="role"></span> <span title="rule">NP-CL</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἔθνος </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">wrapper-clause-scope</span> <span title="role">apposition</span> <span title="rule">PtclCL</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule">O-V</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ᾧ </span></div></div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐὰν </span></div></div><div class="contnr c1   l " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule">O-V</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">δουλεύσουσιν </span></div></div></div></div></div></div></div></div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">κρινῶ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐγώ,</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">modifier-scope</span> <span title="role">s</span> <span title="rule">DetNP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ὁ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Θεὸς </span></div></div></div></div><div class="contnr c0 trm   hl"  style="background-color: #81ee93;" ><div class="lbl c0 trm hl"  style="background-color: #81ee93;" ><span class="txtu grc">εἶπεν,</span></div><div class="features"><span class="note xft" ><span class="f">note=</span>discontinuous discourse</span></div></div></div></div></div>

# %% [markdown]
# ### Past experiment

# %%
results = N1904.search("""
wg
    word book=Revelation chapter=22 verse=21
""")
N1904.show(results, end=1, colorMap=color, condensed=True, multiFeatures=True, withNodes=True, condenseType='wg')
# Out:
#   0.40s 23 results
# <p><b>wg</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Revelation/22/21" title="Show this on the website" sec="Revelation 22:21">Revelation 22:21</a></span></div><div class=" children"><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg:497520 </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule">S-P</span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Revelation</span><span class="bookshort xft" ><span class="f">bookshort=</span>REV</span><span class="cls xft" ><span class="f">cls=</span>cl</span><span class="cltype xft" ><span class="f">cltype=</span>Verbless</span><span class="function xft" ><span class="f">function=</span>Subj-PreC</span><span class="num xft" ><span class="f">num=</span>1869</span><span class="rule xft" ><span class="f">rule=</span>S-P</span><span class="parent xft" ><span class="e" edge="parent" nd="497520">parent•</span>
# <span
#     ef="parent"
#     nd="497520"
#     md="497521"
#     arrow="left"
#     class="etf"
# ><span class="nde">497521</span><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="497520"
#     md="497525"
#     arrow="left"
#     class="etf"
# ><span class="nde">497525</span><span class="etfx">⇥</span></span>
#
# <span
#     ef="parent"
#     nd="497520"
#     md="137806"
#     arrow="right"
#     class="etf"
# ><span class="etfx">↦</span><span class="nde">137806</span></span>
# </span><span class="sibling xft" ><span class="e" edge="sibling" nd="497520">sibling•</span>
# <span
#     ef="sibling"
#     nd="497520"
#     md="489355"
#     arrow="left"
#     class="etf"
# ><span class="nde">489355</span><span class="etfx">⇥</span>465</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489389"
#     arrow="left"
#     class="etf"
# ><span class="nde">489389</span><span class="etfx">⇥</span>464</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489408"
#     arrow="left"
#     class="etf"
# ><span class="nde">489408</span><span class="etfx">⇥</span>463</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489415"
#     arrow="left"
#     class="etf"
# ><span class="nde">489415</span><span class="etfx">⇥</span>462</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489456"
#     arrow="left"
#     class="etf"
# ><span class="nde">489456</span><span class="etfx">⇥</span>461</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489488"
#     arrow="left"
#     class="etf"
# ><span class="nde">489488</span><span class="etfx">⇥</span>460</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489506"
#     arrow="left"
#     class="etf"
# ><span class="nde">489506</span><span class="etfx">⇥</span>459</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489508"
#     arrow="left"
#     class="etf"
# ><span class="nde">489508</span><span class="etfx">⇥</span>458</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489530"
#     arrow="left"
#     class="etf"
# ><span class="nde">489530</span><span class="etfx">⇥</span>457</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489558"
#     arrow="left"
#     class="etf"
# ><span class="nde">489558</span><span class="etfx">⇥</span>456</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489593"
#     arrow="left"
#     class="etf"
# ><span class="nde">489593</span><span class="etfx">⇥</span>455</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489600"
#     arrow="left"
#     class="etf"
# ><span class="nde">489600</span><span class="etfx">⇥</span>454</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489621"
#     arrow="left"
#     class="etf"
# ><span class="nde">489621</span><span class="etfx">⇥</span>453</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489682"
#     arrow="left"
#     class="etf"
# ><span class="nde">489682</span><span class="etfx">⇥</span>452</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489690"
#     arrow="left"
#     class="etf"
# ><span class="nde">489690</span><span class="etfx">⇥</span>451</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489697"
#     arrow="left"
#     class="etf"
# ><span class="nde">489697</span><span class="etfx">⇥</span>450</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489725"
#     arrow="left"
#     class="etf"
# ><span class="nde">489725</span><span class="etfx">⇥</span>449</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489735"
#     arrow="left"
#     class="etf"
# ><span class="nde">489735</span><span class="etfx">⇥</span>448</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489764"
#     arrow="left"
#     class="etf"
# ><span class="nde">489764</span><span class="etfx">⇥</span>447</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489770"
#     arrow="left"
#     class="etf"
# ><span class="nde">489770</span><span class="etfx">⇥</span>446</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489787"
#     arrow="left"
#     class="etf"
# ><span class="nde">489787</span><span class="etfx">⇥</span>445</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489813"
#     arrow="left"
#     class="etf"
# ><span class="nde">489813</span><span class="etfx">⇥</span>444</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489824"
#     arrow="left"
#     class="etf"
# ><span class="nde">489824</span><span class="etfx">⇥</span>443</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489833"
#     arrow="left"
#     class="etf"
# ><span class="nde">489833</span><span class="etfx">⇥</span>442</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489843"
#     arrow="left"
#     class="etf"
# ><span class="nde">489843</span><span class="etfx">⇥</span>441</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489857"
#     arrow="left"
#     class="etf"
# ><span class="nde">489857</span><span class="etfx">⇥</span>440</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489866"
#     arrow="left"
#     class="etf"
# ><span class="nde">489866</span><span class="etfx">⇥</span>439</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489872"
#     arrow="left"
#     class="etf"
# ><span class="nde">489872</span><span class="etfx">⇥</span>438</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489887"
#     arrow="left"
#     class="etf"
# ><span class="nde">489887</span><span class="etfx">⇥</span>437</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489894"
#     arrow="left"
#     class="etf"
# ><span class="nde">489894</span><span class="etfx">⇥</span>436</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489904"
#     arrow="left"
#     class="etf"
# ><span class="nde">489904</span><span class="etfx">⇥</span>435</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489929"
#     arrow="left"
#     class="etf"
# ><span class="nde">489929</span><span class="etfx">⇥</span>434</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489932"
#     arrow="left"
#     class="etf"
# ><span class="nde">489932</span><span class="etfx">⇥</span>433</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489944"
#     arrow="left"
#     class="etf"
# ><span class="nde">489944</span><span class="etfx">⇥</span>432</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489952"
#     arrow="left"
#     class="etf"
# ><span class="nde">489952</span><span class="etfx">⇥</span>431</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489958"
#     arrow="left"
#     class="etf"
# ><span class="nde">489958</span><span class="etfx">⇥</span>430</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489966"
#     arrow="left"
#     class="etf"
# ><span class="nde">489966</span><span class="etfx">⇥</span>429</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489973"
#     arrow="left"
#     class="etf"
# ><span class="nde">489973</span><span class="etfx">⇥</span>428</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="489981"
#     arrow="left"
#     class="etf"
# ><span class="nde">489981</span><span class="etfx">⇥</span>427</span>
#
# <span
#     ef="sibling"
#     nd="497520"
#     md="490012"
#     arrow="left"
#     class="etf"
# ><span class="nde">490

# %%
#word
dict = (1, 137779)
for i in dict:
    print(i, T.text(i,fmt='text-orig-full'))
# Out:
# node
# 1 Βίβλος
# 137779 πάντων.

# %%
T.text(137780,fmt='text-orig-full')
# Out:
# 'Βίβλος γενέσεως Ἰησοῦ Χριστοῦ υἱοῦ Δαυεὶδ υἱοῦ Ἀβραάμ.Ἀβραὰμ ἐγέννησεν τὸν Ἰσαάκ,Ἰσαὰκ δὲ ἐγέννησεν τὸν Ἰακώβ,Ἰακὼβ δὲ ἐγέννησεν τὸν Ἰούδαν καὶ τοὺς ἀδελφοὺς αὐτοῦ,Ἰούδας δὲ ἐγέννησεν τὸν Φαρὲς καὶ τὸν Ζαρὰ ἐκ τῆς Θάμαρ,Φαρὲς δὲ ἐγέννησεν τὸν Ἐσρώμ,Ἐσρὼμ δὲ ἐγέννησεν τὸν Ἀράμ,Ἀρὰμ δὲ ἐγέννησεν τὸν Ἀμιναδάβ,Ἀμιναδὰβ δὲ ἐγέννησεν τὸν Ναασσών,Ναασσὼν δὲ ἐγέννησεν τὸν Σαλμών,Σαλμὼν δὲ ἐγέννησεν τὸν Βόες ἐκ τῆς Ῥαχάβ,Βόες δὲ ἐγέννησεν τὸν Ἰωβὴδ ἐκ τῆς Ῥούθ,Ἰωβὴδ δὲ ἐγέννησεν τὸν Ἰεσσαί,Ἰεσσαὶ δὲ ἐγέννησεν τὸν Δαυεὶδ τὸν βασιλέα
·ἐπὰν δὲ εὕρητε,ἀπαγγείλατέ μοι,ὅπως κἀγὼ ἐλθὼν προσκυνήσω αὐτῷ.οἱ δὲ ἀκούσαντες τοῦ βασιλέως ἐπορεύθησαν·καὶ ἰδοὺ ὁ ἀστὴρ,ὃν εἶδον ἐν τῇ ἀνατολῇ,προῆγεν αὐτούς ἕως ἐλθὼν ἐστάθη ἐπάνω οὗ ἦν τὸ παιδίον.ἰδόντες δὲ τὸν ἀστέρα ἐχάρησαν χαρὰν μεγάλην σφόδρα.καὶ ἐλθόντες εἰς τὴν οἰκίαν εἶδον τὸ παιδίον μετὰ Μαρίας τῆς μητρὸς αὐτοῦ,καὶ πεσόντες προσεκύνησαν αὐτῷ,καὶ ἀνοίξαντες τοὺς θησαυροὺς αὐτῶν προσήνεγκαν αὐτῷ δῶρα,χρυσὸν καὶ λίβανον καὶ σμύρναν.καὶ χρηματισθέντες κατ’ ὄναρ μὴ ἀνακάμψαι πρὸς Ἠρῴδην,δι’ ἄλλης ὁδοῦ ἀνεχώρησαν εἰς τὴν χώραν αὐ ...

# %% [markdown]
# ## June 25 experiment

# %% [markdown]
# Looking for sentences which extends for more than one verse

# %%
results = B.search("""
sentence num=1
    verse verse>1
""")
B.table(results)
# Out:
#   0.03s 44 results
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">sentence</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/1/6" title="Show this on the website" sec="Matthew 1:6">Matthew 1:6</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain  r " ><span class="plain  r " ><span class="txtu grc">Δαυεὶδ </span></span></span><span class="txtu grc">δὲ </span><span class="plain  l " ><span class="txtu grc">ἐγέννησεν </span><span class="txtu grc">τὸν </span><span class="txtu grc">Σολομῶνα </span><span class="txtu grc">ἐκ </span><span class="txtu grc">τῆς </span><span class="txtu grc">τοῦ </span><span class="txtu grc">Οὐρίου,</span></span><span class="plain  r " ><span class="txtu grc">Σολομὼν </span></span><span class="txtu grc">δὲ </span><span class="plain  l " ><span class="txtu grc">ἐγέννησεν </span><span class="txtu grc">τὸν </span><span class="txtu grc">Ῥοβοάμ,</span></span><span class="plain  r " ><span class="txtu grc">Ῥοβοὰμ </span></span><span class="txtu grc">δὲ </span><span class="plain  l " ><span class="txtu grc">ἐγέννησεν </span><span class="txtu grc">τὸν </span><span class="txtu grc">Ἀβιά,</span></span><span class="plain  r " ><span class="txtu grc">Ἀβιὰ </span></span><span class="txtu grc">δὲ </span><span class="plain  l " ><span class="txtu grc">ἐγέννησεν </span><span class="txtu grc">τὸν </span><span class="txtu grc">Ἀσάφ,</span></span><span class="plain  r " ><span class="txtu grc">Ἀσὰφ </span></span><span class="txtu grc">δὲ </span><span class="plain  l " ><span class="txtu grc">ἐγέννησεν </span><span class="txtu grc">τὸν </span><span class="txtu grc">Ἰωσαφάτ,</span></span><span class="plain  r " ><span class="txtu grc">Ἰωσαφὰτ </span></span><span class="txtu grc">δὲ </span><span class="plain  l " ><span class="txtu grc">ἐγέννησεν </span><span class="txtu grc">τὸν </span><span class="txtu grc">Ἰωράμ,</span></span><span class="plain  r " ><span class="txtu grc">Ἰωρὰμ </span></span><span class="txtu grc">δὲ </span><span class="plain  l " ><span class="txtu grc">ἐγέννησεν </span><span class="txtu grc">τὸν </span><span class="txtu grc">Ὀζείαν,</span></span><span class="plain  r " ><span class="txtu grc">Ὀζείας </span></span><span class="txtu grc">δὲ </span><span class="plain  l " ><span class="txtu grc">ἐγέννησεν </span><span class="txtu grc">τὸν </span><span class="txtu grc">Ἰωαθάμ,</span></span><span class="plain  r " ><span class="txtu grc">Ἰωαθὰμ </span></span><span class="txtu grc">δὲ </span><span class="plain  l " ><span class="txtu grc">ἐγέννησεν </span><span class="txtu grc">τὸν </span><span class="txtu grc">Ἄχαζ,</span></span><span class="plain  r " ><span class="txtu grc">Ἄχαζ </span></span><span class="txtu grc">δὲ </span><span class="plain  l " ><span class="txtu grc">ἐγέννησεν </span><span class="txtu grc">τὸν </span><span class="txtu grc">Ἐζεκίαν,</span></span><span class="plain  r " ><span class="txtu grc">Ἐζεκίας </span></span><span class="txtu grc">δὲ </span><span class="plain  l " ><span class="txtu grc">ἐγέννησεν </span><span class="txtu grc">τὸν </span><span class="txtu grc">Μανασσῆ,</span></span><span class="plain  r " ><span class="txtu grc">Μανασσῆς </span></span><span class="txtu grc">δὲ </span><span class="plain  l " ><span class="txtu grc">ἐγέννησεν </span><span class="txtu grc">τὸν </span><span class="txtu grc">Ἀμώς,</span></span><span class="plain  r " ><span class="txtu grc">Ἀμὼς </span></span><span class="txtu grc">δὲ </span><span class="plain  l " ><span class="txtu grc">ἐγέννησεν </span><span class="txtu grc">τὸν </span><span class="txtu grc">Ἰωσείαν,</span></span><span class="plain  r " ><span class="txtu grc">Ἰωσείας </span></span><span class="txtu grc">δὲ </span><span class="txtu grc">ἐγέννησεν </span><span class="txtu grc">τὸν </span><span class="txtu grc">Ἰεχονίαν </span><span class="txtu grc">καὶ </span><span class="txtu grc">τοὺς </span><span class="txtu grc">ἀδελφοὺς </span><span clas ...
# <tr class="tf ltr"><td class="tf ltr">2</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/1/2" title="Show this on the website" sec="Mark 1:2">Mark 1:2</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="txtu grc">Καθὼς </span><span class="txtu grc">γέγραπται </span><span class="txtu grc">ἐν </span><span class="txtu grc">τῷ </span><span class="txtu grc">Ἠσαΐᾳ </span><span class="txtu grc">τῷ </span><span class="txtu grc">προφήτῃ </span><span class="txtu grc">Ἰδοὺ </span><span class="txtu grc">ἀποστέλλω </span><span class="txtu grc">τὸν </span><span class="txtu grc">ἄγγελόν </span><span class="txtu grc">μου </span><span class="txtu grc">πρὸ </span><span class="txtu grc">προσώπου </span><span class="txtu grc">σου,</span><span class="txtu grc">ὃς </span><span class="txtu grc">κατασκευάσει </span><span class="txtu grc">τὴν </span><span class="txtu grc">ὁδόν </span><span class="txtu grc">σου·</span><span class="txtu grc">φωνὴ </span><span class="txtu grc">βοῶντος </span><span class="txtu grc">ἐν </span><span class="txtu grc">τῇ </span><span class="txtu grc">ἐρήμῳ </span><span class="txtu grc">Ἑτοιμάσατε </span><span class="txtu grc">τὴν </span><span class="txtu grc">ὁδὸν </span><span class="txtu grc">Κυρίου,</span><span class="txtu grc">εὐθείας </span><span class="txtu grc">ποιεῖτε </span><span class="txtu grc">τὰς </span><span class="txtu grc">τρίβους </span><span class="txtu grc">αὐτοῦ,</span><span class="txtu grc">ἐγένετο </span><span class="txtu grc">Ἰωάνης </span><span class="txtu grc">ὁ </span><span class="txtu grc">βαπτίζων </span><span class="txtu grc">ἐν </span><span class="txtu grc">τῇ </span><span class="txtu grc">ἐρήμῳ </span><span class="txtu grc">κηρύσσων </span><span class="txtu grc">βάπτισμα </span><span class="txtu grc">μετανοίας </span><span class="txtu grc">εἰς </span><span class="txtu grc">ἄφεσιν </span><span class="txtu grc">ἁμαρτιῶν.</span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">3</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Luke/1/1" title="Show this on the website" sec="Luke 1:1">Luke 1:1</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="txtu grc">Ἐπειδήπερ </span><span class="txtu grc">πολλοὶ </span><span class="txtu grc">ἐπεχείρησαν </span><span class="txtu grc">ἀνατάξασθαι </span><span class="txtu grc">διήγησιν </span><span class="txtu grc">περὶ </span><span class="txtu grc">τῶν </span><span class="txtu grc">πεπληροφορημένων </span><span class="txtu grc">ἐν </span><span class="txtu grc">ἡμῖν </span><span class="txtu grc">πραγμάτων,</span><span class="txtu grc">καθὼς </span><span class="txtu grc">παρέδοσαν </span><span class="txtu grc">ἡμῖν </span><span class="txtu grc">οἱ </span><span class="txtu grc">ἀπ’ </span><span class="txtu grc">ἀρχῆς </span><span class="txtu grc">αὐτόπται </span><span class="txtu grc">καὶ </span><span class="txtu grc">ὑπηρέται </span><span class="txtu grc">γενόμενοι </span><span class="txtu grc">τοῦ </span><span class="txtu grc">λόγου,</span><span class="txtu grc">ἔδοξε </span><span class="txtu grc">κἀμοὶ </span><span class="txtu grc">παρηκολουθηκότι </span><span class="txtu grc">ἄνωθεν </span><span class="txtu grc">πᾶσιν </span><span class="txtu grc">ἀκριβῶς </span><span class="txtu grc">καθεξῆς </span><span class="txtu grc">σοι </span><span class="txtu grc">γράψαι,</span><span class="txtu grc">κράτιστε </span><span class="txtu grc">Θεόφιλε,</span><span class="txtu grc">ἵνα </span><span class="txtu grc">ἐπιγνῷς </span><span class

# %%
results = A.search("""
sentence num=1
    verse verse>1
""")
A.table(results)
# Out:
#   0.02s 20 results
# <table><tr class="tf ltr"><th class="tf ltr">n</th><th class="tf ltr">p</th><th class="tf ltr">sentence</th></tr>
# <tr class="tf ltr"><td class="tf ltr">1</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Luke/1/1" title="Show this on the website" sec="Luke 1:1">Luke 1:1</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="txtu grc">Ἐπειδήπερ </span><span class="txtu grc">πολλοὶ </span><span class="txtu grc">ἐπεχείρησαν </span><span class="txtu grc">ἀνατάξασθαι </span><span class="txtu grc">διήγησιν </span><span class="txtu grc">περὶ </span><span class="txtu grc">τῶν </span><span class="txtu grc">πεπληροφορημένων </span><span class="txtu grc">ἐν </span><span class="txtu grc">ἡμῖν </span><span class="txtu grc">πραγμάτων,</span><span class="txtu grc">καθὼς </span><span class="txtu grc">παρέδοσαν </span><span class="txtu grc">ἡμῖν </span><span class="txtu grc">οἱ </span><span class="txtu grc">ἀπ’ </span><span class="txtu grc">ἀρχῆς </span><span class="txtu grc">αὐτόπται </span><span class="txtu grc">καὶ </span><span class="txtu grc">ὑπηρέται </span><span class="txtu grc">γενόμενοι </span><span class="txtu grc">τοῦ </span><span class="txtu grc">λόγου,</span><span class="txtu grc">ἔδοξε </span><span class="txtu grc">κἀμοὶ </span><span class="txtu grc">παρηκολουθηκότι </span><span class="txtu grc">ἄνωθεν </span><span class="txtu grc">πᾶσιν </span><span class="txtu grc">ἀκριβῶς </span><span class="txtu grc">καθεξῆς </span><span class="txtu grc">σοι </span><span class="txtu grc">γράψαι,</span><span class="txtu grc">κράτιστε </span><span class="txtu grc">Θεόφιλε,</span><span class="txtu grc">ἵνα </span><span class="txtu grc">ἐπιγνῷς </span><span class="txtu grc">περὶ </span><span class="txtu grc">ὧν </span><span class="txtu grc">κατηχήθης </span><span class="txtu grc">λόγων </span><span class="txtu grc">τὴν </span><span class="txtu grc">ἀσφάλειαν.</span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">2</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Acts/1/1" title="Show this on the website" sec="Acts 1:1">Acts 1:1</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="plain  r " ><span class="plain  r " ><span class="txtu grc">Τὸν </span></span></span><span class="txtu grc">μὲν </span><span class="plain  l " ><span class="txtu grc">πρῶτον </span><span class="txtu grc">λόγον </span></span><span class="txtu grc">ἐποιησάμην </span><span class="plain  r " ><span class="txtu grc">περὶ </span><span class="plain  r " ><span class="txtu grc">πάντων,</span></span></span><span class="txtu grc">ὦ </span><span class="txtu grc">Θεόφιλε,</span><span class="plain  r " ><span class="txtu grc">ὧν </span></span><span class="txtu grc">ἤρξατο </span><span class="txtu grc">ὁ </span><span class="txtu grc">Ἰησοῦς </span><span class="txtu grc">ποιεῖν </span><span class="txtu grc">τε </span><span class="txtu grc">καὶ </span><span class="txtu grc">διδάσκειν,</span><span class="txtu grc">ἄχρι </span><span class="txtu grc">ἧς </span><span class="txtu grc">ἡμέρας </span><span class="txtu grc">ἐντειλάμενος </span><span class="txtu grc">τοῖς </span><span class="plain  r " ><span class="txtu grc">ἀποστόλοις </span></span><span class="txtu grc">διὰ </span><span class="txtu grc">Πνεύματος </span><span class="txtu grc">Ἁγίου </span><span class="plain  l " ><span class="plain  l " ><span class="txtu grc">οὓς </span><span class="txtu grc">ἐξελέξατο </span></span></span><span class="txtu grc">ἀνελήμφθη·</span><span class="txtu grc">οἷς </span><span class="txtu grc">καὶ </span><span class="txtu grc">παρέστησεν </span><span class="txtu grc">ἑαυτὸν </span><span class="txtu grc">ζῶντα </span><span class="txtu grc">μετὰ </span><span class="txtu grc">τὸ </span><span class="txtu grc">παθεῖν </span><span class="txtu grc">αὐτὸν </span><span class="txtu grc">ἐν </span><span class="txtu grc">πολλοῖς </span><span class="txtu grc">τεκμηρίοις,</span><span class="txtu grc">δι’ </span><span class="txtu grc">ἡμερῶν </span><span class="txtu grc">τεσσεράκοντα </span><span class="txtu grc">ὀπτανόμενος </span><span class="txtu grc">αὐτοῖς </span><span class="txtu grc">καὶ </span><span class="txtu grc">λέγων </span><span class="txtu grc">τὰ </span><span class="txtu grc">περὶ </span><span class="txtu grc">τῆς </span><span class="txtu grc">βασιλείας </span><span class="txtu grc">τοῦ </span><span class="txtu grc">Θεοῦ·</span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">3</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Romans/1/1" title="Show this on the website" sec="Romans 1:1">Romans 1:1</a></span></span></td><td class="tf ltr"><span class=" ubd"><span class="txtu grc">Παῦλος </span><span class="txtu grc">δοῦλος </span><span class="txtu grc">Χριστοῦ </span><span class="txtu grc">Ἰησοῦ,</span><span class="txtu grc">κλητὸς </span><span class="txtu grc">ἀπόστολος </span><span class="txtu grc">ἀφωρισμένος </span><span class="txtu grc">εἰς </span><span class="txtu grc">εὐαγγέλιον </span><span class="txtu grc">Θεοῦ,</span><span class="txtu grc">ὃ </span><span class="txtu grc">προεπηγγείλατο </span><span class="txtu grc">διὰ </span><span class="txtu grc">τῶν </span><span class="txtu grc">προφητῶν </span><span class="txtu grc">αὐτοῦ </span><span class="txtu grc">ἐν </span><span class="txtu grc">γραφαῖς </span><span class="txtu grc">ἁγίαις </span><span class="txtu grc">περὶ </span><span class="txtu grc">τοῦ </span><span class="txtu grc">Υἱοῦ </span><span class="txtu grc">αὐτοῦ </span><span class="txtu grc">τοῦ </span><span class="txtu grc">γενομένου </span><span class="txtu grc">ἐκ </span><span class="txtu grc">σπέρματος </span><span class="txtu grc">Δαυεὶδ </span><span class="txtu grc">κατὰ </span><span class="txtu grc">σάρκα,</span><span class="txtu grc">τοῦ </span><span class="txtu grc">ὁρισθέντος </span><span class="txtu grc">Υἱοῦ </span><span class="txtu grc">Θεοῦ </span><span class="txtu grc">ἐν </span><span class="txtu grc">δυνάμει </span><span class="txtu grc">κατὰ </span><span class="txtu grc">πνεῦμα </span><span class="txtu grc">ἁγιωσύνης </span><span class="txtu grc">ἐξ </span><span class="txtu grc">ἀναστάσεως </span><span class="txtu grc">νεκρῶν,</span><span class="txtu grc">Ἰησοῦ </span><span class="txtu grc">Χριστοῦ </span><span class="txtu grc">τοῦ </span><span class="txtu grc">Κυρίου </span><span class="txtu grc">ἡμῶν,</span><span class="txtu grc">δι’ </span><span class="txtu grc">οὗ </span><span class="txtu grc">ἐλάβομεν </span><span class="txtu grc">χάριν </span><span class="txtu grc">καὶ </span><span class="txtu grc">ἀποστολὴν </span><span class="txtu grc">εἰς </span><span class="txtu grc">ὑπακοὴν </span><span class="txtu grc">πίστεως </span><span class="txtu grc">ἐν </span><span class="txtu grc">πᾶσιν </span><span class="txtu grc">τοῖς </span><span class="txtu grc">ἔθνεσιν </span><span class="txtu grc">ὑπὲρ </span><span class="txtu grc">τοῦ </span><span class="txtu grc">ὀνόματος </span><span class="txtu grc">αὐτοῦ,</span><span class="txtu grc">ἐν </span><span class="txtu grc">οἷς </span><span class="txtu grc">ἐστε </span><span class="txtu grc">καὶ </span><span class="txtu grc">ὑμεῖς </span><span class="txtu grc">κλητοὶ </span><span class="txtu grc">Ἰησοῦ </span><span class="txtu grc">Χριστοῦ,</span><span class="txtu grc">πᾶσιν </span><span class="txtu grc">τοῖς </span><span class="txtu grc">οὖσιν </span><span class="txtu grc">ἐν </span><span class="txtu grc">Ῥώμῃ </span><span class="txtu grc">ἀγαπητοῖς </span><span class="txtu grc">Θεοῦ,</span><span class="txtu grc">κλητοῖς </span><span class="txtu grc">ἁγίοις·</span></span></td></tr>
# <tr class="tf ltr"><td class="tf ltr">4</td><td class="tf ltr"><span class="tfsechead ltr"><span class="ltr"><a target="_blank" href="https://l

# %%
#N1904.viewtype("wg")
results = A.search("""
sentence num=1
    verse verse>1
""")
A.show(results, end=1, colorMap=color, condensed=True, multiFeatures=False, queryFeatures=False, extraFeatures={'num','rule','crule'}, hiddenTypes='sentence, clause, phrase, subphrase,group', condenseType='verse')
# Out:
#   0.02s 20 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Luke/1/1" title="Show this on the website" sec="Luke 1:1">Luke 1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Luke</span> <span title="chapter">1</span>:<span title="verse">1</span></span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">group</span> <span title="role"></span> <span title="rule">ClCl</span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1</span><span class="rule xft" ><span class="f">rule=</span>ClCl</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule"></span> <span title="junction"></span></span></div><div class="features"><span class="crule xft" ><span class="f">crule=</span>ClCl</span><span class="num xft" ><span class="f">num=</span>2</span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">wrapper-clause-scope</span> <span title="role"></span> <span title="rule">sub-CL</span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>3</span><span class="rule xft" ><span class="f">rule=</span>sub-CL</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἐπειδήπερ </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1</span></div></div><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule"></span> <span title="junction"></span></span></div><div class="features"><span class="crule xft" ><span class="f">crule=</span>ClCl</span><span class="num xft" ><span class="f">num=</span>4</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">πολλοὶ </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>2</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐπεχείρησαν </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>3</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role">o</span> <span title="rule">V-O-ADV</span> <span title="junction">subordinate</span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>5</span><span class="rule xft" ><span class="f">rule=</span>V-O-ADV</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἀνατάξασθαι </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>4</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">διήγησιν </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>5</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">wrapper-scope</span> <span title="role">adv</span> <span title="rule">PrepNp</span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>6</span><span class="rule xft" ><span class="f">rule=</span>PrepNp</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc" ...

# %%
#N1904.viewtype("syntax")
results = A.search("""
sentence num=1
    verse verse>1
""")
A.show(results, end=1, colorMap=color, condensed=True, queryFeatures=False, extraFeatures={'num','crule'}, hiddenTypes='wg,subphrase', condenseType='verse')
# Out:
#   0.02s 20 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Luke/1/1" title="Show this on the website" sec="Luke 1:1">Luke 1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Luke</span> <span title="chapter">1</span>:<span title="verse">1</span></span></div><div class="children hor wrap "><div class="contnr c2   rno hl"  style="background-color: #81ee93;" ><div class="lbl c2  hl"  style="background-color: #81ee93;" ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1</span></div><div class="children hor wrap "><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="cls"></span> <span title="role"></span> <span title="junction"></span></span></div><div class="features"><span class="crule xft" ><span class="f">crule=</span>ClCl</span><span class="num xft" ><span class="f">num=</span>2</span></div><div class="children hor wrap "><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="cls"></span> <span title="role"></span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>3</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἐπειδήπερ </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1</span></div></div><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction"></span></span></div><div class="features"><span class="crule xft" ><span class="f">crule=</span>ClCl</span><span class="num xft" ><span class="f">num=</span>4</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Subj</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">s</span> <span title="rule"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>2</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">πολλοὶ </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>2</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">v</span> <span title="rule"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>3</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐπεχείρησαν </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>3</span></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Obj-Cmpl</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role">o</span> <span title="junction">subordinate</span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>5</span></div><div class="children hor wrap "><div class="contnr c1    " ><div  ...

# %% [markdown]
# ### "Broken" sequence of `sentences`

# %% [markdown]
# Version `0.5.8`

# %%
previousBookName='dummy'
foreLastSentenceNum=-1
previousSentenceNum=0
i=1
for sentence in F.otype.s('sentence'):
    firstNodeText=E.oslots.s(sentence)[0]
    thisBookName=F.book.v(firstNodeText)
    thisSentenceNum=F.num.v(sentence)
    if thisBookName!=previousBookName:
        previousBookName=thisBookName
        previousSentenceNum=0
        foreLastSentenceNum=-1
    expectedSentenceNum=previousSentenceNum+1
    if thisSentenceNum==expectedSentenceNum:
        previousSentenceNum=thisSentenceNum
        foreLastSentenceNum-thisSentenceNum-1
    else:
        if abs(thisSentenceNum - expectedSentenceNum) < 1:
            print(abs(thisSentenceNum-expectedSentenceNum))
        else:
            bookNode=F.book.v(firstNodeText)
            bookChapter=F.chapter.v(firstNodeText)
            bookVerse=F.verse.v(firstNodeText)
            if expectedSentenceNum != 1:
                print(f'{i} - {bookNode} {bookChapter}: {bookVerse} - expected: {expectedSentenceNum} found: {thisSentenceNum}')
        previousSentenceNum=foreLastSentenceNum+1
        i=i+1
# Out:
# 1 - Matthew 1: 2 - expected: 2 found: 23
# 2 - Matthew 2: 17 - expected: 66 found: 162
# 2586 - Mark 1: 2 - expected: 2 found: 1
# 4339 - Luke 1: 32 - expected: 64 found: 717
# 7114 - John 1: 2 - expected: 2 found: 4
# 7115 - John 1: 8 - expected: 9 found: 108
# 9742 - Acts 1: 3 - expected: 2 found: 1
# 11991 - Romans 1: 3 - expected: 2 found: 1
# 13031 - I_Corinthians 1: 2 - expected: 2 found: 1
# 14277 - II_Corinthians 1: 1 - expected: 2 found: 1
# 15001 - Galatians 1: 1 - expected: 2 found: 1
# 15361 - Ephesians 1: 1 - expected: 2 found: 1
# 15596 - Philippians 1: 1 - expected: 2 found: 1
# 15804 - Colossians 1: 5 - expected: 4 found: 1
# 15944 - I_Thessalonians 1: 2 - expected: 3 found: 1
# 16144 - II_Thessalonians 1: 3 - expected: 4 found: 1
# 16245 - I_Timothy 1: 3 - expected: 3 found: 1
# 16437 - II_Timothy 1: 3 - expected: 4 found: 1
# 16575 - Titus 1: 4 - expected: 2 found: 6
# 16576 - Titus 1: 12 - expected: 15 found: 30
# 16627 - Philemon 1: 6 - expected: 4 found: 1
# 16661 - Hebrews 1: 3 - expected: 2 found: 1
# 17272 - James 1: 2 - expected: 2 found: 3
# 17273 - James 1: 11 - expected: 24 found: 34
# 17536 - I_Peter 1: 3 - expected: 4 found: 1
# 17747 - II_Peter 1: 1 - expected: 2 found: 1
# 17835 - I_John 1: 2 - expected: 2 found: 1
# 18206 - II_John 1: 3 - expected: 4 found: 6
# 18236 - III_John 1: 2 - expected: 2 found: 3
# 18237 - III_John 1: 4 - expected: 7 found: 11
# 18265 - Jude 1: 2 - expected: 2 found: 5
# 18267 - Jude 1: 12 - expected: 19 found: 53
# 18281 - Revelation 1: 3 - expected: 2 found: 11
# 18282 - Revelation 1: 4 - expected: 5 found: 18

# %% [markdown]
# Version `0.5.9`

# %%
previousBookName='dummy'
foreLastSentenceNum=-1
previousSentenceNum=0
i=1
for sentence in F.otype.s('sentence'):
    firstNodeText=E.oslots.s(sentence)[0]
    thisBookName=F.book.v(firstNodeText)
    thisSentenceNum=F.num.v(sentence)
    if thisBookName!=previousBookName:
        previousBookName=thisBookName
        previousSentenceNum=0
        foreLastSentenceNum=-1
    expectedSentenceNum=previousSentenceNum+1
    if thisSentenceNum==expectedSentenceNum:
        previousSentenceNum=thisSentenceNum
        foreLastSentenceNum-thisSentenceNum-1
    else:
        if abs(thisSentenceNum - expectedSentenceNum) < 1:
            print(abs(thisSentenceNum-expectedSentenceNum))
        else:
            bookNode=F.book.v(firstNodeText)
            bookChapter=F.chapter.v(firstNodeText)
            bookVerse=F.verse.v(firstNodeText)
            if expectedSentenceNum != 1:
                print(f'{i} - {bookNode} {bookChapter}: {bookVerse} - expected: {expectedSentenceNum} found: {thisSentenceNum}')
        previousSentenceNum=foreLastSentenceNum+1
        i=i+1
# Out:
# 1 - Mark 5: 15 - expected: 434 found: 435
# 1322 - Romans 4: 17 - expected: 224 found: 226
# 2140 - I_Peter 4: 1 - expected: 140 found: 141
# 2215 - I_John 5: 13 - expected: 338 found: 339

# %%
N1904.viewtype("syntax")
results = N1904.search("""
verse book=Mark chapter=5 verse=15
    phrase num=2232
""")
N1904.show(results, end=1, colorMap=color, condensed=True, queryFeatures=False, extraFeatures='num', hiddenTypes='wg,clause,group,subphrase', condenseType='verse')
# Out:
# Display is setup for viewtype [syntax-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/syntax-view.md#start)
#   0.08s 1 result
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/5/15" title="Show this on the website" sec="Mark 5:15">Mark 5:15</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Mark</span> <span title="chapter">5</span>:<span title="verse">15</span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>430</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">καὶ </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1</span></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>431</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">v</span> <span title="rule"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>2227</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἔρχονται </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>2</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">PP</span> <span title="function">Cmpl</span> <span title="rela"></span> \\ <span title="type">wrapper-scope</span> <span title="role">adv</span> <span title="rule">PrepNp</span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>2228</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">πρὸς </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>3</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τὸν </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>4</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰησοῦν,</span></div><div class="features"><span class="num xft" ><span class="f">num=</span>5</span></div></div></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">καὶ </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>6</span></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>432</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">v</span> <span title="rule"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>2231</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">θεωροῦσιν </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>7</span></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><d ...

# %%
N1904.viewtype("wg")
results = N1904.search("""
verse book=Mark chapter=5 verse=15    
    wg num=2232
""")
N1904.show(results, end=1, colorMap=color, condensed=True, multiFeatures=False, queryFeatures=False, extraFeatures='num', hiddenTypes='sentence, clause, phrase, subphrase,group', condenseType='verse')
# Out:
# Display is setup for viewtype [wg-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/wg-view.md#start)
#   0.12s 1 result
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/5/15" title="Show this on the website" sec="Mark 5:15">Mark 5:15</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Mark</span> <span title="chapter">5</span>:<span title="verse">15</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">wrapper-clause-scope</span> <span title="role"></span> <span title="rule">Conj-CL</span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>430</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">καὶ </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule">CLaCL</span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>431</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule">V-ADV</span> <span title="junction">coordinate</span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>655</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἔρχονται </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>2</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">wrapper-scope</span> <span title="role">adv</span> <span title="rule">PrepNp</span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>2228</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">πρὸς </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>3</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">modifier-scope</span> <span title="role"></span> <span title="rule">DetNP</span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>3445</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τὸν </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>4</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰησοῦν,</span></div><div class="features"><span class="num xft" ><span class="f">num=</span>5</span></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">conjuncted-wg</span> <span title="role"></span> <span title="rule"></span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>201</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">καὶ </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>6</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule">CLaCL</span> <span title="junction">coordinate</span></span></div> ...

# %%
N1904.viewtype("syntax")
results = N1904.search("""
verse book=I_John chapter=5 verse=13
    phrase num=1549
        word
""")
N1904.show(results, end=1, colorMap=color, condensed=True, queryFeatures=False, extraFeatures='num', hiddenTypes='wg,subphrase', condenseType='verse')
# Out:
# Display is setup for viewtype [syntax-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/syntax-view.md#start)
#   0.12s 10 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/I_John/5/13" title="Show this on the website" sec="I_John 5:13">I_John 5:13</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">I_John</span> <span title="chapter">5</span>:<span title="verse">13</span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>337</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Objc</span> <span title="rela"></span> \\ <span title="type">demonstrative</span> <span title="role">o</span> <span title="rule"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1547</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ταῦτα </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">v</span> <span title="rule"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1548</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἔγραψα </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>2</span></div></div></div></div><div class="contnr c1   r hl"  style="background-color: #eaff47;" ><div class="lbl c1  hl"  style="background-color: #eaff47;" ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Cmpl</span> <span title="rela"></span> \\ <span title="type">group</span> <span title="role">io</span> <span title="rule">Np-Appos</span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1549</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #81ee93;" ><div class="lbl c0 trm hl"  style="background-color: #81ee93;" ><span class="txtu grc">ὑμῖν </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>3</span></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>339</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἵνα </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>4</span></div></div><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>465</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">v</span> <span title="rule"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1558</span></div><div class="children hor wrap "><div clas ...

# %%
N1904.viewtype("wg")
results = N1904.search("""
verse book=I_John chapter=5 verse=13
    wg num=1549
""")
N1904.show(results, end=1, colorMap=color, condensed=True, multiFeatures=False, queryFeatures=False, extraFeatures='num', hiddenTypes='sentence, clause, phrase, subphrase,group', condenseType='verse')
# Out:
# Display is setup for viewtype [wg-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/wg-view.md#start)
#   0.11s 1 result
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/I_John/5/13" title="Show this on the website" sec="I_John 5:13">I_John 5:13</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">I_John</span> <span title="chapter">5</span>:<span title="verse">13</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule"></span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>463</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ταῦτα </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1</span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἔγραψα </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>2</span></div></div><div class="contnr c1   r hl"  style="background-color: #81ee93;" ><div class="lbl c1  hl"  style="background-color: #81ee93;" ><span class="nd">wg </span> <span class=""><span title="type">group</span> <span title="role">io</span> <span title="rule">Np-Appos</span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>1549</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ὑμῖν </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>3</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">wrapper-clause-scope</span> <span title="role">adv</span> <span title="rule">sub-CL</span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>339</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἵνα </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>4</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule"></span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>465</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">εἰδῆτε </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>5</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">wrapper-clause-scope</span> <span title="role">o</span> <span title="rule">that-VP</span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>340</span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ὅτι </span></div><div class="features"><span class="num xft" ><span class="f">num=</span>6</span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule">O-V</span> <span title="junction"></span></span></div><div class="features"><span class="num xft" ><span class="f">num=</span>466</span></div><div class="children hor wrap "><div class="contnr c1   r " ><div class="lbl c1  " ><span class="nd">wg </span> <span class=""><span title="type">modifier-scope</span> <span title="role">o</span> <span title="rule">NpAdjp</span> <s ...

# %% [markdown]
# ## Text experiment

# %%
AB.viewtype('wg')
# Out:
# Display is setup for viewtype [wg-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/wg-view.md#start)

# %%
results = AB.search("""
word book=Matthew chapter=5 verse=6
""")
AB.show(results, end=1, colorMap=color, condensed=True, multiFeatures=False, withNodes=True)
# Out:
#   0.38s 10 results
# <p><b>sentence</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/5/6" title="Show this on the website" sec="Matthew 5:6">Matthew 5:6</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:247016 </span> <span class=""><span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">wg:391953 </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule"></span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #81ee93;" ><div class="lbl c0 trm hl"  style="background-color: #81ee93;" ><span class="nd">1700 </span> <span class="txtu grc">μακάριοι </span></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:247017 </span> <span class=""><span title="rule">DetCL</span></span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">wg:391953 </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule"></span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg:391954 </span> <span class=""><span title="type">wrapper-clause-scope</span> <span title="role">s</span> <span title="rule">DetCL</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1701 </span> <span class="txtu grc">οἱ </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg:391955 </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule">V-O</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg:391956 </span> <span class=""><span title="type"></span> <span title="role">v</span> <span title="rule">Conj2VP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1702 </span> <span class="txtu grc">πεινῶντες </span></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg:391957 </span> <span class=""><span title="type">conjuncted-wg</span> <span title="role"></span> <span title="rule"></span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1703 </span> <span class="txtu grc">καὶ </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1704 </span> <span class="txtu grc">διψῶντες </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg:391958 </span> <span class=""><span title="type">modifier-scope</span> <span title="role">o</span> <span title="rule">DetNP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1705 </span> <span class="txtu grc">τὴν </span></div></div><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="nd">1706 </span> <span class="txtu grc">δικαιοσύνην,</span></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence:247018 </span> <span class=""><span title="rule">sub-CL</span></span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">wg:391953 </span> <span class=""><span title="type"></span> <span title="role"></span> <span title="rule"></span> <span title="junction"></span></spa ...

# %%
N1904.viewtype('syntax')
# Out:
# Display is setup for viewtype [syntax-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/syntax-view.md#start)

# %%
#wg view
results = NA1904.search("""
verse book=Mark chapter=1 verse=1
""")
NA1904.show(results, end=5, colorMap=color,
            hiddenTypes={'sentence', 'group', 'phrase', 'subphrase', 'clause'},
            condensed=True, multiFeatures=False, suppress={'book','chapter','verse'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20576\3969516063.py in <module>
#       1 #wg view
# ----> 2 results = NA1904.search("""
#       3 verse book=Mark chapter=1 verse=1
#       4 """)
#       5 NA1904.show(results, end=5, colorMap=color,
#
# NameError: name 'NA1904' is not defined

# %%
NA1904.displayReset()

# %%
#syntax view
results = NA1904.search("""
verse book=Mark chapter=1 verse=5
""")
NA1904.show(results, end=5, colorMap=color,
            hiddenTypes={'wg'},
            condensed=True, multiFeatures=False, suppress={'book','chapter','verse'})
# Out:
#   0.01s 1 result
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/1/5" title="Show this on the website" sec="Mark@1:5">Mark@1:5</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book"></span> <span title="chapter"></span>:<span title="verse"></span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class="">#<span title="num">5</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> // <span title="rule">Conj-CL</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">44</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> // <span title="role"></span> <span title="rule"></span> <span title="type"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">καὶ </span></div></div></div></div><div class="contnr c2   rno " ><div class="lbl c2  " ><span class="nd">clause </span> <span class="">#<span title="num">13</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> // <span title="cls">cl</span> <span title="rule">V-ADV-S</span> <span title="junction">coordinate</span></span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">45</span>: <span title="typ"></span> <span title="function"></span> <span title="rela"></span> // <span title="role"></span> <span title="rule">CLaCL</span> <span title="type"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">46</span>: <span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> // <span title="role">v</span> <span title="rule"></span> <span title="type"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἐξεπορεύετο </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">47</span>: <span title="typ">PP</span> <span title="function"></span> <span title="rela"></span> // <span title="role">adv</span> <span title="rule">PrepNp</span> <span title="type">wrapper-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">πρὸς </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">αὐτὸν </span></div></div></div></div></div></div><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">48</span>: <span title="typ"></span> <span title="function">Subj</span> <span title="rela"></span> // <span title="role">s</span> <span title="rule">NpaNp</span> <span title="type"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">49</span>: <span title="typ">NP</span> <span title="function"></span> <span title="rela"></span> // <span title="role"></span> <span title="rule">All-NP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><s ...

# %%
N1904.viewtype('syntax')
# Out:
# Display is setup for viewtype [syntax-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/syntax-view.md#start)

# %%
discontinuos = N1904.nodeFromSectionStr("Mark")
sentence = L.d(discontinuos, otype="sentence")[0]
N1904.pretty(sentence)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/1/1" title="Show this on the website" sec="Mark 1:1">Mark 1:1</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">PreC</span> <span title="rela"></span> \\ <span title="type">modifier-scope</span> <span title="role">p</span> <span title="rule">NPofNP</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">common</span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἀρχὴ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">modifier-scope</span> <span title="role"></span> <span title="rule">DetNP</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">modifier-scope</span> <span title="role"></span> <span title="rule">NPofNP</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">common</span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">εὐαγγελίου </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">group</span> <span title="role"></span> <span title="rule">Np-Appos</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">group</span> <span title="role"></span> <span title="rule">Np-Appos</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">proper</span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰησοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type" ...

# %%
N1904.viewtype('syntax')
# Out:
# Display is setup for viewtype [syntax-view](https://github.com/saulocantanhede/tfgreek2/blob/main/docs/syntax-view.md#start)

# %%
green = "#81ee93"
yellow = "#eaff47"
orange = "#ffcb47"

# %%
book = N1904.nodeFromSectionStr("John")
sentence = L.d(book, otype="sentence")[6]
clause = L.d(sentence, otype="clause")[2]
parent = E.parent.f(clause)[0]
sibling = E.sibling.b(clause)

for (sib, dist) in sibling:
    print(f"\ndistance from {F.otype.v(sib)} node#{sib} to {F.otype.v(clause)}-node #{clause} = {dist}\n")

highlights = {sib[0]:green for sib in sibling}
highlights[clause] = yellow
N1904.pretty(parent, highlights=highlights, queryFeatures=False)
# Out:
# distance from clause node#150134 to clause-node #150136 = 1
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/John/1/6" title="Show this on the website" sec="John 1:6">John 1:6</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="children hor wrap "><div class="contnr c2    hl"  style="background-color: #81ee93;" ><div class="lbl c2  hl"  style="background-color: #81ee93;" ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Subj</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">v</span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἐγένετο </span></div></div></div></div><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">Subj</span> <span title="rela"></span> \\ <span title="type">modifier-clause-scope</span> <span title="role">s</span> <span title="rule">NpAdjp</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">common</span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἄνθρωπος,</span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Cmpl</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction">subordinate</span></span></div><div class="children hor wrap "><div class="contnr c1   lno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">Subj</span> <span title="rela"></span> \\ <span title="type">modifier-clause-scope</span> <span title="role">s</span> <span title="rule">NpAdjp</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">v</span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">ἀπεσταλμένος </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">PP</span> <span title="function">Cmpl</span> <span title="rela"></span> \\ <span title="type">wrapper-scope</span> <span title="role">adv</span> <span title="rule">PrepNp</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">παρὰ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span ...

# %%
N1904.displaySetup(condenseType='verse')

# %%
results = N1904.search("""
verse book=John chapter=1 verse=3
    sentence
        word
        -sibling>1> word
""")
N1904.show(results, end=1, queryFeatures=False, colorMap={2: yellow, 3: green, 4:orange}, condenseType='verse')
# Out:
#   0.89s 1 result
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/John/1/3" title="Show this on the website" sec="John 1:3">John 1:3</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">John</span> <span title="chapter">1</span>:<span title="verse">3</span></span></div><div class="children hor wrap "><div class="contnr c2    hl"  style="background-color: #ffcb47;" ><div class="lbl c2  hl"  style="background-color: #ffcb47;" ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Subj-Cmpl-Pred</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction">coordinate</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Subj</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">s</span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #eaff47;" ><div class="lbl c0 trm hl"  style="background-color: #eaff47;" ><span class="txtu grc">πάντα </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">PP</span> <span title="function">Cmpl</span> <span title="rela"></span> \\ <span title="type">wrapper-scope</span> <span title="role">adv</span> <span title="rule">PrepNp</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">δι’ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">personal</span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">αὐτοῦ </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">v</span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #81ee93;" ><div class="lbl c0 trm hl"  style="background-color: #81ee93;" ><span class="txtu grc">ἐγένετο,</span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">group </span> <span class=""><span title="typ">conjuncted</span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">conjuncted-wg</span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span cla ...

# %%
results = N1904.search("""
verse book=John chapter=1 verse=6
    word
    -frame> word framespec*
""")
N1904.show(results, end=1, colorMap={2: yellow, 3: green, 4:orange}, condenseType='verse', extraFeatures='id')
# Out:
#   0.72s 2 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/John/1/6" title="Show this on the website" sec="John 1:6">John 1:6</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">John</span> <span title="chapter">1</span>:<span title="verse">6</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="verse xft" ><span class="f">verse=</span>6</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Subj</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">v</span> <span title="rule"></span></span></div><div class="features"><span class="framespec xft" ><span class="f">framespec=</span>A0:n43001006002</span><span class="id xft" ><span class="f">id=</span>n43001006001</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #81ee93;" ><div class="lbl c0 trm hl"  style="background-color: #81ee93;" ><span class="txtu grc">Ἐγένετο </span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="framespec xft" ><span class="f">framespec=</span>A0:n43001006002</span><span class="id xft" ><span class="f">id=</span>n43001006001</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div></div></div><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">Subj</span> <span title="rela"></span> \\ <span title="type">modifier-clause-scope</span> <span title="role">s</span> <span title="rule">NpAdjp</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">common</span> <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="id xft" ><span class="f">id=</span>n43001006002</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #ffcb47;" ><div class="lbl c0 trm hl"  style="background-color: #ffcb47;" ><span class="txtu grc">ἄνθρωπος,</span></div><div class="features"><span class="book xft" ><span class="f">book=</span>John</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="id xft" ><span class="f">id=</span>n43001006002</span><span class="verse xft" ><span class="f">verse=</span>6</span></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Cmpl</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction">subordinate</span></span></div><div class="features"><span cl ...

# %%
results = B.search("""
verse book=John chapter=1 verse=1
""")
B.show(results, end=1, multiFeatures=False, queryFeatures=False, hiddenTypes={"wg"}, colorMap=color)
# Out:
#   0.02s 1 result
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/John/1/1" title="Show this on the website" sec="John@1:1">John@1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">John</span> <span title="chapter">1</span> <span title="verse">1</span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">PP</span> <span title="function">PreC</span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἐν </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἀρχῇ </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ἦν </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">Subj</span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Λόγος,</span></div></div></div></div></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">group </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">καὶ </span></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">Subj</span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">ὁ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Λόγος </span></div></div></div></div></div></div><div class="contnr c1    " ><div  ...

# %%
NA1904.Viewtype('syntax')
# Out:
# setup for syntax-view

# %%
discontinuos = NA1904.nodeFromSectionStr("Mark")
sentence = L.d(discontinuos, otype="sentence")[0]
NA1904.pretty(sentence, hiddenTypes='wg')
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/1/1" title="Show this on the website" sec="Mark@1:1">Mark@1:1</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class="">#<span title="num">1</span>: <span title="rule">P2CL</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">1</span>: <span title="function">PreC</span> <span title="role">p</span> <span title="rule">NPofNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἀρχὴ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">2</span>: <span title="function"></span> <span title="role"></span> <span title="rule">DetNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">3</span>: <span title="function"></span> <span title="role"></span> <span title="rule">NPofNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">εὐαγγελίου </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">4</span>: <span title="function"></span> <span title="role"></span> <span title="rule">Np-Appos</span> <span title="type">group</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">5</span>: <span title="function"></span> <span title="role"></span> <span title="rule">Np-Appos</span> <span title="type">group</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἰησοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Χριστοῦ </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">6</span>: <span title="function"></span> <span title="role">apposition</span> <span title="rule">NPofNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">(Υἱοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Θεοῦ).</span></div></div></div></div></div></div></div></div></div></div></div></div></div></div>< ...

# %%
NA1904.Viewtype('reset')

# %%
OptionDict = ['hiddenTypes', 'extraFeatures', 'condensed', 'queryFeatures', 'suppress']
NA1904.displayReset(*OptionDict)

# %%
discontinuos = NA1904.nodeFromSectionStr("Matthew")
sentence = L.d(discontinuos, otype="sentence")[0]
NA1904.pretty(sentence)
# Out:
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Matthew/1/1" title="Show this on the website" sec="Matthew@1:1">Matthew@1:1</a></span></div><div class=" children"><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">PreC</span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Βίβλος </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">PreC</span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">γενέσεως </span></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">PreC</span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἰησοῦ </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Χριστοῦ </span></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div></div><div class="contnr c1    " ><di ...

# %%
results = A.search("""
verse book=Mark chapter=1 verse=1
""")
A.show(results, end=1, multiFeatures=False, queryFeatures=False, colorMap=color)
# Out:
#   0.01s 1 result
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/1/1" title="Show this on the website" sec="Mark@1:1">Mark@1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Mark</span> <span title="chapter">1</span>:<span title="verse">1</span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class="">#<span title="num">1</span>: <span title="rule">P2CL</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">1</span>: <span title="type"></span> <span title="role"></span> <span title="rule">P2CL</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">1</span>: <span title="type">modifier-scope</span> <span title="role">p</span> <span title="rule">NPofNP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">1</span>: <span title="function">PreC</span> <span title="role">p</span> <span title="rule">NPofNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">Ἀρχὴ </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">2</span>: <span title="type">modifier-scope</span> <span title="role"></span> <span title="rule">DetNP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">1</span>: <span title="function">PreC</span> <span title="role">p</span> <span title="rule">NPofNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">2</span>: <span title="function"></span> <span title="role"></span> <span title="rule">DetNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu grc">τοῦ </span></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span> <span class="">#<span title="num">3</span>: <span title="type">modifier-scope</span> <span title="role"></span> <span title="rule">NPofNP</span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">1</span>: <span title="function">PreC</span> <span title="role">p</span> <span title="rule">NPofNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class="">#<span title="num">2</span>: <span title="function"></span> <span title="role"></span> <span title="rule">DetNP</span> <span title="type">modifier-scope</span></span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span cla ...

# %%
results = B.search("""
verse book=Mark chapter=1 verse=1
""")
B.show(results, end=1, multiFeatures=False, queryFeatures=False, colorMap=color)
# Out:
#   0.01s 1 result
# <p><b>result</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/1/1" title="Show this on the website" sec="Mark@1:1">Mark@1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Mark</span> <span title="chapter">1</span> <span title="verse">1</span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">PreC</span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">Ἀρχὴ </span></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">PreC</span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">τοῦ </span></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">PreC</span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1   rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span></div><div class="children hor wrap "><div class="contnr c0 trm   " ><div class="lbl c0 trm " ><span class="txtu">εὐαγγελίου </span></div></div></div></div></div></div></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">wg </span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">PreC</span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela"></span></span></div><div class="children hor wrap "><div class="contnr c1   lno rno " ><div class="lbl c1  " ><span ...

# %% [markdown]
# ## July experiments

# %% [markdown]
# Using old `sentence` classification

# %%
results = N1904.search("""
word book=Mark verse=1 chapter=2
""")
N1904.show(results, end=1, condensed=True, multiFeatures=False, queryFeatures=False, withNodes=False, colorMap=color)
# Out:
#   0.11s 12 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/2/1" title="Show this on the website" sec="Mark 2:1">Mark 2:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Mark</span> <span title="chapter">2</span>:<span title="verse">1</span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #ff479d;" ><div class="lbl c0 trm hl"  style="background-color: #ff479d;" ><span class="txtu grc">Καὶ </span></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Cmpl-Cmpl-Cmpl</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">v</span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #ff4747;" ><div class="lbl c0 trm hl"  style="background-color: #ff4747;" ><span class="txtu grc">εἰσελθὼν </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Adv</span> <span title="rela"></span> \\ <span title="type"></span> <span title="role">adv</span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #477eff;" ><div class="lbl c0 trm hl"  style="background-color: #477eff;" ><span class="txtu grc">πάλιν </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">PP</span> <span title="function">Cmpl</span> <span title="rela"></span> \\ <span title="type">wrapper-scope</span> <span title="role">adv</span> <span title="rule">PrepNp</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #a647ff;" ><div class="lbl c0 trm hl"  style="background-color: #a647ff;" ><span class="txtu grc">εἰς </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="type">proper</span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl" ><div class="lbl c0 trm hl" ><span class="txtu grc">Καφαρναοὺμ </span></div></div></div></div></div></div><div class="contnr c1    " ><div class=" ...

# %% [markdown]
# Using new `sentence` classification

# %%
results = N1904.search("""
word book=Mark verse=1 chapter=2
""")
N1904.show(results, end=1, condensed=True, multiFeatures=False, queryFeatures=False, withNodes=False, colorMap=color)
# Out:
#   0.11s 12 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/2/1" title="Show this on the website" sec="Mark 2:1">Mark 2:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Mark</span> <span title="chapter">2</span>:<span title="verse">1</span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #ff479d;" ><div class="lbl c0 trm hl"  style="background-color: #ff479d;" ><span class="txtu grc">Καὶ </span></div></div></div></div><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="cls"></span> <span title="role"></span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">clause </span> <span class=""><span title="typ"></span> <span title="function">Pred-Cmpl-Cmpl-Cmpl</span> <span title="rela"></span> \\ <span title="cls">cl</span> <span title="role"></span> <span title="junction"></span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Pred</span> <span title="rela"></span> \\ <span title="typems"></span> <span title="role">v</span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #ff4747;" ><div class="lbl c0 trm hl"  style="background-color: #ff4747;" ><span class="txtu grc">εἰσελθὼν </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ"></span> <span title="function">Adv</span> <span title="rela"></span> \\ <span title="typems"></span> <span title="role">adv</span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #477eff;" ><div class="lbl c0 trm hl"  style="background-color: #477eff;" ><span class="txtu grc">πάλιν </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">PP</span> <span title="function">Cmpl</span> <span title="rela"></span> \\ <span title="typems">wrapper-scope</span> <span title="role">adv</span> <span title="rule">PrepNp</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #a647ff;" ><div class="lbl c0 trm hl"  style="background-color: #a647ff;" ><span class="txtu grc">εἰς </span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems">proper</span> <span title="role"></span> <span title="rule"></span></span></div><div class="children hor wrap "><div class="contnr c0 trm    ...

# %%
results = N1904.search("""
word book=Mark verse=1 chapter=1 lemma*
""")
N1904.show(results, end=1, condensed=True, multiFeatures=False, queryFeatures=True, withNodes=False, colorMap=color)
# Out:
#   0.09s 7 results
# <p><b>verse</b> <i>1</i>
# <div class="tfsechead "><span class="ltr"><a target="_blank" href="https://learner.bible/text/show_text/nestle1904/Mark/1/1" title="Show this on the website" sec="Mark 1:1">Mark 1:1</a></span></div><div class=" children"><div class="contnr c3    " ><div class="lbl c3  " ><span class="nd">verse </span> <span class=""><span title="book">Mark</span> <span title="chapter">1</span>:<span title="verse">1</span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="verse xft" ><span class="f">verse=</span>1</span></div><div class="children hor wrap "><div class="contnr c2    " ><div class="lbl c2  " ><span class="nd">sentence </span> <span class=""><span title="function"></span></span></div><div class="features"><span class="book xft" ><span class="f">book=</span>Mark</span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">phrase </span> <span class=""><span title="typ">NP</span> <span title="function">PreC</span> <span title="rela"></span> \\ <span title="typems">modifier-scope</span> <span title="role">p</span> <span title="rule">NPofNP</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems">common</span> <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="lemma xft" ><span class="f">lemma=</span>ἀρχή</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #ffa647;" ><div class="lbl c0 trm hl"  style="background-color: #ffa647;" ><span class="txtu grc">Ἀρχὴ </span></div><div class="features"><span class="lemma " ><span class="f">lemma=</span>ἀρχή</span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems">modifier-scope</span> <span title="role"></span> <span title="rule">DetNP</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems"></span> <span title="role"></span> <span title="rule"></span></span></div><div class="features"><span class="lemma xft" ><span class="f">lemma=</span>ὁ</span></div><div class="children hor wrap "><div class="contnr c0 trm   hl"  style="background-color: #ff7b47;" ><div class="lbl c0 trm hl"  style="background-color: #ff7b47;" ><span class="txtu grc">τοῦ </span></div><div class="features"><span class="lemma " ><span class="f">lemma=</span>ὁ</span><span class="book xft" ><span class="f">book=</span>Mark</span><span class="chapter xft" ><span class="f">chapter=</span>1</span><span class="verse xft" ><span class="f">verse=</span>1</span></div></div></div></div><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ">NP</span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems">modifier-scope</span> <span title="role"></span> <span title="rule">NPofNP</span></span></div><div class="children hor wrap "><div class="contnr c1    " ><div class="lbl c1  " ><span class="nd">subphrase </span> <span class=""><span title="typ"></span> <span title="function"></span> <span title="rela"></span> \\ <span title="typems">common</span> <span title="role"></span> <span title="rule"></span></span></div> ...

# %%
F.after.freqList()
# Out:
# ((' ', 238522),
#  (', ', 18878),
#  ('. ', 11408),
#  ('· ', 4710),
#  ('; ', 1938),
#  (',— ', 36),
#  ('— ', 14),
#  ('). ', 12),
#  ('.]] ', 8),
#  ('·— ', 8),
#  (',) ', 6),
#  (']]. ', 4),
#  ('(, ', 2),
#  ('.) ', 2),
#  (';) ', 2),
#  (';— ', 2),
#  ('] ', 2),
#  (']] ', 2),
#  ('—, ', 2))

# %%
F.before.freqList()
# Out:
# (('—', 32), ('(', 20), ('[[', 14), ('[', 2))

# %%
F.punctuation.freqList()
# Out:
# ((',', 18924), ('.', 11434), ('·', 4718), (';', 1942))

# %%
F.criticalsign.freqList()
# Out:
# (('—', 50), ('(', 22), (')', 22), ('[[', 14), (']]', 14), ('[', 2), (']', 2))

# %%
F.trailer.freqList()
# Out:
# ((' ', 238540), (', ', 18924), ('. ', 11434), ('· ', 4718), ('; ', 1942))

# %%
node = 428664
E.parent.f(node)
# Out:
# (137783,)

# %%
T.text(184053,fmt='lex-orig-plain')
# Out:
# 'καί μηκέτι ἁμαρτάνω. '

# %%
