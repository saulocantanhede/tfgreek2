# %%
# %load_ext autoreload
# %autoreload 2

# %%
import xml.etree.ElementTree as ET
from collections import defaultdict

# %%
files = {'01-matthew.xml', '02-mark.xml', '03-luke.xml',
         '04-john.xml', '05-acts.xml', '06-romans.xml',
         '07-1corinthians.xml', '08-2corinthians.xml', '09-galatians.xml',
         '10-ephesians.xml', '11-philippians.xml', '12-colossians.xml',
         '13-1thessalonians.xml', '14-2thessalonians.xml', '15-1timothy.xml',
         '16-2timothy.xml', '17-titus.xml', '18-philemon.xml',
         '19-hebrews.xml', '20-james.xml', '21-1peter.xml',
         '22-2peter.xml', '23-1john.xml', '24-2john.xml',
         '25-3john.xml', '26-jude.xml', '27-revelation.xml'}

xml_directory = "xml/2024-06-12/gnt/"

def parse_and_inventory_xml(xml_file, keyword_attributes, remaining_attributes):
    tree = ET.parse(xml_file)
    root = tree.getroot()

    def process_element(element):
        if element.tag in keyword_tags:
            for attr, value in element.attrib.items():
                keyword_attributes[element.tag][attr].append(value)
        else:
            for attr, value in element.attrib.items():
                remaining_attributes[element.tag][attr].append(value)

        for child in element:
            process_element(child)

    process_element(root)

keyword_attributes = defaultdict(lambda: defaultdict(list))
remaining_attributes = defaultdict(lambda: defaultdict(list))

keyword_tags = ['w', 'wg']

for file in files:
    xml_file = f"{xml_directory}{file}"
    parse_and_inventory_xml(xml_file, keyword_attributes, remaining_attributes)

def replace_numbers_with_N(value):
    return ''.join(['N' if char.isdigit() else char for char in value])

def format_inventory(attr_dict):
    report = ""
    for tag, attrs in attr_dict.items():
        report += f"\n\t<{tag}>\n"
        for attr, values in attrs.items():
            value_count = defaultdict(int)
            for value in values:
                new_value = replace_numbers_with_N(value)
                value_count[new_value] += 1
            
            last_value = None
            last_attr = None
            for val, count in sorted(value_count.items()):
                if val == last_value:
                    if attr == last_attr:
                        report += f"\t               \"              {count}x {val}\n"
                else:
                    if attr == last_attr:
                        report += f"\t               \"              {count}x {val}\n"
                    else:
                        report += f"\t               {attr}=           {count}x {val}\n"
                last_attr = attr
                last_value = val
    return report

inventory_report = "Inventory of tags and attributes in the source XML files.\n"
inventory_report += "Contains the following sections:\n"
inventory_report += "\tKeyword Attributes\n"
inventory_report += "\tRemaining Attributes and Elements\n\n"

inventory_report += "Keyword Attributes\n"
inventory_report += format_inventory(keyword_attributes)

inventory_report += "\nRemaining Attributes and Elements\n"
inventory_report += format_inventory(remaining_attributes)

inventory_file = "report/2024-06-12/elements_complete_v2.txt"
with open(inventory_file, "w", encoding="utf-8") as f:
    f.write(inventory_report)
print(f"Inventário de tags e atributos salvo em: {inventory_file}")
# Out:
# Inventário de tags e atributos salvo em: report/2024-06-12/elements_complete_v2.txt

# %%
! diff report/2024-06-12/elements_complete_v1.txt report/2024-06-12/elements_complete_v2.txt
# Out:
# 12c12
# < 	               "              30152x cl
# ---
# > 	               "              30857x cl
# 14c14
# < 	               "              30911x np
# ---
# > 	               "              33710x np
# 18,19c18,19
# < 	               rule=           67x ADV-ADV
# < 	               "              14x ADV-ADV-ADV
# ---
# > 	               rule=           64x ADV-ADV
# > 	               "              11x ADV-ADV-ADV
# 29,30c29,30
# < 	               "              24x ADV-ADV-ADV-V
# < 	               "              9x ADV-ADV-ADV-V-ADV
# ---
# > 	               "              21x ADV-ADV-ADV-V
# > 	               "              8x ADV-ADV-ADV-V-ADV
# 52c52
# < 	               "              6x ADV-ADV-P-VC
# ---
# > 	               "              5x ADV-ADV-P-VC
# 56,57c56
# < 	               "              1x ADV-ADV-S-ADV-P-VC
# < 	               "              2x ADV-ADV-S-ADV-V
# ---
# > 	               "              1x ADV-ADV-S-ADV-V
# 61d59
# < 	               "              1x ADV-ADV-S-O-V-ADV
# 65c63
# < 	               "              7x ADV-ADV-S-V-ADV
# ---
# > 	               "              5x ADV-ADV-S-V-ADV
# 67c65
# < 	               "              2x ADV-ADV-S-V-O-ADV
# ---
# > 	               "              1x ADV-ADV-S-V-O-ADV
# 70,71c68,69
# < 	               "              163x ADV-ADV-V
# < 	               "              78x ADV-ADV-V-ADV
# ---
# > 	               "              156x ADV-ADV-V
# > 	               "              75x ADV-ADV-V-ADV
# 82c80
# < 	               "              78x ADV-ADV-V-O
# ---
# > 	               "              75x ADV-ADV-V-O
# 86,87c84,85
# < 	               "              6x ADV-ADV-V-O-S
# < 	               "              22x ADV-ADV-V-S
# ---
# > 	               "              4x ADV-ADV-V-O-S
# > 	               "              20x ADV-ADV-V-S
# 111c109
# < 	               "              57x ADV-O
# ---
# > 	               "              55x ADV-O
# 114c112
# < 	               "              14x ADV-O-ADV-V
# ---
# > 	               "              13x ADV-O-ADV-V
# 118,119c116
# < 	               "              1x ADV-O-IO-S-V
# < 	               "              4x ADV-O-IO-V
# ---
# > 	               "              3x ADV-O-IO-V
# 124,125c121,122
# < 	               "              156x ADV-O-V
# < 	               "              29x ADV-O-V-ADV
# ---
# > 	               "              145x ADV-O-V
# > 	               "              28x ADV-O-V-ADV
# 136,137c133,134
# < 	               "              2x ADV-ON-V-O
# < 	               "              60x ADV-P
# ---
# > 	               "              1x ADV-ON-V-O
# > 	               "              55x ADV-P
# 146,147c143,144
# < 	               "              41x ADV-P-VC
# < 	               "              12x ADV-P-VC-ADV
# ---
# > 	               "              38x ADV-P-VC
# > 	               "              11x ADV-P-VC-ADV
# 150c147
# < 	               "              13x ADV-P-VC-S
# ---
# > 	               "              12x ADV-P-VC-S
# 152,153c149,150
# < 	               "              76x ADV-S
# < 	               "              6x ADV-S-ADV
# ---
# > 	               "              74x ADV-S
# > 	               "              5x ADV-S-ADV
# 168,169c165,166
# < 	               "              37x ADV-S-ADV-V
# < 	               "              20x ADV-S-ADV-V-ADV
# ---
# > 	               "              32x ADV-S-ADV-V
# > 	               "              19x ADV-S-ADV-V-ADV
# 175c172
# < 	               "              20x ADV-S-ADV-V-O
# ---
# > 	               "              19x ADV-S-ADV-V-O
# 184c181
# < 	               "              12x ADV-S-O-V
# ---
# > 	               "              11x ADV-S-O-V
# 190c187
# < 	               "              21x ADV-S-P-VC
# ---
# > 	               "              18x ADV-S-P-VC
# 192,193c189,190
# < 	               "              154x ADV-S-V
# < 	               "              87x ADV-S-V-ADV
# ---
# > 	               "              148x ADV-S-V
# > 	               "              83x ADV-S-V-ADV
# 201,203c198,200
# < 	               "              5x ADV-S-V-IO-O
# < 	               "              65x ADV-S-V-O
# < 	               "              25x ADV-S-V-O-ADV
# ---
# > 	               "              4x ADV-S-V-IO-O
# > 	               "              64x ADV-S-V-O
# > 	               "              22x ADV-S-V-O-ADV
# 205d201
# < 	               "              2x ADV-S-V-O-IO
# 208,211c204,207
# < 	               "              9x ADV-S-VC-P
# < 	               "              1137x ADV-V
# < 	               "              447x ADV-V-ADV
# < 	               "              84x ADV-V-ADV-ADV
# ---
# > 	               "              8x ADV-S-VC-P
# > 	               "              1073x ADV-V
# > 	               "              426x ADV-V-ADV
# > 	               "              83x ADV-V-ADV-ADV
# 222,223c218,219
# < 	               "              31x ADV-V-ADV-S
# < 	               "              8x ADV-V-ADV-S-ADV
# ---
# > 	               "              30x ADV-V-ADV-S
# > 	               "              7x ADV-V-ADV-S-ADV
# 225c221
# < 	               "              41x ADV-V-IO
# ---
# > 	               "              39x ADV-V-IO
# 229c225
# < 	               "              31x ADV-V-IO-O
# ---
# > 	               "              29x ADV-V-IO-O
# 231c227
# < 	               "              11x ADV-V-IO-S
# ---
# > 	               "              10x ADV-V-IO-S
# 234,235c230,231
# < 	               "              661x ADV-V-O
# < 	               "              125x ADV-V-O-ADV
# ---
# > 	               "              625x ADV-V-O
# > 	               "              114x ADV-V-O-ADV
# 238c234
# < 	               "              3x ADV-V-O-ADV-S
# ---
# > 	               "              2x ADV-V-O-ADV-S
# 244c240
# < 	               "              19x ADV-V-O-S
# ---
# > 	               "              17x ADV-V-O-S
# 247,248c243,244
# < 	               "              225x ADV-V-S
# < 	               "              81x ADV-V-S-ADV
# ---
# > 	               "              214x ADV-V-S
# > 	               "              77x ADV-V-S-ADV
# 256c252
# < 	               "              52x ADV-V-S-O
# ---
# > 	               "              49x ADV-V-S-O
# 260c256
# < 	               "              3x ADV-VC-ADV-P
# ---
# > 	               "              2x ADV-VC-ADV-P
# 262c258
# < 	               "              52x ADV-VC-P
# ---
# > 	               "              45x ADV-VC-P
# 266,267c262,263
# < 	               "              16x ADV-VC-P-S
# < 	               "              3x ADV-VC-P-S-ADV
# ---
# > 	               "              13x ADV-VC-P-S
# > 	               "              2x ADV-VC-P-S-ADV
# 269c265
# < 	               "              22x ADV-VC-S-P
# ---
# > 	               "              21x ADV-VC-S-P
# 271c267
# < 	               "              174x ADVNCL
# ---
# > 	               "              160x ADVNCL
# 291c287
# < 	               "              58x AdvpCL
# ---
# > 	               "              54x AdvpCL
# 298c294
# < 	               "              3829x CLaCL
# ---
# > 	               "              3668x CLaCL
# 300c296
# < 	               "              27x CLandCLN
# ---
# > 	               "              26x CLandCLN
# 302,303c298,299
# < 	               "              1579x ClCl
# < 	               "              45x ClClCl
# ---
# > 	               "              707x ClCl
# > 	               "              42x ClClCl
# 305c301
# < 	               "              11x ClClClClCl
# ---
# > 	               "              10x ClClClClCl
# 312,313c308,309
# < 	               "              887x ClClN
# < 	               "              5576x Conj-CL
# ---
# > 	               "              355x ClClN
# > 	               "              5571x Conj-CL
# 319c315
# < 	               "              233x ConjNCL
# ---
# > 	               "              219x ConjNCL
# 349d344
# < 	               "              1x IO-ADV-V-O
# 364c359
# < 	               "              3x IO-S-V-ADV
# ---
# > 	               "              1x IO-S-V-ADV
# 371,373c366,367
# < 	               "              23x IO-V-O
# < 	               "              3x IO-V-O-ADV
# < 	               "              1x IO-V-O-ADV-ADV
# ---
# > 	               "              22x IO-V-O
# > 	               "              2x IO-V-O-ADV
# 379c373
# < 	               "              51x IntjNCL
# ---
# > 	               "              49x IntjNCL
# 422c416
# < 	               "              14x O-ADV-ADV-V
# ---
# > 	               "              13x O-ADV-ADV-V
# 428,429c422,423
# < 	               "              174x O-ADV-V
# < 	               "              28x O-ADV-V-ADV
# ---
# > 	               "              164x O-ADV-V
# > 	               "              26x O-ADV-V-ADV
# 434c428
# < 	               "              3x O-ADV-V-ON
# ---
# > 	               "              2x O-ADV-V-ON
# 442c436
# < 	               "              26x O-IO-V
# ---
# > 	               "              25x O-IO-V
# 446,447c440
# < 	               "              1x O-IO-V-S-ADV
# < 	               "              7x O-ON
# ---
# > 	               "              6x O-ON
# 454c447
# < 	               "              21x O-S-ADV-V
# ---
# > 	               "              20x O-S-ADV-V
# 457c450
# < 	               "              4x O-S-IO-V
# ---
# > 	               "              2x O-S-IO-V
# 459,460c452,453
# < 	               "              86x O-S-V
# < 	               "              20x O-S-V-ADV
# ---
# > 	               "              80x O-S-V
# > 	               "              17x O-S-V-ADV
# 463,468c456,461
# < 	               "              19x O-S-V-IO
# < 	               "              3x O-S-V-IO-ADV
# < 	               "              1076x O-V
# < 	               "              276x O-V-ADV
# < 	               "              47x O-V-ADV-ADV
# < 	               "              9x O-V-ADV-ADV-ADV
# ---
# > 	               "              18x O-S-V-IO
# > 	               "              2x O-S-V-IO-ADV
# > 	               "              1050x O-V
# > 	               "              264x O-V-ADV
# > 	               "              45x O-V-ADV-ADV
# > 	               "              8x O-V-ADV-ADV-ADV
# 471,472c464,465
# < 	               "              2x O-V-ADV-S-ADV
# < 	               "              95x O-V-IO
# ---
# > 	               "              1x O-V-ADV-S-ADV
# > 	               "              87x O-V-IO
# 475c468
# < 	               "              17x O-V-IO-S
# ---
# > 	               "              13x O-V-IO-S
# 480,481c473,474
# < 	               "              94x O-V-S
# < 	               "              30x O-V-S-ADV
# ---
# > 	               "              88x O-V-S
# > 	               "              27x O-V-S-ADV
# 489c482
# < 	               "              11x ON-O-V
# ---
# > 	               "              9x ON-O-V
# 500c493
# < 	               "              43x P-ADV
# ---
# > 	               "              41x P-ADV
# 506c499
# < 	               "              3x P-ADV-S-ADV
# ---
# > 	               "              1x P-ADV-S-ADV
# 512,513c505,506
# < 	               "              208x P-S
# < 	               "              17x P-S-ADV
# ---
# > 	               "              199x P-S
# > 	               "              16x P-S-ADV
# 516c509
# < 	               "              38x P-S-VC
# ---
# > 	               "              37x P-S-VC
# 518,520c511,513
# < 	               "              292x P-VC
# < 	               "              60x P-VC-ADV
# < 	               "              10x P-VC-ADV-ADV
# ---
# > 	               "              280x P-VC
# > 	               "              58x P-VC-ADV
# > 	               "              8x P-VC-ADV-ADV
# 523,524c516,517
# < 	               "              203x P-VC-S
# < 	               "              15x P-VC-S-ADV
# ---
# > 	               "              187x P-VC-S
# > 	               "              12x P-VC-S-ADV
# 526c519
# < 	               "              156x PNCL
# ---
# > 	               "              151x PNCL
# 536,537c529,530
# < 	               "              572x PtclCL
# < 	               "              100x S-ADV
# ---
# > 	               "              538x PtclCL
# > 	               "              96x S-ADV
# 543c536
# < 	               "              3x S-ADV-ADV-ADV-V-ADV
# ---
# > 	               "              1x S-ADV-ADV-ADV-V-ADV
# 548c541
# < 	               "              6x S-ADV-ADV-O-V
# ---
# > 	               "              5x S-ADV-ADV-O-V
# 553c546
# < 	               "              45x S-ADV-ADV-V
# ---
# > 	               "              43x S-ADV-ADV-V
# 557,558c550,551
# < 	               "              2x S-ADV-ADV-V-IO
# < 	               "              22x S-ADV-ADV-V-O
# ---
# > 	               "              1x S-ADV-ADV-V-IO
# > 	               "              21x S-ADV-ADV-V-O
# 568,569c561,562
# < 	               "              31x S-ADV-O-V
# < 	               "              5x S-ADV-O-V-ADV
# ---
# > 	               "              29x S-ADV-O-V
# > 	               "              4x S-ADV-O-V-ADV
# 576c569
# < 	               "              16x S-ADV-P-VC
# ---
# > 	               "              14x S-ADV-P-VC
# 578,580c571,573
# < 	               "              360x S-ADV-V
# < 	               "              152x S-ADV-V-ADV
# < 	               "              36x S-ADV-V-ADV-ADV
# ---
# > 	               "              351x S-ADV-V
# > 	               "              147x S-ADV-V-ADV
# > 	               "              35x S-ADV-V-ADV-ADV
# 589,590c582,583
# < 	               "              190x S-ADV-V-O
# < 	               "              40x S-ADV-V-O-ADV
# ---
# > 	               "              180x S-ADV-V-O
# > 	               "              38x S-ADV-V-O-ADV
# 597,598c590,591
# < 	               "              50x S-ADV-VC-P
# < 	               "              5x S-ADV-VC-P-ADV
# ---
# > 	               "              46x S-ADV-VC-P
# > 	               "              4x S-ADV-VC-P-ADV
# 600c593
# < 	               "              40x S-IO
# ---
# > 	               "              36x S-IO
# 606c599
# < 	               "              12x S-IO-V
# ---
# > 	               "              10x S-IO-V
# 611c604
# < 	               "              2x S-IO-V-O-ADV
# ---
# > 	               "              1x S-IO-V-O-ADV
# 615c608
# < 	               "              40x S-O-ADV-V
# ---
# > 	               "              38x S-O-ADV-V
# 620,624c613,617
# < 	               "              2x S-O-ON-V
# < 	               "              202x S-O-V
# < 	               "              48x S-O-V-ADV
# < 	               "              8x S-O-V-ADV-ADV
# < 	               "              5x S-O-V-IO
# ---
# > 	               "              1x S-O-ON-V
# > 	               "              194x S-O-V
# > 	               "              44x S-O-V-ADV
# > 	               "              6x S-O-V-ADV-ADV
# > 	               "              4x S-O-V-IO
# 626c619
# < 	               "              7x S-O-V-ON
# ---
# > 	               "              6x S-O-V-ON
# 630c623
# < 	               "              300x S-P
# ---
# > 	               "              292x S-P
# 637c630
# < 	               "              240x S-P-VC
# ---
# > 	               "              231x S-P-VC
# 640,642c633,635
# < 	               "              639x S-V
# < 	               "              459x S-V-ADV
# < 	               "              119x S-V-ADV-ADV
# ---
# > 	               "              618x S-V
# > 	               "              450x S-V-ADV
# > 	               "              113x S-V-ADV-ADV
# 648d640
# < 	               "              1x S-V-ADV-O-IO
# 653,654c645
# < 	               "              1x S-V-IO-ADV-O
# < 	               "              27x S-V-IO-O
# ---
# > 	               "              26x S-V-IO-O
# 657,659c648,650
# < 	               "              506x S-V-O
# < 	               "              162x S-V-O-ADV
# < 	               "              10x S-V-O-ADV-ADV
# ---
# > 	               "              483x S-V-O
# > 	               "              159x S-V-O-ADV
# > 	               "              9x S-V-O-ADV-ADV
# 662c653
# < 	               "              9x S-V-O-IO
# ---
# > 	               "              8x S-V-O-IO
# 664c655
# < 	               "              2x S-V-O-ON-ADV
# ---
# > 	               "              1x S-V-O-ON-ADV
# 670c661
# < 	               "              24x S-VC-ADV-P
# ---
# > 	               "              23x S-VC-ADV-P
# 672,673c663,664
# < 	               "              397x S-VC-P
# < 	               "              40x S-VC-P-ADV
# ---
# > 	               "              391x S-VC-P
# > 	               "              38x S-VC-P-ADV
# 676,678c667,669
# < 	               "              177x SNCL
# < 	               "              1687x V-ADV
# < 	               "              288x V-ADV-ADV
# ---
# > 	               "              170x SNCL
# > 	               "              1642x V-ADV
# > 	               "              278x V-ADV-ADV
# 682c673
# < 	               "              2x V-ADV-ADV-ADV-S
# ---
# > 	               "              1x V-ADV-ADV-ADV-S
# 685c676
# < 	               "              8x V-ADV-ADV-S
# ---
# > 	               "              7x V-ADV-ADV-S
# 691c682
# < 	               "              137x V-ADV-O
# ---
# > 	               "              129x V-ADV-O
# 695,696c686,687
# < 	               "              112x V-ADV-S
# < 	               "              36x V-ADV-S-ADV
# ---
# > 	               "              106x V-ADV-S
# > 	               "              33x V-ADV-S-ADV
# 698d688
# < 	               "              1x V-ADV-S-ADV-O
# 700,701c690,691
# < 	               "              222x V-IO
# < 	               "              45x V-IO-ADV
# ---
# > 	               "              211x V-IO
# > 	               "              42x V-IO-ADV
# 707,708c697,698
# < 	               "              142x V-IO-O
# < 	               "              12x V-IO-O-ADV
# ---
# > 	               "              132x V-IO-O
# > 	               "              11x V-IO-O-ADV
# 712c702
# < 	               "              45x V-IO-S
# ---
# > 	               "              42x V-IO-S
# 717,720c707,710
# < 	               "              2725x V-O
# < 	               "              551x V-O-ADV
# < 	               "              80x V-O-ADV-ADV
# < 	               "              9x V-O-ADV-ADV-ADV
# ---
# > 	               "              2660x V-O
# > 	               "              540x V-O-ADV
# > 	               "              76x V-O-ADV-ADV
# > 	               "              7x V-O-ADV-ADV-ADV
# 727c717
# < 	               "              67x V-O-IO
# ---
# > 	               "              65x V-O-IO
# 736c726
# < 	               "              103x V-O-S
# ---
# > 	               "              101x V-O-S
# 739,741c729
# < 	               "              3x V-O-S-ADV-ADV-ADV
# < 	               "              1x V-O-S-ADV-ON
# < 	               "              1x V-O-S-IO
# ---
# > 	               "              2x V-O-S-ADV-ADV-ADV
# 743c731
# < 	               "              6x V-O-S-ON
# ---
# > 	               "              5x V-O-S-ON
# 748,751c736,739
# < 	               "              609x V-S
# < 	               "              303x V-S-ADV
# < 	               "              55x V-S-ADV-ADV
# < 	               "              16x V-S-ADV-ADV-ADV
# ---
# > 	               "              587x V-S
# > 	               "              301x V-S-ADV
# > 	               "              53x V-S-ADV-ADV
# > 	               "              15x V-S-ADV-ADV-ADV
# 753,754c741,742
# < 	               "              14x V-S-ADV-O
# < 	               "              2x V-S-ADV-O-ADV
# ---
# > 	               "              12x V-S-ADV-O
# > 	               "              1x V-S-ADV-O-ADV
# 761,763c749,751
# < 	               "              149x V-S-O
# < 	               "              26x V-S-O-ADV
# < 	               "              4x V-S-O-ADV-ADV
# ---
# > 	               "              141x V-S-O
# > 	               "              25x V-S-O-ADV
# > 	               "              3x V-S-O-ADV-ADV
# 768c756
# < 	               "              14x VC-ADV-P
# ---
# > 	               "              13x VC-ADV-P
# 773,774c761
# < 	               "              1x VC-ADV-S-P-ADV
# < 	               "              268x VC-P
# ---
# > 	               "              260x VC-P
# 777c764
# < 	               "              4x VC-P-ADV-S
# ---
# > 	               "              5x VC-P-ADV-S
# 781c768
# < 	               "              2x VC-P-S-ADV-ADV
# ---
# > 	               "              1x VC-P-S-ADV-ADV
# 784c771
# < 	               "              92x VC-S-P
# ---
# > 	               "              90x VC-S-P
# 788c775
# < 	               "              2843x VNCL
# ---
# > 	               "              2753x VNCL
# 792,793c779,780
# < 	               "              142x aCLaCL
# < 	               "              13x aCLaCLaCL
# ---
# > 	               "              141x aCLaCL
# > 	               "              12x aCLaCLaCL
# 801c788
# < 	               "              210x notCLbutCLNCL
# ---
# > 	               "              191x notCLbutCLNCL
# 806,813c793,799
# < 	               "              3029x sub-CL
# < 	               "              894x that-VP
# < 	               cltype=           832x Minor
# < 	               "              1050x VerbElided
# < 	               "              961x Verbless
# < 	               role=           15981x adv
# < 	               "              2429x apposition
# < 	               "              351x aux
# ---
# > 	               "              3114x sub-CL
# > 	               "              903x that-VP
# > 	               cltype=           830x Minor
# > 	               "              1009x VerbElided
# > 	               "              929x Verbless
# > 	               role=           16710x adv
# > 	               "              360x aux
# 816,817c802,803
# < 	               "              8822x o
# < 	               "              218x oN
# ---
# > 	               "              9329x o
# > 	               "              171x oN
# 820,821c806,807
# < 	               "              2x tail
# < 	               "              23x topic
# ---
# > 	               "              1x tail
# > 	               "              25x topic
# 824,838c810,817
# < 	               type=           891x apposition-group
# < 	               "              8075x conjuncted-wg
# < 	               "              4957x group
# < 	               "              1712x modifier-clause-scope
# < 	               "              29645x modifier-scope
# < 	               "              12166x wrapper-clause-scope
# < 	               "              11264x wrapper-scope
# < 	               articular=           28772x true
# < 	               appositioncontainer=           1908x true
# < 	               Rule=           4308x ClCl
# < 	               "              1250x ClClN
# < 	               nodeId=           5558x NNNNNNNNNNNNNNN
# < 	               clauseType=           5296x nominalized
# < 	               junction=           9367x coordinate
# < 	               "              8554x subordinate
# ---
# > 	               articular=           28713x true
# > 	               type=           2799x apposition
# > 	               "              9699x group
# > 	               junction=           2302x apposition
# > 	               Rule=           4942x ClCl
# > 	               "              1689x ClClN
# > 	               nodeId=           6631x NNNNNNNNNNNNNNN
# > 	               clauseType=           5197x nominalized
# 24880,24883c24859,24864
# < 	               strong=           22x N
# < 	               "              1760x NN
# < 	               "              15796x NNN
# < 	               "              120201x NNNN
# ---
# > 	               strong=           24x N
# > 	               "              1761x NN
# > 	               "              15795x NNN
# > 	               "              120193x NNNN
# > 	               "              3x NNNN+NNNN
# > 	               "              3x NNNN+NNNN+NNNN
# 44917c44898
# < 	               "              2855x NNN
# ---
# > 	               "              2868x NNN
# 44920c44901
# < 	               "              121809x NNNNNN
# ---
# > 	               "              122318x NNNNNN
# 44924c44905
# < 	               "              1885x NNNNNN NNNNNN
# ---
# > 	               "              1898x NNNNNN NNNNNN
# 44930c44911
# < 	               "              1458x N.N
# ---
# > 	               "              1461x N.N
# 44936c44917
# < 	               "              4342x N.NN
# ---
# > 	               "              4349x N.NN
# 44947c44928
# < 	               "              645x N.NNN
# ---
# > 	               "              646x N.NNN
# 44952c44933
# < 	               "              20384x NN.N
# ---
# > 	               "              21059x NN.N
# 44960c44941
# < 	               "              164x NN.N NN.NN
# ---
# > 	               "              197x NN.N NN.NN
# 44970c44951
# < 	               "              77779x NN.NN
# ---
# > 	               "              78139x NN.NN
# 44978c44959
# < 	               "              835x NN.NN NN.NN
# ---
# > 	               "              841x NN.NN NN.NN
# 44991c44972
# < 	               "              17050x NN.NNN
# ---
# > 	               "              17135x NN.NNN
# 45027,45028d45007
# < 	               "              613x NN.N{N:NNN}
# < 	               "              22x NN.N{N:NNN} NN.NN
# 71074a71054
# > 	               junction=           496x apposition
# 71076d71055
# < 	               "              10x apposition
# 71197,71198c71176,71177
# < 	               "              200x nNNNNNNNNNNN nNNNNNNNNNNN nNNNNNNNNNNN nNNNNNNNNNNN
# < 	               "              107x nNNNNNNNNNNN nNNNNNNNNNNN nNNNNNNNNNNN nNNNNNNNNNNN nNNNNNNNNNNN
# ---
# > 	               "              201x nNNNNNNNNNNN nNNNNNNNNNNN nNNNNNNNNNNN nNNNNNNNNNNN
# > 	               "              106x nNNNNNNNNNNN nNNNNNNNNNNN nNNNNNNNNNNN nNNNNNNNNNNN nNNNNNNNNNNN
# 71305a71285
# > 	               junction=           1x apposition
